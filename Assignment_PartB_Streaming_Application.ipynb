# %%
#pip install python-geohash

# %%
import json
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType
import geohash
import os

os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.3.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0 pyspark-shell'

#change ip address
host_ip = "10.192.33.112"
#172.16.33.120



mongo_client = MongoClient(
    host=f'{host_ip}',
    port=27017
)
db = mongo_client['fit3182_assignment_db']
collection = db.a2_partB
#to get the latest value after schema change
#collection.drop()

spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('Streaming Application')
    .getOrCreate()
)

#append stream from multiple topic together
topic = "Producer1|Producer2|Producer3"
#topic_hotspot = 'A2_hotspot_topic'
# topic_AQUA = 'Scenaries02'
# topic_TERRA  = 'Scenaries03'

# %%
kafka_sdf = (
    spark.readStream
    .format('kafka')  #auto_offset_reset='earliest' by default 'latest'
    .option('kafka.bootstrap.servers', f'{host_ip}:9092')
    .option('subscribePattern', topic) #listen to multiple topics
    .load()
)
kafka_sdf.printSchema()

#select the value column in dataframe
climatehotspot_sdf = kafka_sdf.select('value')
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
from datetime import datetime, timedelta

def climate_geohash(lat, lon):
    return geohash.encode(lat, lon, precision=3)

def hotspot_geohash(lat, lon):
    return geohash.encode(lat, lon, precision=5)

def insertOne(result):
    collection.insert_one(result)
    #print("INSERTED !")
    

def func(batch_df,batch_id):
    #retrieve all data from dataframe  (for kafka) into a python list for 
    entries = batch_df.collect()
    #convert each entry into python dictionary
    data = [entry.asDict() for entry in entries]
    
    
    if data is not None:
        #for each entry/row in one batch of 10 seconds
        climate_report = None
        climate_geohash3 = None
        hotspot_hash = {}
        #store the hotspot in precision 3
        climate_hash = {}
        
        #each dict
        for row in data: #select value column from kafka dict
            byte_array = row['value']
            # Decode the bytearray into a string
            json_str = byte_array.decode('utf-8')

            # Parse the JSON string into a dictionary
            data_dict = json.loads(json_str)
            
            #climate report
            if data_dict['producer'] == 'Producer_1':
                #take only the first climate report
                if climate_report is None:
                    climate_report = data_dict
                    
                    
                    climate_geohash3 = climate_geohash(climate_report['latitude'], climate_report['longitude'])
                    #initialise a blank array in set to append hotspot later
                    climate_hash[climate_geohash3] = []
                    climate_report['hotspot'] = []

                    
            #hotspot report
            else:
                hotspot_dict = data_dict
                print("hotspot_dict: ", hotspot_dict)    #climate geohash as key only ke
                
                #hash the geohash among the hotspots
                hotspot_geohash5 = hotspot_geohash(hotspot_dict['latitude'], hotspot_dict['longitude'])
                
                #maintain hotspot for not the same geohash string in precision 5
                if hotspot_geohash5 not in hotspot_hash.keys():
                    #accumulate the hotspot dictionary until cliamte report come
                    hotspot_hash[hotspot_geohash5] = [hotspot_dict]
                    
                #add to the array with the same geohash key 
                else:
                    hotspot_hash[hotspot_geohash5].append(hotspot_dict)
                    
                
        #if climate report exist for each batch
        if climate_report is not None:
                #for each geohash5 hotspots do average of temp within 10 minutes
            for key, value in hotspot_hash.items():
                last_hp = value[-1]
                #datetime string      #do again strptime to turn into datetime object
                latest_min = datetime.strptime(last_hp['created_time'], '%H:%M:%S')
                avg_temp = 0
                avg_conf = 0
                len_array = len(value)
                #print(len_array)

                #for each key average the surface temperature and confidence of the array in value
                #by reducing array 
                for hp in value:
                    # within 10 minutes from latest hotspot in each batch
                    time_differnce = latest_min - datetime.strptime(hp['created_time'], '%H:%M:%S')
                    if  time_differnce < timedelta(minutes = 10):
                        #print(time_differnce)
                        avg_temp += hp['surface_temperature_celcius']
                        avg_conf += hp['confidence']

                avg_temp = avg_temp/len_array
                avg_conf = avg_conf/len_array
                last_hp['surface_temperature_celcius'] = avg_temp
                last_hp['avg_conf'] = avg_conf
                #set it to only hotspot for this key
                hotspot_hash[key] = last_hp


                # Check if the first 3 characters of the key match the climate_geohash3
                if str(key[:3]) == climate_geohash3:
                    # If the key exists in climate_hash, append to it, otherwise create a new list
                    if climate_geohash3 in climate_hash:
                        climate_hash[climate_geohash3].append(hotspot_hash[key])
                    else:
                        climate_hash[climate_geohash3] = [hotspot_hash[key]]
                    # Append the hotspots to the climate report
                    #print(climate_hash[climate_geohash3])
                    
                    
            climate_report['hotspot'] = climate_hash[climate_geohash3]
                    #print("hotspots: " + str(climate_report['hotspot']))
            #print(len_array)
            #CAUSE OF fire event
            if climate_report['air_temperature_celcius'] > 20 and climate_report['GHI_w/m2'] > 180:
                climate_report['fire_cause'] = 'natural'
            else:
                climate_report['fire_cause'] = 'other'
        
            print(climate_report)
            insertOne(climate_report)        

                
db_writer = (
    climatehotspot_sdf.writeStream
    .outputMode('append')
    .trigger(processingTime ='10 seconds') # one day 
    #apply a function to each aach of data with the internal of processing time
    .foreachBatch(func) #batch and batch id and input
)

# %%
try:
    query = db_writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.')
finally:
    query.stop()
# Out:
# hotspot_dict:  {'latitude': -36.0295, 'longitude': 143.6409, 'confidence': 89.0, 'surface_temperature_celcius': 65.0, 'producer': 'Producer_3', 'created_time': '09:00:00'}
# hotspot_dict:  {'latitude': -36.984, 'longitude': 148.25, 'confidence': 50.0, 'surface_temperature_celcius': 35.0, 'producer': 'Producer_3', 'created_time': '09:02:00'}
# hotspot_dict:  {'latitude': -34.3539, 'longitude': 141.5629, 'confidence': 81.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_2', 'created_time': '09:04:00'}
# hotspot_dict:  {'latitude': -36.5134, 'longitude': 142.4682, 'confidence': 70.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '09:03:00'}
# hotspot_dict:  {'latitude': -34.9194, 'longitude': 140.9678, 'confidence': 66.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_3', 'created_time': '09:05:00'}
# hotspot_dict:  {'latitude': -37.853, 'longitude': 142.5253, 'confidence': 94.0, 'surface_temperature_celcius': 104.0, 'producer': 'Producer_2', 'created_time': '09:07:00'}
# hotspot_dict:  {'latitude': -38.2234, 'longitude': 143.9549, 'confidence': 56.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '09:08:00'}
# hotspot_dict:  {'latitude': -36.3253, 'longitude': 144.1026, 'confidence': 72.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_3', 'created_time': '09:07:00'}
# hotspot_dict:  {'latitude': -36.6537, 'longitude': 143.8781, 'confidence': 95.0, 'surface_temperature_celcius': 76.0, 'producer': 'Producer_2', 'created_time': '09:09:00'}
# hotspot_dict:  {'latitude': -37.324, 'longitude': 146.1647, 'confidence': 60.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '09:09:00'}
# hotspot_dict:  {'latitude': -37.8519, 'longitude': 147.2555, 'confidence': 59.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_3', 'created_time': '09:10:00'}
# hotspot_dict:  {'latitude': -36.902, 'longitude': 141.9965, 'confidence': 86.0, 'surface_temperature_celcius': 60.0, 'producer': 'Producer_2', 'created_time': '09:12:00'}
# hotspot_dict:  {'latitude': -37.3359, 'longitude': 149.3816, 'confidence': 51.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_2', 'created_time': '09:13:00'}
# hotspot_dict:  {'latitude': -36.3742, 'longitude': 144.4851, 'confidence': 75.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_3', 'created_time': '09:12:00'}
# hotspot_dict:  {'latitude': -37.8759, 'longitude': 143.3141, 'confidence': 63.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_2', 'created_time': '09:14:00'}
# hotspot_dict:  {'latitude': -37.4373, 'longitude': 142.7654, 'confidence': 87.0, 'surface_temperature_celcius': 62.0, 'producer': 'Producer_2', 'created_time': '09:15:00'}
# hotspot_dict:  {'latitude': -36.418, 'longitude': 141.596, 'confidence': 50.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_3', 'created_time': '09:14:00'}
# hotspot_dict:  {'latitude': -37.469, 'longitude': 148.125, 'confidence': 88.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_2', 'created_time': '09:16:00'}
# hotspot_dict:  {'latitude': -37.7697, 'longitude': 148.336, 'confidence': 81.0, 'surface_temperature_celcius': 57.0, 'producer': 'Producer_3', 'created_time': '09:16:00'}
# hotspot_dict:  {'latitude': -34.4929, 'longitude': 141.3558, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '09:17:00'}
# hotspot_dict:  {'latitude': -35.7786, 'longitude': 143.469, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_2', 'created_time': '09:19:00'}
# hotspot_dict:  {'latitude': -38.1403, 'longitude': 144.2187, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_3', 'created_time': '09:18:00'}
# {'latitude': -36.2693, 'longitude': 143.1768, 'air_temperature_celcius': 12, 'relative_humidity': 46.6, 'windspeed_knots': 6.7, 'max_wind_speed': 14.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 106, 'producer': 'Producer_1', 'date': '2024-02-29', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.6946, 'longitude': 144.7875, 'confidence': 100.0, 'surface_temperature_celcius': 117.0, 'producer': 'Producer_3', 'created_time': '09:19:00'}
# hotspot_dict:  {'latitude': -38.0427, 'longitude': 146.3979, 'confidence': 78.0, 'surface_temperature_celcius': 56.0, 'producer': 'Producer_3', 'created_time': '09:20:00'}
# hotspot_dict:  {'latitude': -35.937, 'longitude': 145.607, 'confidence': 73.0, 'surface_temperature_celcius': 51.0, 'producer': 'Producer_2', 'created_time': '09:22:00'}
# hotspot_dict:  {'latitude': -36.357, 'longitude': 141.2363, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '09:21:00'}
# hotspot_dict:  {'latitude': -36.277, 'longitude': 146.165, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_2', 'created_time': '09:23:00'}
# hotspot_dict:  {'latitude': -36.9205, 'longitude': 143.0889, 'confidence': 67.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_2', 'created_time': '09:24:00'}
# hotspot_dict:  {'latitude': -36.6756, 'longitude': 141.708, 'confidence': 63.0, 'surface_temperature_celcius': 57.0, 'producer': 'Producer_3', 'created_time': '09:23:00'}
# hotspot_dict:  {'latitude': -37.5316, 'longitude': 143.1498, 'confidence': 77.0, 'surface_temperature_celcius': 51.0, 'producer': 'Producer_2', 'created_time': '09:25:00'}
# hotspot_dict:  {'latitude': -37.633, 'longitude': 149.264, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '09:25:00'}
# hotspot_dict:  {'latitude': -37.8046, 'longitude': 146.0304, 'confidence': 91.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_2', 'created_time': '09:27:00'}
# hotspot_dict:  {'latitude': -38.294, 'longitude': 143.7227, 'confidence': 60.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '09:28:00'}
# hotspot_dict:  {'latitude': -36.7606, 'longitude': 147.1326, 'confidence': 75.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_3', 'created_time': '09:27:00'}
# hotspot_dict:  {'latitude': -35.4666, 'longitude': 142.0749, 'confidence': 89.0, 'surface_temperature_celcius': 65.0, 'producer': 'Producer_3', 'created_time': '09:28:00'}
# {'latitude': -37.379, 'longitude': 148.132, 'air_temperature_celcius': 12, 'relative_humidity': 44.9, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 107, 'producer': 'Producer_1', 'date': '2024-03-01', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.8644, 'longitude': 143.4263, 'confidence': 91.0, 'surface_temperature_celcius': 69.0, 'producer': 'Producer_2', 'created_time': '09:31:00'}
# hotspot_dict:  {'latitude': -37.9754, 'longitude': 143.3964, 'confidence': 83.0, 'surface_temperature_celcius': 57.0, 'producer': 'Producer_3', 'created_time': '09:30:00'}
# hotspot_dict:  {'latitude': -34.3383, 'longitude': 141.543, 'confidence': 76.0, 'surface_temperature_celcius': 56.0, 'producer': 'Producer_2', 'created_time': '09:33:00'}
# hotspot_dict:  {'latitude': -36.7507, 'longitude': 147.1308, 'confidence': 80.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '09:34:00'}
# hotspot_dict:  {'latitude': -36.1698, 'longitude': 142.0536, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_3', 'created_time': '09:33:00'}
# hotspot_dict:  {'latitude': -38.0219, 'longitude': 141.2238, 'confidence': 76.0, 'surface_temperature_celcius': 62.0, 'producer': 'Producer_3', 'created_time': '09:34:00'}
# hotspot_dict:  {'latitude': -36.448, 'longitude': 145.7893, 'confidence': 72.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '09:36:00'}
# hotspot_dict:  {'latitude': -36.4844, 'longitude': 143.9663, 'confidence': 66.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_3', 'created_time': '09:37:00'}
# hotspot_dict:  {'latitude': -37.5021, 'longitude': 142.8861, 'confidence': 71.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_2', 'created_time': '09:39:00'}
# hotspot_dict:  {'latitude': -37.732, 'longitude': 148.6059, 'confidence': 87.0, 'surface_temperature_celcius': 62.0, 'producer': 'Producer_3', 'created_time': '09:38:00'}
# {'latitude': -37.1405, 'longitude': 144.1375, 'air_temperature_celcius': 20, 'relative_humidity': 60.8, 'windspeed_knots': 10.4, 'max_wind_speed': 16.9, 'precipitation': ' 0.08G', 'GHI_w/m2': 156, 'producer': 'Producer_1', 'date': '2024-03-02', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.3009, 'longitude': 143.4777, 'confidence': 52.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '09:40:00'}
# hotspot_dict:  {'latitude': -36.4371, 'longitude': 141.7692, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_2', 'created_time': '09:42:00'}
# hotspot_dict:  {'latitude': -36.5107, 'longitude': 144.4722, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_3', 'created_time': '09:42:00'}
# hotspot_dict:  {'latitude': -36.5234, 'longitude': 145.4642, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '09:45:00'}
# hotspot_dict:  {'latitude': -37.5436, 'longitude': 143.6122, 'confidence': 80.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_3', 'created_time': '09:45:00'}
# hotspot_dict:  {'latitude': -36.4125, 'longitude': 143.1189, 'confidence': 100.0, 'surface_temperature_celcius': 92.0, 'producer': 'Producer_2', 'created_time': '09:47:00'}
# hotspot_dict:  {'latitude': -37.7052, 'longitude': 144.6926, 'confidence': 72.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_2', 'created_time': '09:49:00'}
# {'latitude': -37.452, 'longitude': 148.115, 'air_temperature_celcius': 8, 'relative_humidity': 43.8, 'windspeed_knots': 7.3, 'max_wind_speed': 14.0, 'precipitation': ' 0.08G', 'GHI_w/m2': 72, 'producer': 'Producer_1', 'date': '2024-03-03', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.6665, 'longitude': 141.7502, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_3', 'created_time': '09:48:00'}
# hotspot_dict:  {'latitude': -36.0799, 'longitude': 146.529, 'confidence': 57.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '09:50:00'}
# hotspot_dict:  {'latitude': -36.0834, 'longitude': 146.5364, 'confidence': 50.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '09:49:00'}
# hotspot_dict:  {'latitude': -36.797, 'longitude': 141.3621, 'confidence': 82.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_2', 'created_time': '09:52:00'}
# hotspot_dict:  {'latitude': -37.5077, 'longitude': 143.2495, 'confidence': 59.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_3', 'created_time': '09:52:00'}
# hotspot_dict:  {'latitude': -36.4553, 'longitude': 142.8786, 'confidence': 76.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_2', 'created_time': '09:54:00'}
# hotspot_dict:  {'latitude': -35.7647, 'longitude': 142.0858, 'confidence': 89.0, 'surface_temperature_celcius': 65.0, 'producer': 'Producer_3', 'created_time': '09:53:00'}
# hotspot_dict:  {'latitude': -37.4843, 'longitude': 143.0592, 'confidence': 89.0, 'surface_temperature_celcius': 66.0, 'producer': 'Producer_2', 'created_time': '09:55:00'}
# hotspot_dict:  {'latitude': -36.634, 'longitude': 144.5408, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '09:57:00'}
# hotspot_dict:  {'latitude': -37.627, 'longitude': 149.33, 'confidence': 92.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '09:56:00'}
# {'latitude': -37.087, 'longitude': 145.37, 'air_temperature_celcius': 9, 'relative_humidity': 40.1, 'windspeed_knots': 7.5, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 84, 'producer': 'Producer_1', 'date': '2024-03-04', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.2367, 'longitude': 141.3998, 'confidence': 65.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '09:58:00'}
# hotspot_dict:  {'latitude': -38.1616, 'longitude': 143.0674, 'confidence': 100.0, 'surface_temperature_celcius': 114.0, 'producer': 'Producer_2', 'created_time': '10:00:00'}
# hotspot_dict:  {'latitude': -35.4619, 'longitude': 143.5251, 'confidence': 58.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_3', 'created_time': '10:00:00'}
# hotspot_dict:  {'latitude': -36.6716, 'longitude': 141.3451, 'confidence': 75.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_3', 'created_time': '10:01:00'}
# hotspot_dict:  {'latitude': -37.8323, 'longitude': 147.2232, 'confidence': 84.0, 'surface_temperature_celcius': 68.0, 'producer': 'Producer_2', 'created_time': '10:03:00'}
# hotspot_dict:  {'latitude': -36.6936, 'longitude': 145.2788, 'confidence': 86.0, 'surface_temperature_celcius': 61.0, 'producer': 'Producer_3', 'created_time': '10:02:00'}
# hotspot_dict:  {'latitude': -36.3634, 'longitude': 144.3871, 'confidence': 72.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '10:05:00'}
# hotspot_dict:  {'latitude': -36.7786, 'longitude': 145.178, 'confidence': 100.0, 'surface_temperature_celcius': 105.0, 'producer': 'Producer_3', 'created_time': '10:04:00'}
# hotspot_dict:  {'latitude': -36.8846, 'longitude': 145.1679, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '10:06:00'}
# hotspot_dict:  {'latitude': -36.3371, 'longitude': 144.5115, 'confidence': 76.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_3', 'created_time': '10:05:00'}
# hotspot_dict:  {'latitude': -34.8404, 'longitude': 143.1806, 'confidence': 78.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_2', 'created_time': '10:07:00'}
# hotspot_dict:  {'latitude': -36.6538, 'longitude': 142.7552, 'confidence': 72.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '10:06:00'}
# hotspot_dict:  {'latitude': -36.4347, 'longitude': 143.5704, 'confidence': 63.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '10:07:00'}
# {'latitude': -38.038, 'longitude': 142.986, 'air_temperature_celcius': 15, 'relative_humidity': 50.7, 'windspeed_knots': 9.2, 'max_wind_speed': 13.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 128, 'producer': 'Producer_1', 'date': '2024-03-05', 'hotspot': [{'latitude': -38.1616, 'longitude': 143.0674, 'confidence': 100.0, 'surface_temperature_celcius': 114.0, 'producer': 'Producer_2', 'created_time': '10:00:00', 'avg_conf': 100.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.295, 'longitude': 144.377, 'confidence': 75.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '10:08:00'}
# hotspot_dict:  {'latitude': -36.8834, 'longitude': 142.2701, 'confidence': 76.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_2', 'created_time': '10:10:00'}
# hotspot_dict:  {'latitude': -36.686, 'longitude': 143.8575, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '10:09:00'}
# hotspot_dict:  {'latitude': -37.8429, 'longitude': 147.2691, 'confidence': 96.0, 'surface_temperature_celcius': 78.0, 'producer': 'Producer_2', 'created_time': '10:11:00'}
# hotspot_dict:  {'latitude': -37.6104, 'longitude': 147.8367, 'confidence': 62.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '10:10:00'}
# hotspot_dict:  {'latitude': -38.3557, 'longitude': 147.0372, 'confidence': 78.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '10:13:00'}
# hotspot_dict:  {'latitude': -36.4195, 'longitude': 141.2093, 'confidence': 60.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '10:12:00'}
# hotspot_dict:  {'latitude': -36.3484, 'longitude': 141.4983, 'confidence': 61.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '10:14:00'}
# hotspot_dict:  {'latitude': -37.7845, 'longitude': 142.9936, 'confidence': 86.0, 'surface_temperature_celcius': 60.0, 'producer': 'Producer_3', 'created_time': '10:13:00'}
# hotspot_dict:  {'latitude': -36.7362, 'longitude': 142.1063, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_2', 'created_time': '10:16:00'}
# hotspot_dict:  {'latitude': -36.943, 'longitude': 141.863, 'confidence': 50.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_3', 'created_time': '10:16:00'}
# hotspot_dict:  {'latitude': -36.5839, 'longitude': 143.0588, 'confidence': 100.0, 'surface_temperature_celcius': 99.0, 'producer': 'Producer_3', 'created_time': '10:17:00'}
# hotspot_dict:  {'latitude': -36.3769, 'longitude': 144.7505, 'confidence': 55.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '10:19:00'}
# {'latitude': -36.748, 'longitude': 144.168, 'air_temperature_celcius': 11, 'relative_humidity': 48.2, 'windspeed_knots': 10.8, 'max_wind_speed': 22.9, 'precipitation': ' 0.59G', 'GHI_w/m2': 96, 'producer': 'Producer_1', 'date': '2024-03-06', 'hotspot': [{'latitude': -37.295, 'longitude': 144.377, 'confidence': 75.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '10:08:00', 'avg_conf': 75.0}, {'latitude': -36.686, 'longitude': 143.8575, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '10:09:00', 'avg_conf': 71.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.876, 'longitude': 143.7804, 'confidence': 89.0, 'surface_temperature_celcius': 65.0, 'producer': 'Producer_3', 'created_time': '10:18:00'}
# hotspot_dict:  {'latitude': -37.7068, 'longitude': 141.3149, 'confidence': 76.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_2', 'created_time': '10:20:00'}
# hotspot_dict:  {'latitude': -37.8046, 'longitude': 146.0304, 'confidence': 91.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_3', 'created_time': '10:19:00'}
# hotspot_dict:  {'latitude': -37.5728, 'longitude': 142.6348, 'confidence': 100.0, 'surface_temperature_celcius': 98.0, 'producer': 'Producer_2', 'created_time': '10:21:00'}
# hotspot_dict:  {'latitude': -36.4483, 'longitude': 142.2303, 'confidence': 76.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_3', 'created_time': '10:20:00'}
# hotspot_dict:  {'latitude': -36.0144, 'longitude': 141.7008, 'confidence': 51.0, 'surface_temperature_celcius': 38.0, 'producer': 'Producer_2', 'created_time': '10:23:00'}
# hotspot_dict:  {'latitude': -36.4339, 'longitude': 141.5458, 'confidence': 87.0, 'surface_temperature_celcius': 62.0, 'producer': 'Producer_3', 'created_time': '10:22:00'}
# hotspot_dict:  {'latitude': -36.5223, 'longitude': 144.5934, 'confidence': 70.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_2', 'created_time': '10:25:00'}
# hotspot_dict:  {'latitude': -36.3711, 'longitude': 145.8311, 'confidence': 59.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_3', 'created_time': '10:24:00'}
# hotspot_dict:  {'latitude': -36.018, 'longitude': 143.2048, 'confidence': 85.0, 'surface_temperature_celcius': 60.0, 'producer': 'Producer_3', 'created_time': '10:25:00'}
# hotspot_dict:  {'latitude': -37.5077, 'longitude': 143.2495, 'confidence': 59.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_2', 'created_time': '10:27:00'}
# hotspot_dict:  {'latitude': -37.722, 'longitude': 148.6026, 'confidence': 62.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '10:28:00'}
# hotspot_dict:  {'latitude': -36.1401, 'longitude': 146.0217, 'confidence': 68.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_3', 'created_time': '10:27:00'}
# hotspot_dict:  {'latitude': -38.1693, 'longitude': 143.0466, 'confidence': 93.0, 'surface_temperature_celcius': 73.0, 'producer': 'Producer_2', 'created_time': '10:29:00'}
# {'latitude': -36.8835, 'longitude': 142.2098, 'air_temperature_celcius': 11, 'relative_humidity': 41.6, 'windspeed_knots': 7.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 101, 'producer': 'Producer_1', 'date': '2024-03-07', 'hotspot': [{'latitude': -37.5728, 'longitude': 142.6348, 'confidence': 100.0, 'surface_temperature_celcius': 98.0, 'producer': 'Producer_2', 'created_time': '10:21:00', 'avg_conf': 100.0}, {'latitude': -37.5077, 'longitude': 143.2495, 'confidence': 59.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_2', 'created_time': '10:27:00', 'avg_conf': 59.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -38.0219, 'longitude': 141.2238, 'confidence': 76.0, 'surface_temperature_celcius': 62.0, 'producer': 'Producer_2', 'created_time': '10:31:00'}
# hotspot_dict:  {'latitude': -36.5607, 'longitude': 144.1913, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '10:30:00'}
# hotspot_dict:  {'latitude': -36.6946, 'longitude': 144.7875, 'confidence': 100.0, 'surface_temperature_celcius': 117.0, 'producer': 'Producer_2', 'created_time': '10:34:00'}
# hotspot_dict:  {'latitude': -36.2721, 'longitude': 146.847, 'confidence': 70.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_3', 'created_time': '10:33:00'}
# hotspot_dict:  {'latitude': -36.0325, 'longitude': 145.7562, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_2', 'created_time': '10:35:00'}
# hotspot_dict:  {'latitude': -36.9748, 'longitude': 143.9369, 'confidence': 55.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '10:36:00'}
# hotspot_dict:  {'latitude': -38.1561, 'longitude': 143.7846, 'confidence': 89.0, 'surface_temperature_celcius': 65.0, 'producer': 'Producer_3', 'created_time': '10:36:00'}
# hotspot_dict:  {'latitude': -37.0856, 'longitude': 143.8728, 'confidence': 71.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_2', 'created_time': '10:38:00'}
# {'latitude': -36.0966, 'longitude': 142.3635, 'air_temperature_celcius': 22, 'relative_humidity': 57.0, 'windspeed_knots': 8.5, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 178, 'producer': 'Producer_1', 'date': '2024-03-08', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.6095, 'longitude': 142.7011, 'confidence': 87.0, 'surface_temperature_celcius': 62.0, 'producer': 'Producer_2', 'created_time': '10:40:00'}
# hotspot_dict:  {'latitude': -37.5115, 'longitude': 143.14, 'confidence': 99.0, 'surface_temperature_celcius': 86.0, 'producer': 'Producer_3', 'created_time': '10:39:00'}
# hotspot_dict:  {'latitude': -35.1064, 'longitude': 141.1556, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_3', 'created_time': '10:40:00'}
# hotspot_dict:  {'latitude': -37.8167, 'longitude': 142.1718, 'confidence': 86.0, 'surface_temperature_celcius': 61.0, 'producer': 'Producer_2', 'created_time': '10:43:00'}
# hotspot_dict:  {'latitude': -37.8704, 'longitude': 142.5842, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_3', 'created_time': '10:42:00'}
# hotspot_dict:  {'latitude': -37.9538, 'longitude': 143.1487, 'confidence': 62.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '10:46:00'}
# hotspot_dict:  {'latitude': -37.9538, 'longitude': 143.1487, 'confidence': 62.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_3', 'created_time': '10:45:00'}
# {'latitude': -38.231, 'longitude': 147.172, 'air_temperature_celcius': 24, 'relative_humidity': 61.6, 'windspeed_knots': 7.7, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 186, 'producer': 'Producer_1', 'date': '2024-03-09', 'hotspot': [], 'fire_cause': 'natural'}
# hotspot_dict:  {'latitude': -36.1398, 'longitude': 141.7793, 'confidence': 62.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '10:49:00'}
# hotspot_dict:  {'latitude': -36.3278, 'longitude': 141.082, 'confidence': 54.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '10:48:00'}
# hotspot_dict:  {'latitude': -36.4837, 'longitude': 142.6042, 'confidence': 83.0, 'surface_temperature_celcius': 63.0, 'producer': 'Producer_3', 'created_time': '10:49:00'}
# hotspot_dict:  {'latitude': -37.382, 'longitude': 149.341, 'confidence': 64.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '10:51:00'}
# hotspot_dict:  {'latitude': -36.6363, 'longitude': 144.3033, 'confidence': 54.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_3', 'created_time': '10:50:00'}
# hotspot_dict:  {'latitude': -36.4147, 'longitude': 141.0669, 'confidence': 56.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '10:53:00'}
# hotspot_dict:  {'latitude': -35.6469, 'longitude': 142.376, 'confidence': 100.0, 'surface_temperature_celcius': 93.0, 'producer': 'Producer_3', 'created_time': '10:52:00'}
# hotspot_dict:  {'latitude': -36.754, 'longitude': 141.7932, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '10:53:00'}
# hotspot_dict:  {'latitude': -36.4392, 'longitude': 144.2111, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '10:55:00'}
# hotspot_dict:  {'latitude': -37.8672, 'longitude': 143.8194, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_3', 'created_time': '10:55:00'}
# hotspot_dict:  {'latitude': -36.6217, 'longitude': 142.0944, 'confidence': 55.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '10:58:00'}
# {'latitude': -38.226, 'longitude': 147.167, 'air_temperature_celcius': 10, 'relative_humidity': 43.7, 'windspeed_knots': 7.2, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 90, 'producer': 'Producer_1', 'date': '2024-03-10', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.7508, 'longitude': 147.1254, 'confidence': 66.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '10:58:00'}
# hotspot_dict:  {'latitude': -37.5406, 'longitude': 142.9301, 'confidence': 59.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_2', 'created_time': '11:00:00'}
# hotspot_dict:  {'latitude': -37.621, 'longitude': 143.447, 'confidence': 87.0, 'surface_temperature_celcius': 61.0, 'producer': 'Producer_2', 'created_time': '11:02:00'}
# hotspot_dict:  {'latitude': -37.9022, 'longitude': 141.1109, 'confidence': 81.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_3', 'created_time': '11:01:00'}
# hotspot_dict:  {'latitude': -37.1999, 'longitude': 143.8231, 'confidence': 100.0, 'surface_temperature_celcius': 90.0, 'producer': 'Producer_3', 'created_time': '11:02:00'}
# hotspot_dict:  {'latitude': -36.0818, 'longitude': 146.5461, 'confidence': 57.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '11:04:00'}
# hotspot_dict:  {'latitude': -36.5509, 'longitude': 144.1143, 'confidence': 76.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_2', 'created_time': '11:05:00'}
# hotspot_dict:  {'latitude': -36.7145, 'longitude': 143.471, 'confidence': 78.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '11:06:00'}
# hotspot_dict:  {'latitude': -37.8025, 'longitude': 143.4677, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_3', 'created_time': '11:05:00'}
# hotspot_dict:  {'latitude': -37.785, 'longitude': 143.092, 'confidence': 56.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '11:07:00'}
# hotspot_dict:  {'latitude': -37.164, 'longitude': 148.915, 'confidence': 55.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_2', 'created_time': '11:08:00'}
# hotspot_dict:  {'latitude': -37.1749, 'longitude': 143.9573, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_3', 'created_time': '11:07:00'}
# {'latitude': -37.406, 'longitude': 148.123, 'air_temperature_celcius': 12, 'relative_humidity': 44.7, 'windspeed_knots': 11.4, 'max_wind_speed': 18.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 107, 'producer': 'Producer_1', 'date': '2024-03-11', 'hotspot': [{'latitude': -37.164, 'longitude': 148.915, 'confidence': 55.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_2', 'created_time': '11:08:00', 'avg_conf': 55.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.6657, 'longitude': 143.1675, 'confidence': 93.0, 'surface_temperature_celcius': 72.0, 'producer': 'Producer_2', 'created_time': '11:11:00'}
# hotspot_dict:  {'latitude': -37.287, 'longitude': 144.392, 'confidence': 79.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_3', 'created_time': '11:10:00'}
# hotspot_dict:  {'latitude': -37.6435, 'longitude': 146.1417, 'confidence': 66.0, 'surface_temperature_celcius': 36.0, 'producer': 'Producer_2', 'created_time': '11:12:00'}
# hotspot_dict:  {'latitude': -38.1756, 'longitude': 143.9829, 'confidence': 65.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '11:13:00'}
# hotspot_dict:  {'latitude': -36.7159, 'longitude': 141.3991, 'confidence': 75.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_2', 'created_time': '11:15:00'}
# hotspot_dict:  {'latitude': -38.0229, 'longitude': 143.749, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_3', 'created_time': '11:15:00'}
# hotspot_dict:  {'latitude': -36.99, 'longitude': 142.9147, 'confidence': 76.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_2', 'created_time': '11:17:00'}
# hotspot_dict:  {'latitude': -37.386, 'longitude': 148.043, 'confidence': 84.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_2', 'created_time': '11:18:00'}
# hotspot_dict:  {'latitude': -36.7507, 'longitude': 147.1308, 'confidence': 80.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '11:17:00'}
# {'latitude': -37.634, 'longitude': 149.237, 'air_temperature_celcius': 16, 'relative_humidity': 48.4, 'windspeed_knots': 8.1, 'max_wind_speed': 15.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 139, 'producer': 'Producer_1', 'date': '2024-03-12', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.4097, 'longitude': 145.8952, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_2', 'created_time': '11:19:00'}
# hotspot_dict:  {'latitude': -37.3942, 'longitude': 147.0455, 'confidence': 60.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '11:20:00'}
# hotspot_dict:  {'latitude': -36.767, 'longitude': 142.6811, 'confidence': 55.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '11:19:00'}
# hotspot_dict:  {'latitude': -36.7954, 'longitude': 141.3483, 'confidence': 83.0, 'surface_temperature_celcius': 56.0, 'producer': 'Producer_2', 'created_time': '11:23:00'}
# hotspot_dict:  {'latitude': -37.0411, 'longitude': 142.996, 'confidence': 77.0, 'surface_temperature_celcius': 51.0, 'producer': 'Producer_3', 'created_time': '11:22:00'}
# hotspot_dict:  {'latitude': -36.941, 'longitude': 143.268, 'confidence': 80.0, 'surface_temperature_celcius': 37.0, 'producer': 'Producer_2', 'created_time': '11:24:00'}
# hotspot_dict:  {'latitude': -37.0908, 'longitude': 143.906, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_2', 'created_time': '11:25:00'}
# hotspot_dict:  {'latitude': -37.336, 'longitude': 148.073, 'confidence': 82.0, 'surface_temperature_celcius': 38.0, 'producer': 'Producer_3', 'created_time': '11:24:00'}
# hotspot_dict:  {'latitude': -37.4229, 'longitude': 147.027, 'confidence': 100.0, 'surface_temperature_celcius': 99.0, 'producer': 'Producer_2', 'created_time': '11:27:00'}
# hotspot_dict:  {'latitude': -36.3636, 'longitude': 141.6612, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_2', 'created_time': '11:28:00'}
# hotspot_dict:  {'latitude': -36.2961, 'longitude': 144.861, 'confidence': 57.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '11:27:00'}
# {'latitude': -37.8276, 'longitude': 142.7573, 'air_temperature_celcius': 9, 'relative_humidity': 42.1, 'windspeed_knots': 7.6, 'max_wind_speed': 12.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 82, 'producer': 'Producer_1', 'date': '2024-03-13', 'hotspot': [{'latitude': -36.767, 'longitude': 142.6811, 'confidence': 55.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '11:19:00', 'avg_conf': 55.0}, {'latitude': -37.0411, 'longitude': 142.996, 'confidence': 77.0, 'surface_temperature_celcius': 51.0, 'producer': 'Producer_3', 'created_time': '11:22:00', 'avg_conf': 77.0}, {'latitude': -36.941, 'longitude': 143.268, 'confidence': 80.0, 'surface_temperature_celcius': 37.0, 'producer': 'Producer_2', 'created_time': '11:24:00', 'avg_conf': 80.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.002, 'longitude': 148.2055, 'confidence': 51.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '11:31:00'}
# hotspot_dict:  {'latitude': -36.0667, 'longitude': 146.0308, 'confidence': 85.0, 'surface_temperature_celcius': 59.0, 'producer': 'Producer_3', 'created_time': '11:30:00'}
# hotspot_dict:  {'latitude': -36.8616, 'longitude': 142.8025, 'confidence': 90.0, 'surface_temperature_celcius': 78.0, 'producer': 'Producer_2', 'created_time': '11:33:00'}
# hotspot_dict:  {'latitude': -36.3168, 'longitude': 141.1422, 'confidence': 66.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_3', 'created_time': '11:32:00'}
# hotspot_dict:  {'latitude': -37.7269, 'longitude': 143.0087, 'confidence': 100.0, 'surface_temperature_celcius': 114.0, 'producer': 'Producer_2', 'created_time': '11:34:00'}
# hotspot_dict:  {'latitude': -36.2635, 'longitude': 141.1145, 'confidence': 58.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_3', 'created_time': '11:34:00'}
# hotspot_dict:  {'latitude': -35.0706, 'longitude': 141.4435, 'confidence': 95.0, 'surface_temperature_celcius': 75.0, 'producer': 'Producer_2', 'created_time': '11:37:00'}
# hotspot_dict:  {'latitude': -36.1506, 'longitude': 143.5671, 'confidence': 100.0, 'surface_temperature_celcius': 95.0, 'producer': 'Producer_3', 'created_time': '11:36:00'}
# {'latitude': -37.287, 'longitude': 144.392, 'air_temperature_celcius': 12, 'relative_humidity': 48.2, 'windspeed_knots': 7.3, 'max_wind_speed': 11.1, 'precipitation': ' 0.03G', 'GHI_w/m2': 104, 'producer': 'Producer_1', 'date': '2024-03-14', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.3415, 'longitude': 141.5733, 'confidence': 88.0, 'surface_temperature_celcius': 64.0, 'producer': 'Producer_2', 'created_time': '11:40:00'}
# hotspot_dict:  {'latitude': -37.332, 'longitude': 148.091, 'confidence': 100.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_3', 'created_time': '11:39:00'}
# hotspot_dict:  {'latitude': -36.8202, 'longitude': 141.802, 'confidence': 80.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_3', 'created_time': '11:40:00'}
# hotspot_dict:  {'latitude': -37.1262, 'longitude': 141.7213, 'confidence': 88.0, 'surface_temperature_celcius': 63.0, 'producer': 'Producer_2', 'created_time': '11:42:00'}
# hotspot_dict:  {'latitude': -37.6387, 'longitude': 142.9032, 'confidence': 87.0, 'surface_temperature_celcius': 88.0, 'producer': 'Producer_3', 'created_time': '11:42:00'}
# hotspot_dict:  {'latitude': -36.0318, 'longitude': 145.7492, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '11:44:00'}
# hotspot_dict:  {'latitude': -35.1175, 'longitude': 141.1396, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_3', 'created_time': '11:43:00'}
# hotspot_dict:  {'latitude': -36.0959, 'longitude': 145.6233, 'confidence': 50.0, 'surface_temperature_celcius': 38.0, 'producer': 'Producer_2', 'created_time': '11:46:00'}
# hotspot_dict:  {'latitude': -36.4811, 'longitude': 142.2606, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_3', 'created_time': '11:46:00'}
# hotspot_dict:  {'latitude': -38.1356, 'longitude': 143.7098, 'confidence': 72.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_2', 'created_time': '11:48:00'}
# hotspot_dict:  {'latitude': -34.9843, 'longitude': 141.8736, 'confidence': 53.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_3', 'created_time': '11:47:00'}
# {'latitude': -36.0005, 'longitude': 143.1847, 'air_temperature_celcius': 17, 'relative_humidity': 52.5, 'windspeed_knots': 7.7, 'max_wind_speed': 16.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 143, 'producer': 'Producer_1', 'date': '2024-03-15', 'hotspot': [{'latitude': -36.4811, 'longitude': 142.2606, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_3', 'created_time': '11:46:00', 'avg_conf': 77.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.1749, 'longitude': 143.9573, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '11:51:00'}
# hotspot_dict:  {'latitude': -36.3269, 'longitude': 144.0871, 'confidence': 67.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_3', 'created_time': '11:50:00'}
# hotspot_dict:  {'latitude': -37.5436, 'longitude': 143.6122, 'confidence': 80.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_2', 'created_time': '11:54:00'}
# hotspot_dict:  {'latitude': -37.639, 'longitude': 142.0648, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_3', 'created_time': '11:53:00'}
# hotspot_dict:  {'latitude': -37.4465, 'longitude': 143.5163, 'confidence': 70.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_3', 'created_time': '11:55:00'}
# hotspot_dict:  {'latitude': -37.7856, 'longitude': 143.4095, 'confidence': 67.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_2', 'created_time': '11:57:00'}
# hotspot_dict:  {'latitude': -37.5632, 'longitude': 142.2864, 'confidence': 69.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_3', 'created_time': '11:56:00'}
# hotspot_dict:  {'latitude': -36.9034, 'longitude': 141.0013, 'confidence': 100.0, 'surface_temperature_celcius': 95.0, 'producer': 'Producer_3', 'created_time': '11:57:00'}
# {'latitude': -37.6745, 'longitude': 142.9848, 'air_temperature_celcius': 15, 'relative_humidity': 44.5, 'windspeed_knots': 10.2, 'max_wind_speed': 14.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 134, 'producer': 'Producer_1', 'date': '2024-03-16', 'hotspot': [{'latitude': -37.639, 'longitude': 142.0648, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_3', 'created_time': '11:53:00', 'avg_conf': 79.0}, {'latitude': -37.7856, 'longitude': 143.4095, 'confidence': 67.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_2', 'created_time': '11:57:00', 'avg_conf': 67.0}, {'latitude': -37.5632, 'longitude': 142.2864, 'confidence': 69.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_3', 'created_time': '11:56:00', 'avg_conf': 69.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.1559, 'longitude': 141.8102, 'confidence': 80.0, 'surface_temperature_celcius': 66.0, 'producer': 'Producer_2', 'created_time': '11:59:00'}
# hotspot_dict:  {'latitude': -35.4603, 'longitude': 143.5411, 'confidence': 86.0, 'surface_temperature_celcius': 60.0, 'producer': 'Producer_3', 'created_time': '12:00:00'}
# hotspot_dict:  {'latitude': -37.7376, 'longitude': 142.6328, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_2', 'created_time': '12:02:00'}
# hotspot_dict:  {'latitude': -36.589, 'longitude': 143.1818, 'confidence': 76.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_2', 'created_time': '12:03:00'}
# hotspot_dict:  {'latitude': -36.6914, 'longitude': 140.9792, 'confidence': 81.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_3', 'created_time': '12:03:00'}
# hotspot_dict:  {'latitude': -36.357, 'longitude': 141.2363, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_2', 'created_time': '12:05:00'}
# hotspot_dict:  {'latitude': -36.7321, 'longitude': 143.1978, 'confidence': 54.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '12:04:00'}
# hotspot_dict:  {'latitude': -36.2756, 'longitude': 145.811, 'confidence': 50.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '12:05:00'}
# hotspot_dict:  {'latitude': -36.3334, 'longitude': 141.1515, 'confidence': 60.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '12:07:00'}
# hotspot_dict:  {'latitude': -36.4622, 'longitude': 142.4773, 'confidence': 83.0, 'surface_temperature_celcius': 57.0, 'producer': 'Producer_3', 'created_time': '12:06:00'}
# {'latitude': -35.6374, 'longitude': 142.3787, 'air_temperature_celcius': 14, 'relative_humidity': 41.6, 'windspeed_knots': 13.1, 'max_wind_speed': 18.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 128, 'producer': 'Producer_1', 'date': '2024-03-17', 'hotspot': [{'latitude': -36.4622, 'longitude': 142.4773, 'confidence': 83.0, 'surface_temperature_celcius': 57.0, 'producer': 'Producer_3', 'created_time': '12:06:00', 'avg_conf': 83.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.5954, 'longitude': 143.0895, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '12:08:00'}
# hotspot_dict:  {'latitude': -36.7651, 'longitude': 143.5801, 'confidence': 91.0, 'surface_temperature_celcius': 68.0, 'producer': 'Producer_2', 'created_time': '12:10:00'}
# hotspot_dict:  {'latitude': -36.7348, 'longitude': 141.8343, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_3', 'created_time': '12:10:00'}
# hotspot_dict:  {'latitude': -37.856, 'longitude': 143.416, 'confidence': 75.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '12:12:00'}
# hotspot_dict:  {'latitude': -38.116, 'longitude': 143.818, 'confidence': 76.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_3', 'created_time': '12:11:00'}
# hotspot_dict:  {'latitude': -37.4611, 'longitude': 144.9371, 'confidence': 91.0, 'surface_temperature_celcius': 69.0, 'producer': 'Producer_3', 'created_time': '12:13:00'}
# hotspot_dict:  {'latitude': -36.8299, 'longitude': 142.2781, 'confidence': 82.0, 'surface_temperature_celcius': 56.0, 'producer': 'Producer_2', 'created_time': '12:15:00'}
# hotspot_dict:  {'latitude': -37.976, 'longitude': 145.649, 'confidence': 88.0, 'surface_temperature_celcius': 64.0, 'producer': 'Producer_3', 'created_time': '12:15:00'}
# hotspot_dict:  {'latitude': -37.602, 'longitude': 149.311, 'confidence': 81.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_2', 'created_time': '12:18:00'}
# {'latitude': -36.404, 'longitude': 142.5467, 'air_temperature_celcius': 25, 'relative_humidity': 60.9, 'windspeed_knots': 6.3, 'max_wind_speed': 8.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 195, 'producer': 'Producer_1', 'date': '2024-03-18', 'hotspot': [], 'fire_cause': 'natural'}
# hotspot_dict:  {'latitude': -36.6667, 'longitude': 143.7526, 'confidence': 71.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_3', 'created_time': '12:18:00'}
# hotspot_dict:  {'latitude': -36.9285, 'longitude': 143.9622, 'confidence': 66.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_2', 'created_time': '12:21:00'}
# hotspot_dict:  {'latitude': -37.9742, 'longitude': 141.1855, 'confidence': 78.0, 'surface_temperature_celcius': 51.0, 'producer': 'Producer_3', 'created_time': '12:21:00'}
# hotspot_dict:  {'latitude': -37.0961, 'longitude': 143.8138, 'confidence': 80.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_2', 'created_time': '12:24:00'}
# hotspot_dict:  {'latitude': -37.522, 'longitude': 143.4742, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '12:23:00'}
# hotspot_dict:  {'latitude': -36.3674, 'longitude': 143.7295, 'confidence': 78.0, 'surface_temperature_celcius': 51.0, 'producer': 'Producer_2', 'created_time': '12:26:00'}
# hotspot_dict:  {'latitude': -37.477, 'longitude': 143.352, 'confidence': 100.0, 'surface_temperature_celcius': 93.0, 'producer': 'Producer_3', 'created_time': '12:25:00'}
# hotspot_dict:  {'latitude': -36.7667, 'longitude': 141.1177, 'confidence': 68.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '12:27:00'}
# hotspot_dict:  {'latitude': -37.8774, 'longitude': 142.5932, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_2', 'created_time': '12:28:00'}
# {'latitude': -34.289, 'longitude': 141.712, 'air_temperature_celcius': 32, 'relative_humidity': 54.1, 'windspeed_knots': 12.8, 'max_wind_speed': 19.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 265, 'producer': 'Producer_1', 'date': '2024-03-19', 'hotspot': [], 'fire_cause': 'natural'}
# hotspot_dict:  {'latitude': -36.1141, 'longitude': 141.6787, 'confidence': 72.0, 'surface_temperature_celcius': 37.0, 'producer': 'Producer_2', 'created_time': '12:29:00'}
# hotspot_dict:  {'latitude': -37.5816, 'longitude': 148.5862, 'confidence': 84.0, 'surface_temperature_celcius': 65.0, 'producer': 'Producer_3', 'created_time': '12:28:00'}
# hotspot_dict:  {'latitude': -36.1031, 'longitude': 143.0782, 'confidence': 63.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_2', 'created_time': '12:32:00'}
# hotspot_dict:  {'latitude': -36.228, 'longitude': 144.6721, 'confidence': 56.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '12:31:00'}
# hotspot_dict:  {'latitude': -36.6707, 'longitude': 143.8452, 'confidence': 78.0, 'surface_temperature_celcius': 51.0, 'producer': 'Producer_2', 'created_time': '12:33:00'}
# hotspot_dict:  {'latitude': -37.228, 'longitude': 142.146, 'confidence': 76.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '12:32:00'}
# hotspot_dict:  {'latitude': -38.211, 'longitude': 143.9122, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_2', 'created_time': '12:34:00'}
# hotspot_dict:  {'latitude': -37.6714, 'longitude': 144.2154, 'confidence': 67.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '12:33:00'}
# hotspot_dict:  {'latitude': -36.228, 'longitude': 144.6721, 'confidence': 56.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '12:37:00'}
# hotspot_dict:  {'latitude': -37.9373, 'longitude': 146.0744, 'confidence': 56.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_3', 'created_time': '12:36:00'}
# hotspot_dict:  {'latitude': -37.9199, 'longitude': 145.8475, 'confidence': 76.0, 'surface_temperature_celcius': 49.0, 'producer': 'Producer_2', 'created_time': '12:38:00'}
# {'latitude': -36.1002, 'longitude': 142.3405, 'air_temperature_celcius': 23, 'relative_humidity': 49.6, 'windspeed_knots': 6.3, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 198, 'producer': 'Producer_1', 'date': '2024-03-20', 'hotspot': [{'latitude': -36.1031, 'longitude': 143.0782, 'confidence': 63.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_2', 'created_time': '12:32:00', 'avg_conf': 63.0}], 'fire_cause': 'natural'}
# hotspot_dict:  {'latitude': -37.9071, 'longitude': 143.538, 'confidence': 100.0, 'surface_temperature_celcius': 88.0, 'producer': 'Producer_2', 'created_time': '12:39:00'}
# hotspot_dict:  {'latitude': -37.38, 'longitude': 148.053, 'confidence': 80.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '12:38:00'}
# hotspot_dict:  {'latitude': -36.9405, 'longitude': 142.8627, 'confidence': 68.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '12:40:00'}
# ...
# hotspot_dict:  {'latitude': -34.8368, 'longitude': 141.5197, 'confidence': 83.0, 'surface_temperature_celcius': 56.0, 'producer': 'Producer_3', 'created_time': '05:54:00'}
# hotspot_dict:  {'latitude': -34.5442, 'longitude': 141.7211, 'confidence': 62.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '05:57:00'}
# hotspot_dict:  {'latitude': -38.5533, 'longitude': 143.4927, 'confidence': 74.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_2', 'created_time': '05:58:00'}
# hotspot_dict:  {'latitude': -36.8702, 'longitude': 144.0381, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_3', 'created_time': '05:57:00'}
# hotspot_dict:  {'latitude': -37.9009, 'longitude': 143.6217, 'confidence': 62.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_3', 'created_time': '05:58:00'}
# hotspot_dict:  {'latitude': -37.3902, 'longitude': 148.2955, 'confidence': 100.0, 'surface_temperature_celcius': 98.0, 'producer': 'Producer_3', 'created_time': '05:59:00'}
# hotspot_dict:  {'latitude': -36.3909, 'longitude': 141.1843, 'confidence': 54.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '06:01:00'}
# hotspot_dict:  {'latitude': -36.1418, 'longitude': 144.0261, 'confidence': 95.0, 'surface_temperature_celcius': 76.0, 'producer': 'Producer_3', 'created_time': '06:00:00'}
# {'latitude': -36.293, 'longitude': 146.148, 'air_temperature_celcius': 16, 'relative_humidity': 50.8, 'windspeed_knots': 5.8, 'max_wind_speed': 12.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 136, 'producer': 'Producer_1', 'date': '2024-07-03', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.0753, 'longitude': 141.0532, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '06:02:00'}
# hotspot_dict:  {'latitude': -37.6198, 'longitude': 143.0357, 'confidence': 52.0, 'surface_temperature_celcius': 38.0, 'producer': 'Producer_2', 'created_time': '06:04:00'}
# hotspot_dict:  {'latitude': -36.798, 'longitude': 142.4482, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_3', 'created_time': '06:03:00'}
# hotspot_dict:  {'latitude': -37.6629, 'longitude': 143.1587, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'producer': 'Producer_3', 'created_time': '06:04:00'}
# hotspot_dict:  {'latitude': -37.4506, 'longitude': 143.102, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '06:07:00'}
# hotspot_dict:  {'latitude': -36.6669, 'longitude': 142.8645, 'confidence': 100.0, 'surface_temperature_celcius': 110.0, 'producer': 'Producer_3', 'created_time': '06:06:00'}
# hotspot_dict:  {'latitude': -37.5701, 'longitude': 142.6497, 'confidence': 100.0, 'surface_temperature_celcius': 94.0, 'producer': 'Producer_2', 'created_time': '06:08:00'}
# hotspot_dict:  {'latitude': -36.2115, 'longitude': 141.6878, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_3', 'created_time': '06:08:00'}
# hotspot_dict:  {'latitude': -37.0682, 'longitude': 145.3607, 'confidence': 81.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_2', 'created_time': '06:10:00'}
# hotspot_dict:  {'latitude': -37.3802, 'longitude': 145.9147, 'confidence': 100.0, 'surface_temperature_celcius': 103.0, 'producer': 'Producer_3', 'created_time': '06:09:00'}
# {'latitude': -36.098, 'longitude': 143.735, 'air_temperature_celcius': 17, 'relative_humidity': 58.1, 'windspeed_knots': 11.7, 'max_wind_speed': 19.0, 'precipitation': ' 0.04G', 'GHI_w/m2': 136, 'producer': 'Producer_1', 'date': '2024-07-04', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.0844, 'longitude': 141.4934, 'confidence': 81.0, 'surface_temperature_celcius': 71.0, 'producer': 'Producer_3', 'created_time': '06:11:00'}
# hotspot_dict:  {'latitude': -36.888, 'longitude': 142.2484, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '06:13:00'}
# hotspot_dict:  {'latitude': -36.36, 'longitude': 145.9097, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_3', 'created_time': '06:12:00'}
# hotspot_dict:  {'latitude': -35.7859, 'longitude': 143.4824, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'producer': 'Producer_3', 'created_time': '06:13:00'}
# hotspot_dict:  {'latitude': -37.7637, 'longitude': 143.4072, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '06:16:00'}
# hotspot_dict:  {'latitude': -36.1925, 'longitude': 145.93, 'confidence': 97.0, 'surface_temperature_celcius': 79.0, 'producer': 'Producer_3', 'created_time': '06:16:00'}
# hotspot_dict:  {'latitude': -36.6995, 'longitude': 142.978, 'confidence': 95.0, 'surface_temperature_celcius': 76.0, 'producer': 'Producer_3', 'created_time': '06:17:00'}
# hotspot_dict:  {'latitude': -36.2669, 'longitude': 143.1906, 'confidence': 61.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_2', 'created_time': '06:19:00'}
# hotspot_dict:  {'latitude': -36.6188, 'longitude': 144.0402, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_3', 'created_time': '06:19:00'}
# hotspot_dict:  {'latitude': -37.9408, 'longitude': 146.0611, 'confidence': 58.0, 'surface_temperature_celcius': 47.0, 'producer': 'Producer_2', 'created_time': '06:21:00'}
# {'latitude': -37.434, 'longitude': 148.091, 'air_temperature_celcius': 9, 'relative_humidity': 40.0, 'windspeed_knots': 8.6, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 84, 'producer': 'Producer_1', 'date': '2024-07-05', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.4543, 'longitude': 142.9843, 'confidence': 86.0, 'surface_temperature_celcius': 61.0, 'producer': 'Producer_2', 'created_time': '06:23:00'}
# hotspot_dict:  {'latitude': -37.7011, 'longitude': 143.0393, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_3', 'created_time': '06:22:00'}
# hotspot_dict:  {'latitude': -36.0933, 'longitude': 141.7154, 'confidence': 63.0, 'surface_temperature_celcius': 35.0, 'producer': 'Producer_3', 'created_time': '06:23:00'}
# hotspot_dict:  {'latitude': -37.6659, 'longitude': 143.186, 'confidence': 61.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_2', 'created_time': '06:25:00'}
# hotspot_dict:  {'latitude': -36.942, 'longitude': 143.282, 'confidence': 63.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '06:26:00'}
# hotspot_dict:  {'latitude': -36.7315, 'longitude': 143.9232, 'confidence': 67.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '06:28:00'}
# hotspot_dict:  {'latitude': -36.4317, 'longitude': 143.0967, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '06:27:00'}
# hotspot_dict:  {'latitude': -36.1615, 'longitude': 141.8728, 'confidence': 90.0, 'surface_temperature_celcius': 66.0, 'producer': 'Producer_2', 'created_time': '06:30:00'}
# hotspot_dict:  {'latitude': -36.4528, 'longitude': 141.0038, 'confidence': 82.0, 'surface_temperature_celcius': 55.0, 'producer': 'Producer_3', 'created_time': '06:29:00'}
# hotspot_dict:  {'latitude': -35.7108, 'longitude': 143.7836, 'confidence': 86.0, 'surface_temperature_celcius': 60.0, 'producer': 'Producer_2', 'created_time': '06:31:00'}
# {'latitude': -37.605, 'longitude': 149.302, 'air_temperature_celcius': 18, 'relative_humidity': 54.4, 'windspeed_knots': 5.7, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 149, 'producer': 'Producer_1', 'date': '2024-07-06', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.3405, 'longitude': 141.1927, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'producer': 'Producer_2', 'created_time': '06:32:00'}
# hotspot_dict:  {'latitude': -36.438, 'longitude': 145.5865, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_3', 'created_time': '06:32:00'}
# hotspot_dict:  {'latitude': -35.9438, 'longitude': 145.0824, 'confidence': 78.0, 'surface_temperature_celcius': 52.0, 'producer': 'Producer_2', 'created_time': '06:34:00'}
# hotspot_dict:  {'latitude': -38.2583, 'longitude': 143.9717, 'confidence': 62.0, 'surface_temperature_celcius': 41.0, 'producer': 'Producer_3', 'created_time': '06:34:00'}
# hotspot_dict:  {'latitude': -38.0148, 'longitude': 146.5413, 'confidence': 87.0, 'surface_temperature_celcius': 71.0, 'producer': 'Producer_2', 'created_time': '06:36:00'}
# hotspot_dict:  {'latitude': -36.6942, 'longitude': 143.8021, 'confidence': 93.0, 'surface_temperature_celcius': 72.0, 'producer': 'Producer_3', 'created_time': '06:37:00'}
# hotspot_dict:  {'latitude': -36.284, 'longitude': 146.145, 'confidence': 100.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_2', 'created_time': '06:39:00'}
# hotspot_dict:  {'latitude': -37.3165, 'longitude': 147.4932, 'confidence': 93.0, 'surface_temperature_celcius': 72.0, 'producer': 'Producer_3', 'created_time': '06:38:00'}
# hotspot_dict:  {'latitude': -37.2166, 'longitude': 143.8674, 'confidence': 50.0, 'surface_temperature_celcius': 38.0, 'producer': 'Producer_2', 'created_time': '06:40:00'}
# hotspot_dict:  {'latitude': -37.5867, 'longitude': 143.6256, 'confidence': 99.0, 'surface_temperature_celcius': 85.0, 'producer': 'Producer_3', 'created_time': '06:39:00'}
# hotspot_dict:  {'latitude': -37.7885, 'longitude': 142.9509, 'confidence': 66.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_2', 'created_time': '06:41:00'}
# {'latitude': -37.926, 'longitude': 144.0898, 'air_temperature_celcius': 15, 'relative_humidity': 51.0, 'windspeed_knots': 9.0, 'max_wind_speed': 13.0, 'precipitation': ' 1.26G', 'GHI_w/m2': 128, 'producer': 'Producer_1', 'date': '2024-07-07', 'hotspot': [{'latitude': -36.6942, 'longitude': 143.8021, 'confidence': 93.0, 'surface_temperature_celcius': 72.0, 'producer': 'Producer_3', 'created_time': '06:37:00', 'avg_conf': 93.0}, {'latitude': -37.2166, 'longitude': 143.8674, 'confidence': 50.0, 'surface_temperature_celcius': 38.0, 'producer': 'Producer_2', 'created_time': '06:40:00', 'avg_conf': 50.0}, {'latitude': -37.5867, 'longitude': 143.6256, 'confidence': 99.0, 'surface_temperature_celcius': 85.0, 'producer': 'Producer_3', 'created_time': '06:39:00', 'avg_conf': 99.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.7609, 'longitude': 143.1633, 'confidence': 94.0, 'surface_temperature_celcius': 74.0, 'producer': 'Producer_2', 'created_time': '06:43:00'}
# hotspot_dict:  {'latitude': -36.8681, 'longitude': 143.5186, 'confidence': 95.0, 'surface_temperature_celcius': 76.0, 'producer': 'Producer_3', 'created_time': '06:42:00'}
# hotspot_dict:  {'latitude': -38.0652, 'longitude': 142.9781, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'producer': 'Producer_3', 'created_time': '06:44:00'}
# hotspot_dict:  {'latitude': -34.2568, 'longitude': 141.64, 'confidence': 51.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_2', 'created_time': '06:46:00'}
# hotspot_dict:  {'latitude': -37.6674, 'longitude': 142.2687, 'confidence': 65.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '06:46:00'}
# hotspot_dict:  {'latitude': -35.2464, 'longitude': 141.1143, 'confidence': 98.0, 'surface_temperature_celcius': 45.0, 'producer': 'Producer_2', 'created_time': '06:49:00'}
# hotspot_dict:  {'latitude': -38.0372, 'longitude': 146.0616, 'confidence': 90.0, 'surface_temperature_celcius': 67.0, 'producer': 'Producer_3', 'created_time': '06:49:00'}
# {'latitude': -36.2032, 'longitude': 145.3025, 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'windspeed_knots': 7.1, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 152, 'producer': 'Producer_1', 'date': '2024-07-08', 'hotspot': [], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -37.1815, 'longitude': 146.7777, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '06:50:00'}
# hotspot_dict:  {'latitude': -37.7929, 'longitude': 143.1197, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_2', 'created_time': '06:52:00'}
# hotspot_dict:  {'latitude': -37.247, 'longitude': 141.27, 'confidence': 94.0, 'surface_temperature_celcius': 43.0, 'producer': 'Producer_3', 'created_time': '06:52:00'}
# hotspot_dict:  {'latitude': -36.1887, 'longitude': 143.4722, 'confidence': 56.0, 'surface_temperature_celcius': 39.0, 'producer': 'Producer_2', 'created_time': '06:54:00'}
# hotspot_dict:  {'latitude': -36.4713, 'longitude': 144.4747, 'confidence': 58.0, 'surface_temperature_celcius': 40.0, 'producer': 'Producer_2', 'created_time': '06:56:00'}
# hotspot_dict:  {'latitude': -35.4625, 'longitude': 143.1486, 'confidence': 67.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_3', 'created_time': '06:55:00'}
# hotspot_dict:  {'latitude': -36.3111, 'longitude': 143.7704, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_2', 'created_time': '06:57:00'}
# hotspot_dict:  {'latitude': -37.5389, 'longitude': 143.1632, 'confidence': 57.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '06:56:00'}
# hotspot_dict:  {'latitude': -37.8343, 'longitude': 143.6581, 'confidence': 72.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '06:58:00'}
# hotspot_dict:  {'latitude': -36.3728, 'longitude': 141.3641, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_2', 'created_time': '07:00:00'}
# {'latitude': -37.805, 'longitude': 144.15, 'air_temperature_celcius': 12, 'relative_humidity': 45.0, 'windspeed_knots': 10.5, 'max_wind_speed': 16.9, 'precipitation': ' 0.16G', 'GHI_w/m2': 107, 'producer': 'Producer_1', 'date': '2024-07-09', 'hotspot': [{'latitude': -37.8343, 'longitude': 143.6581, 'confidence': 72.0, 'surface_temperature_celcius': 46.0, 'producer': 'Producer_3', 'created_time': '06:58:00', 'avg_conf': 72.0}], 'fire_cause': 'other'}
# hotspot_dict:  {'latitude': -36.6281, 'longitude': 142.4349, 'confidence': 64.0, 'surface_temperature_celcius': 68.0, 'producer': 'Producer_3', 'created_time': '07:00:00'}
# hotspot_dict:  {'latitude': -35.0722, 'longitude': 141.4325, 'confidence': 76.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_2', 'created_time': '07:02:00'}
# hotspot_dict:  {'latitude': -36.1552, 'longitude': 141.7256, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'producer': 'Producer_3', 'created_time': '07:02:00'}
# hotspot_dict:  {'latitude': -36.275, 'longitude': 146.154, 'confidence': 86.0, 'surface_temperature_celcius': 60.0, 'producer': 'Producer_2', 'created_time': '07:04:00'}
# hotspot_dict:  {'latitude': -37.365, 'longitude': 148.052, 'confidence': 90.0, 'surface_temperature_celcius': 63.0, 'producer': 'Producer_2', 'created_time': '07:06:00'}
# hotspot_dict:  {'latitude': -37.7929, 'longitude': 143.1197, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'producer': 'Producer_3', 'created_time': '07:05:00'}
# hotspot_dict:  {'latitude': -37.399, 'longitude': 148.081, 'confidence': 100.0, 'surface_temperature_celcius': 84.0, 'producer': 'Producer_2', 'created_time': '07:07:00'}
# hotspot_dict:  {'latitude': -37.0667, 'longitude': 143.0582, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'producer': 'Producer_3', 'created_time': '07:07:00'}
# hotspot_dict:  {'latitude': -37.452, 'longitude': 148.115, 'confidence': 68.0, 'surface_temperature_celcius': 77.0, 'producer': 'Producer_2', 'created_time': '07:09:00'}
# hotspot_dict:  {'latitude': -37.4984, 'longitude': 142.9739, 'confidence': 93.0, 'surface_temperature_celcius': 73.0, 'producer': 'Producer_3', 'created_time': '07:09:00'}
# {'latitude': -37.61, 'longitude': 149.296, 'air_temperature_celcius': 16, 'relative_humidity': 48.3, 'windspeed_knots': 14.4, 'max_wind_speed': 19.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 139, 'producer': 'Producer_1', 'date': '2024-07-10', 'hotspot': [], 'fire_cause': 'other'}

# %%
import geohash
from pyspark.sql.functions import from_json, col, avg
from pyspark.sql.types import StructType, StructField, DoubleType, StringType


# Define the schema for the Climate and Hotspot data payload
# for from_json to know how to parse the structure

#Schema to inform how parse the JSON object
climate_schema = StructType([   #specify the data typem True to contain null values
    StructField('latitude', StringType(), True),
    StructField('longitude', DoubleType(), True),
    StructField('air_temperature_celcius', IntegerType(), True),
    StructField('relative_humidity', DoubleType(), True),
    StructField('windspeed_knots', DoubleType(), True),
    StructField('max_wind_speed', DoubleType(), True),
    StructField('precipitation', StringType(), True),
    StructField('GHI_w/m2', IntegerType(), True),
    StructField('producer', StringType(), True),
    StructField('date', StringType(), True),
    StructField('created_time', IntegerType(), True)
])

hotspot_schema = StructType([
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("confidence", DoubleType(), True),
    StructField('surface_temperature_celcius', DoubleType(), True),
    StructField("producer", StringType(), True),
    StructField("random_time", IntegerType(), True)

])

# %%
from pyspark.sql.functions import to_timestamp
# Define the geohash UDF for climate
def climate_geohash(lat, lon):
    return geohash.encode(lat, lon, precision=3)

# # Register UDFs in Spark
climate_geohash_udf = udf(climate_geohash, StringType())
spark.udf.register("climate_geohash", climate_geohash_udf)


# climate_sdf = (
#     spark.readStream
#     .format('kafka')
#     .option('kafka.bootstrap.servers', f'{host_ip}:9092')
#     .option('subscribe', topic)
#     .load() #value store the actual dataframe
#     .select('value')
#      #do processing after .load() to get into the dataframe and deal with row
# #     .withColumn('geohash', climate_geohash_udf(col('latitude'), col('longtitude')))
# #     .limit(1)  # Retains only the first row
    
# )

# Deserialize the JSON payload from the 'value' column
climate_sdf = (
    spark.readStream
    .format('kafka')
    .option('kafka.bootstrap.servers', f'{host_ip}:9092')
    .option('subscribe', topic)
    .load()  #load the JSON object to be in Dataframe, use climate_sdf.printSchema()  to see it
    #deserialize the binary ‘value’ column into a format that allows you to access the ‘latitude’ and ‘longitude’ fields
    .select(from_json(col("value").cast("string"), climate_schema).alias("data"))
    #from_json: parse a JSON string and convert into a DataDrame of complex type StructType or MapType
    #col("value").cast("string"): akes the ‘value’ column, which is in binary format, and 
    #casts it to a string type. This is necessary because from_json expects a JSON string as input.
    #climate_schema: schema that defined which from_json will use to parse the JSON string. 
    #should match the structure of the JSON data you’re working with.
    #.alias("data"): This renames the resulting column from the from_json function to ‘data’.
    .select("data.*")  
    #After JSON string parsed into a structured format
    #select statement used to select all fields from the 'data' column since renamed
    #.select("data.*") select 
    .withColumn('geohash', climate_geohash_udf(col('latitude'), col('longitude')))
    .withColumn('created_time', to_timestamp(col('created_time')))
    .limit(1)  # Retains only the first row
)

#print the schema
climate_sdf.printSchema()
# Out:
# root
#  |-- latitude: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- air_temperature_celcius: integer (nullable = true)
#  |-- relative_humidity: double (nullable = true)
#  |-- windspeed_knots: double (nullable = true)
#  |-- max_wind_speed: double (nullable = true)
#  |-- precipitation: string (nullable = true)
#  |-- GHI_w/m2: integer (nullable = true)
#  |-- producer: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- created_time: timestamp (nullable = true)
#  |-- geohash: string (nullable = true)

# %%
#all producers send to the same topic to make Kafka to join the stream
hotspot_sdf = (
    spark.readStream
    .format('kafka')
    .option('kafka.bootstrap.servers', f'{host_ip}:9092')
    .option('subscribe', topic_hotspot)
    .load()
)

hotspot_sdf = (
    spark.readStream
    .format('kafka')
    .option('kafka.bootstrap.servers', f'{host_ip}:9092')
    .option('subscribe', topic)
    .load()  
    .select(from_json(col("value").cast("string"), hotspot_schema).alias("data"))
    .select("data.*")
)

hotspot_sdf.printSchema()
# Out:
# root
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- confidence: double (nullable = true)
#  |-- surface_temperature_celcius: double (nullable = true)
#  |-- producer: string (nullable = true)
#  |-- random_time: integer (nullable = true)

# %%
from pyspark.sql.functions import first
# Define the geohash UDF for hotspot
def hotspot_geohash(lat, lon):
    return geohash.encode(lat, lon, precision=5)

# Register the UDF for pyspark to group
hotspot_geohash_udf = udf(hotspot_geohash, StringType())
spark.udf.register("hotspot_geohash", hotspot_geohash_udf)



# climate_stream = climate_stream.withColumn('geohash', climate_geohash_udf(col('latitude'), col('longtitude')))
hotspots_merge_sdf = (
    hotspot_sdf
    .withColumn('geohash', hotspot_geohash_udf(col('latitude'), col('longitude')))
    #drop the rows with the same geohash at this time window
    .dropDuplicates(['geohash'])
    #laod data from source in dataframe format
)

# Update the result after dropDuplicates to update geohash to new value
hotspots_merge_sdf = (
    hotspot_sdf
    .withColumn('geohash', hotspot_geohash_udf(col('latitude'), col('longitude')))
    .dropDuplicates(['geohash'])
    # Load data from source in DataFrame format
    # Assuming load() is a method that loads the DataFrame, replace it with the actual method if different
    # after dropDuplicates base on geohash, replace with lower precision geohash value
    # for climat
    .withColumn('geohash', climate_geohash_udf(col('latitude'), col('longitude')))
    
)

# Alias the DataFrames before joining
climate_sdf_alias = climate_sdf.alias("climate")
hotspots_merge_sdf_alias = hotspots_merge_sdf.alias("hotspot")

# Perform the join using the aliased DataFrames
joined_df = climate_sdf_alias.join(hotspots_merge_sdf_alias, ["geohash"], how='left_outer')

# Select columns using the alias  #select all columns 
joined_df = joined_df.select("climate.*", "hotspot.*")

# Apply a watermark to the joined DataFrame using the correct timestamp column
# Replace 'created_time' with the actual timestamp column name from your data
joined_df = joined_df.withWatermark("climate.created_time", "10 seconds")

# Perform aggregation
averaged_df = joined_df.groupBy('climate.geohash').agg(
    avg(col('hotspot.surface_temperature_celcius')).alias('surface_temperature_celcius'),
    avg(col('hotspot.confidence')).alias('confidence'),
    first(col('climate.air_temperature_celcius')).alias('air_temperature_celcius'),
    first(col('climate.relative_humidity')).alias('relative_humidity'),
    first(col('climate.windspeed_knots')).alias('windspeed_knots'),
    first(col('climate.max_wind_speed')).alias('max_wind_speed'),
    first(col('climate.precipitation')).alias('precipitation'),
    first(col('climate.GHI_w/m2')).alias('GHI_w/m2'),
    first(col('hotspot.producer')).alias('producer'),
    first(col('climate.date')).alias('date'),
    first(col('climate.latitude')).alias('latitude'),
    first(col('climate.longitude')).alias('longitude'),
    first(col('climate.created_time')).alias('created_time')
)

averaged_df.printSchema()
# ## Each stream is a DStream of (key, value) pairs where 'key' could be a location 
# # Only include rows that have matching geohashes in both streams
# # inner join since it is important that it has fire

# #must join since from two different streams
# joined_df = climate_sdf.join(hotspots_merge_sdf, on=['geohash'], how='left_outer') 

# # Select the disambiguated 'created_time' column from one of the DataFrames
# # Assuming 'created_time' comes from the 'climate' DataFrame
# joined_df = joined_df.select("climate_sdf.*", "hotspots_merge_sdf.geohash")
# # Apply a watermark to the joined DataFrame
# joined_df = joined_df.withWatermark("created_time", "10 seconds")

# # Perform aggregation
# averaged_df = joined_df.groupBy('geohash').agg(avg(col('surface_temperature_celcius')),avg(col('confidence')))
# Out:
# root
#  |-- geohash: string (nullable = true)
#  |-- surface_temperature_celcius: double (nullable = true)
#  |-- confidence: double (nullable = true)
#  |-- air_temperature_celcius: integer (nullable = true)
#  |-- relative_humidity: double (nullable = true)
#  |-- windspeed_knots: double (nullable = true)
#  |-- max_wind_speed: double (nullable = true)
#  |-- precipitation: string (nullable = true)
#  |-- GHI_w/m2: integer (nullable = true)
#  |-- producer: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- created_time: timestamp (nullable = true)

# %%
# for debugging, print on console
class DbWriter:
    
    # called at the start of processing each partition in each output micro-batch
    def open(self, partition_id, epoch_id):
        self.mongo_client = MongoClient(
            host=f'{host_ip}',
            port=27017
        )
        #use the same database, name: fit3182_db
        self.db = self.mongo_client['fit3182_db']
        return True
    
    #what ever row it receive at the time just process
    def process(self, row):
                #road of data from JSON string to 
        data = json.loads(row.value)
        
        record = {}
        #climate
        record['air_temperature_celcius'] = data.get('air_temperature_celcius')
        record['relative_humidity'] = data.get('relative_humidity')
        record['windspeed_knots'] = data.get('windspeed_knots')
        record['max_wind_speed'] = data.get('max_wind_speed')
        record['precipitation'] = data.get('precipitation')
        record['GHI_w/m2'] = data.get('GHI_w/m2')
        record['date'] = data.get('date')
        record['latitude'] = data.get('latitude')
        record['longtitude'] = data.get('longtitude')
        
        #hotspots
        record['confidence'] = data.get('confidence')
        record['surface_temperature_celcius'] = data.get('surface_temperature_celcius')
        record['producer'] = data.get('producer')
        print(record)
        
    def close(self, err):
        return True

# %%
writer = (
    # Initializes a streaming write for the climate_sdf DataFrame.
    averaged_df.writeStream.format("console")
    # Output will be written to the standard console/output.
    .option("checkpointLocation", "./hotspot_sdf_checkpoints")
    # Specifies the location for checkpointing, which allows streaming 
    # queries to be resilient to failures by storing the state.
    .outputMode('append')  # Only new rows will be written to the output sink since the last trigger.
    .trigger(processingTime = '10 seconds')
    .foreach(DbWriter())  # Applies a foreach writer with DbWriter_climate instance.
    # This indicates that for each row in the output, the DbWriter_climate class’s process method will be called.
)

# %%
try:
    query = writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.')
finally:
    query.stop()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[116], line 2
#       1 try:
# ----> 2     query = writer.start()
#       3     query.awaitTermination()
#
# File /opt/conda/lib/python3.8/site-packages/pyspark/sql/streaming.py:1389, in DataStreamWriter.start(self, path, format, outputMode, partitionBy, queryName, **options)
#    1388 if path is None:
# -> 1389     return self._sq(self._jwrite.start())
#    1390 else:
#
# File /opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#
# File /opt/conda/lib/python3.8/site-packages/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#
# AnalysisException: Append output mode not supported when there are streaming aggregations on streaming DataFrames/DataSets without watermark;
# Aggregate [geohash#1475], [geohash#1475, avg(surface_temperature_celcius#3376) AS surface_temperature_celcius#3880, avg(confidence#3375) AS confidence#3882, first(air_temperature_celcius#1454, false) AS air_temperature_celcius#3884, first(relative_humidity#1455, false) AS relative_humidity#3886, first(windspeed_knots#1456, false) AS windspeed_knots#3888, first(max_wind_speed#1457, false) AS max_wind_speed#3890, first(precipitation#1458, false) AS precipitation#3892, first(GHI_w/m2#1459, false) AS GHI_w/m2#3894, first(producer#3377, false) AS producer#3896, first(date#1461, false) AS date#3898, first(latitude#1452, false) AS latitude#3900, first(longitude#1453, false) AS longitude#3902, first(created_time#1488-T10000ms, false) AS created_time#3904]
# +- EventTimeWatermark created_time#1488: timestamp, 10 seconds
#    +- Project [geohash#1475, latitude#1452, longitude#1453, air_temperature_celcius#1454, relative_humidity#1455, windspeed_knots#1456, max_wind_speed#1457, precipitation#1458, GHI_w/m2#1459, producer#1460, date#1461, created_time#1488, geohash#3815, latitude#3373, longitude#3374, confidence#3375, surface_temperature_celcius#3376, producer#3377, random_time#3378]
#       +- Project [geohash#3815, geohash#1475, latitude#1452, longitude#1453, air_temperature_celcius#1454, relative_humidity#1455, windspeed_knots#1456, max_wind_speed#1457, precipitation#1458, GHI_w/m2#1459, producer#1460, date#1461, created_time#1488, latitude#3373, longitude#3374, confidence#3375, surface_temperature_celcius#3376, producer#3377, random_time#3378]
#          +- Join LeftOuter, (geohash#1475 = geohash#3815)
#             :- SubqueryAlias climate
#             :  +- GlobalLimit 1
#             :     +- LocalLimit 1
#             :        +- Project [latitude#1452, longitude#1453, air_temperature_celcius#1454, relative_humidity#1455, windspeed_knots#1456, max_wind_speed#1457, precipitation#1458, GHI_w/m2#1459, producer#1460, date#1461, to_timestamp(created_time#1462, None, TimestampType, Some(Etc/UTC)) AS created_time#1488, geohash#1475]
#             :           +- Project [latitude#1452, longitude#1453, air_temperature_celcius#1454, relative_humidity#1455, windspeed_knots#1456, max_wind_speed#1457, precipitation#1458, GHI_w/m2#1459, producer#1460, date#1461, created_time#1462, climate_geohash(latitude#1452, longitude#1453)#1474 AS geohash#1475]
#             :              +- Project [data#1450.latitude AS latitude#1452, data#1450.longitude AS longitude#1453, data#1450.air_temperature_celcius AS air_temperature_celcius#1454, data#1450.relative_humidity AS relative_humidity#1455, data#1450.windspeed_knots AS windspeed_knots#1456, data#1450.max_wind_speed AS max_wind_speed#1457, data#1450.precipitation AS precipitation#1458, data#1450.GHI_w/m2 AS GHI_w/m2#1459, data#1450.producer AS producer#1460, data#1450.date AS date#1461, data#1450.created_time AS created_time#1462]
#             :                 +- Project [from_json(StructField(latitude,StringType,true), StructField(longitude,DoubleType,true), StructField(air_temperature_celcius,IntegerType,true), StructField(relative_humidity,DoubleType,true), StructField(windspeed_knots,DoubleType,true), StructField(max_wind_speed,DoubleType,true), StructField(precipitation,StringType,true), StructField(GHI_w/m2,IntegerType,true), StructField(producer,StringType,true), StructField(date,StringType,true), StructField(created_time,IntegerType,true), cast(value#1437 as string), Some(Etc/UTC)) AS data#1450]
#             :                    +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@3189691b, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@63342902, [kafka.bootstrap.servers=172.16.55.43:9092, subscribe=A2_climate_topic], [key#1436, value#1437, topic#1438, partition#1439, offset#1440L, timestamp#1441, timestampType#1442], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@4038c988,kafka,List(),None,List(),None,Map(kafka.bootstrap.servers -> 172.16.55.43:9092, subscribe -> A2_climate_topic),None), kafka, [key#1429, value#1430, topic#1431, partition#1432, offset#1433L, timestamp#1434, timestampType#1435]
#             +- SubqueryAlias hotspot
#                +- Project [latitude#3373, longitude#3374, confidence#3375, surface_temperature_celcius#3376, producer#3377, random_time#3378, climate_geohash(latitude#3373, longitude#3374)#3814 AS geohash#3815]
#                   +- Deduplicate [geohash#3806]
#                      +- Project [latitude#3373, longitude#3374, confidence#3375, surface_temperature_celcius#3376, producer#3377, random_time#3378, hotspot_geohash(latitude#3373, longitude#3374)#3805 AS geohash#3806]
#                         +- Project [data#3371.latitude AS latitude#3373, data#3371.longitude AS longitude#3374, data#3371.confidence AS confidence#3375, data#3371.surface_temperature_celcius AS surface_temperature_celcius#3376, data#3371.producer AS producer#3377, data#3371.random_time AS random_time#3378]
#                            +- Project [from_json(StructField(latitude,DoubleType,true), StructField(longitude,DoubleType,true), StructField(confidence,DoubleType,true), StructField(surface_temperature_celcius,DoubleType,true), StructField(producer,StringType,true), StructField(random_time,IntegerType,true), cast(value#3358 as string), Some(Etc/UTC)) AS data#3371]
#                               +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@5f228c81, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@33256074, [kafka.bootstrap.servers=172.16.55.43:9092, subscribe=A2_climate_topic], [key#3357, value#3358, topic#3359, partition#3360, offset#3361L, timestamp#3362, timestampType#3363], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@4038c988,kafka,List(),None,List(),None,Map(kafka.bootstrap.servers -> 172.16.55.43:9092, subscribe -> A2_climate_topic),None), kafka, [key#3350, value#3351, topic#3352, partition#3353, offset#3354L, timestamp#3355, timestampType#3356]
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 7
#       5     print('Interrupted by CTRL-C. Stopping query.')
#       6 finally:
# ----> 7     query.stop()
#
# NameError: name 'query' is not defined

# %%
class DbWriter_climate:
    """
    Check whether it works in pyspark log
    """
    # called at the start of processing each partition in each output micro-batch
    def open(self, partition_id, epoch_id):
        self.mongo_client = MongoClient(
            host=f'{host_ip}',
            port=27017
        )
        #use the same database, name: fit3182_db
        self.db = self.mongo_client['fit3182_db']
        return True
    
    
    # called once per row of the result dataframe
    # the current code DOES NOT handle duplicate processing
    #   e.g., query fails and restarts just before current micro-batch was fully inserted
    def process(self, row):
        #passing JSON string from row.value
        #into a dictionary data
        data = json.loads(row.value)
        
        db_record = {}
        db_record['air_temperature_celcius'] = data.get('air_temperature_celcius')
        db_record['relative_humidity'] = data.get('relative_humidity')
        db_record['windspeed_knots'] = data.get('windspeed_knots')
        db_record['max_wind_speed'] = data.get('max_wind_speed')
        db_record['precipitation'] = data.get('precipitation')
        db_record['GHI_w/m2'] = data.get('GHI_w/m2')
        db_record['producer'] = data.get('producer')
        db_record['date'] = data.get('date')
        #print(db_record)
        #print heren not working
                  
        #update and insert
        # New database has nothing so just insert
        # later something with the same station then update
        self.db['A2'].replace_one({'station': data.get('kerbsideid')}, db_record, upsert=True)
    
    # called once all rows have been processed (possibly with error)
    def close(self, err):
        self.mongo_client.close()

# %%
writer = (
    #initializes a streaming write for the parking_sdf DataFrame.
    climate_sdf.writeStream.format("console")
    #output will be written to the standard console/output.
    .option("checkpointLocation", "./climate_sdf_checkpoints")
    #Specifies the location for checkpointing, which allows streaming 
    #queries to be resilient to failures by storing the state.
    #.outputMode('append'): Sets the output mode to ‘append’, meaning 
    #only new rows will be written to the output sink since the last trigger.
    .outputMode('append').foreach(DbWriter_climate())
    # Applies a foreach writer, which in this case is an instance of DbWriter(). 
    #This indicates that for each row in the output, the DbWriter() class’s process 
    #method will be called
)

# %%
try:
    query = writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.')
finally:
    query.stop()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[62], line 2
#       1 try:
# ----> 2     query = writer.start()
#       3     query.awaitTermination()
#
# File /opt/conda/lib/python3.8/site-packages/pyspark/sql/streaming.py:1389, in DataStreamWriter.start(self, path, format, outputMode, partitionBy, queryName, **options)
#    1388 if path is None:
# -> 1389     return self._sq(self._jwrite.start())
#    1390 else:
#
# File /opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#
# File /opt/conda/lib/python3.8/site-packages/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#
# AnalysisException: Append output mode not supported when there are streaming aggregations on streaming DataFrames/DataSets without watermark;
# Aggregate [geohash#1363], [geohash#1363, avg(surface_temperature_celcius#1422) AS avg(surface_temperature_celcius)#1568, avg(confidence#1421) AS avg(confidence)#1569]
# +- Project [geohash#1363, latitude#1342, longitude#1343, air_temperature_celcius#1344, relative_humidity#1345, windspeed_knots#1346, max_wind_speed#1347, precipitation#1348, GHI_w/m2#1349, producer#1350, date#1351, latitude#1419, longitude#1420, confidence#1421, surface_temperature_celcius#1422, created_time#1423, created_time#1424]
#    +- Join LeftOuter, (geohash#1363 = geohash#1524)
#       :- GlobalLimit 1
#       :  +- LocalLimit 1
#       :     +- Project [latitude#1342, longitude#1343, air_temperature_celcius#1344, relative_humidity#1345, windspeed_knots#1346, max_wind_speed#1347, precipitation#1348, GHI_w/m2#1349, producer#1350, date#1351, climate_geohash(latitude#1342, longitude#1343)#1362 AS geohash#1363]
#       :        +- Project [data#1340.latitude AS latitude#1342, data#1340.longitude AS longitude#1343, data#1340.air_temperature_celcius AS air_temperature_celcius#1344, data#1340.relative_humidity AS relative_humidity#1345, data#1340.windspeed_knots AS windspeed_knots#1346, data#1340.max_wind_speed AS max_wind_speed#1347, data#1340.precipitation AS precipitation#1348, data#1340.GHI_w/m2 AS GHI_w/m2#1349, data#1340.producer AS producer#1350, data#1340.date AS date#1351]
#       :           +- Project [from_json(StructField(latitude,StringType,true), StructField(longitude,DoubleType,true), StructField(air_temperature_celcius,IntegerType,true), StructField(relative_humidity,DoubleType,true), StructField(windspeed_knots,DoubleType,true), StructField(max_wind_speed,DoubleType,true), StructField(precipitation,StringType,true), StructField(GHI_w/m2,IntegerType,true), StructField(producer,StringType,true), StructField(date,StringType,true), cast(value#1327 as string), Some(Etc/UTC)) AS data#1340]
#       :              +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@6b840a63, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@485245e5, [kafka.bootstrap.servers=172.16.55.43:9092, subscribe=A2_climate_topic], [key#1326, value#1327, topic#1328, partition#1329, offset#1330L, timestamp#1331, timestampType#1332], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@30c9a569,kafka,List(),None,List(),None,Map(kafka.bootstrap.servers -> 172.16.55.43:9092, subscribe -> A2_climate_topic),None), kafka, [key#1319, value#1320, topic#1321, partition#1322, offset#1323L, timestamp#1324, timestampType#1325]
#       +- Project [latitude#1419, longitude#1420, confidence#1421, surface_temperature_celcius#1422, created_time#1423, created_time#1424, climate_geohash(latitude#1419, longitude#1420)#1523 AS geohash#1524]
#          +- Deduplicate [geohash#1515]
#             +- Project [latitude#1419, longitude#1420, confidence#1421, surface_temperature_celcius#1422, created_time#1423, created_time#1424, hotspot_geohash(latitude#1419, longitude#1420)#1514 AS geohash#1515]
#                +- Project [data#1417.latitude AS latitude#1419, data#1417.longitude AS longitude#1420, data#1417.confidence AS confidence#1421, data#1417.surface_temperature_celcius AS surface_temperature_celcius#1422, data#1417.created_time AS created_time#1423, data#1417.created_time AS created_time#1424]
#                   +- Project [from_json(StructField(latitude,DoubleType,true), StructField(longitude,DoubleType,true), StructField(confidence,DoubleType,true), StructField(surface_temperature_celcius,DoubleType,true), StructField(created_time,StringType,true), StructField(created_time,IntegerType,true), cast(value#1404 as string), Some(Etc/UTC)) AS data#1417]
#                      +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@25aa5511, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@735e7fe0, [kafka.bootstrap.servers=172.16.55.43:9092, subscribe=A2_climate_topic], [key#1403, value#1404, topic#1405, partition#1406, offset#1407L, timestamp#1408, timestampType#1409], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@30c9a569,kafka,List(),None,List(),None,Map(kafka.bootstrap.servers -> 172.16.55.43:9092, subscribe -> A2_climate_topic),None), kafka, [key#1396, value#1397, topic#1398, partition#1399, offset#1400L, timestamp#1401, timestampType#1402]
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 7
#       5     print('Interrupted by CTRL-C. Stopping query.')
#       6 finally:
# ----> 7     query.stop()
#
# NameError: name 'query' is not defined

# %%
# from pyspark.sql.functions import from_json, col
# climate_stream = (
#     spark.readStream
#     .format('kafka')
#     .option('kafka.bootstrap.servers', f'{host_ip}:9092')
#     .option('subscribe', topic)
#     #load into dataframe for raw data from source(Kafka)
#     .load()    #parse JSON string into structured format (Dataframe) based on schema
#     .select(from_json(col('value').cast('string'), climate_schema).alias('data'))
#     .select('data.*')         
# )           #cast bytes in value column into string
#             #alias rename value column into data
#             #flatten by expandign fields of the data column into separate columns
#             #select data column since renamed
            
# hotspot_AQUA_stream = (
#     spark.readStream \
#     .format("kafka")
#     .option("kafka.bootstrap.servers", "localhost:9092") 
#     .option("subscribe", topic_AQUA)
#     .load()
#     .select(from_json(col("value").cast("string"), hotspot_schema).alias("data"))
#     .select("data.*")
# )

# hotspot_TERRA_stream = (
#     spark.readStream \
#     .format("kafka")
#     .option("kafka.bootstrap.servers", "localhost:9092") 
#     .option("subscribe", topic_TERRA)
#     .load()
#     .select(from_json(col("value").cast("string"), hotspot_schema).alias("data"))
#     .select("data.*")
# )

# %%
# import geohash
# from pyspark.sql.functions import col, udf
# from pyspark.sql.types import StringType


# # Define the geohash UDF for hotspot
# def hotspot_geohash(lat, lon):
#     return geohash.encode(lat, lon, precision=5)

# # Register the UDF
# hotspot_geohash_udf = udf(hotspot_geohash, StringType())
# spark.udf.register("hotspot_geohash", hotspot_geohash_udf)


# # Define the geohash UDF for climate
# def climate_geohash(lat, lon):
#     return geohash.encode(lat, lon, precision=3)

# # # Register UDFs in Spark
# climate_geohash_udf = udf(climate_geohash, StringType())
# spark.udf.register("climate_geohash", climate_geohash_udf)



# # Apply the geohash UDF to the DataFrame columns
# climate_stream = climate_stream.withColumn('geohash', climate_geohash_udf(col('latitude'), col('longtitude')))
# hotspot_AQUA_stream = hotspot_AQUA_stream.withColumn('geohash', hotspot_geohash_udf(col('latitude'), col('longtitude')))
# hotspot_TERRA_stream = hotspot_TERRA_stream.withColumn('geohash', hotspot_geohash_udf(col('latitude'), col('longtitude')))


# # Join the streams and drop duplicates
# joined_hotspot_stream = hotspot_AQUA_stream.join(hotspot_TERRA_stream, 'geohash').dropDuplicates(['geohash'])
# final_stream = climate_stream.join(joined_hotspot_stream, 'geohash')


# # # Assuming you have a joined DataFrame called 'joined_df1_df2'
# # for row in joined_hotspot_stream.collect():
# #     geohash = row["geohash"]
# #     temperature = row["temperature"]
# #     hotspot_count = row["hotspot_count"]
# #     # Store relevant information in the dictionary
# #     result_dict[geohash] = {"temperature": temperature, "hotspot_count": hotspot_count}
# #     print(row)
# # # Now 'result_dict' contains the processed data
# # Print the schema of the DataFrame
# climate_stream.printSchema()
# hotspot_AQUA_stream.printSchema()
# hotspot_TERRA_stream.printSchema()

# # Show the contents of the DataFrame
# climate_stream.show()
# hotspot_AQUA_stream.show()
# hotspot_TERRA_stream.show()

# # After joining the streams
# joined_hotspot_stream.printSchema()
# final_stream.printSchema()

# # Show the contents after joining
# joined_hotspot_stream.show()
# final_stream.show()
# Out:
# root
#  |-- latitude: string (nullable = true)
#  |-- longtitude: double (nullable = true)
#  |-- air_temperature_celcius: integer (nullable = true)
#  |-- relative_humidity: double (nullable = true)
#  |-- windspeed_knots: double (nullable = true)
#  |-- max_wind_speed: double (nullable = true)
#  |-- precipitation: string (nullable = true)
#  |-- GHI_w/m2: integer (nullable = true)
#  |-- producer: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- geohash: string (nullable = true)
#
# root
#  |-- latitude: double (nullable = true)
#  |-- longtitude: double (nullable = true)
#  |-- confidence: double (nullable = true)
#  |-- surface_temperature: double (nullable = true)
#  |-- created_time: string (nullable = true)
#  |-- created_time: integer (nullable = true)
#  |-- geohash: string (nullable = true)
#
# root
#  |-- latitude: double (nullable = true)
#  |-- longtitude: double (nullable = true)
#  |-- confidence: double (nullable = true)
#  |-- surface_temperature: double (nullable = true)
#  |-- created_time: string (nullable = true)
#  |-- created_time: integer (nullable = true)
#  |-- geohash: string (nullable = true)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[81], line 51
#      48 hotspot_TERRA_stream.printSchema()
#      50 # Show the contents of the DataFrame
# ---> 51 climate_stream.show()
#      52 hotspot_AQUA_stream.show()
#      53 hotspot_TERRA_stream.show()
#
# File /opt/conda/lib/python3.8/site-packages/pyspark/sql/dataframe.py:606, in DataFrame.show(self, n, truncate, vertical)
#     603     raise TypeError("Parameter 'vertical' must be a bool")
#     605 if isinstance(truncate, bool) and truncate:
# --> 606     print(self._jdf.showString(n, 20, vertical))
#     607 else:
#     608     try:
#
# File /opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /opt/conda/lib/python3.8/site-packages/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     192 converted = convert_exception(e.java_exception)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#     198     raise
#
# AnalysisException: Queries with streaming sources must be executed with writeStream.start();
# kafka
