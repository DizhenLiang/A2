# %% [markdown]
# Key Points:
#
# Embedded Documents: Use embedded documents to store related data together, which allows for efficient querying.
#
# The common attribute of these two dataset is date, if we do embedded data model, it would accelerate all the queries related with date, range of hotspot data would be limited to the range with this specific date.

# %%
import os
print(os.getcwd())
# Out:
# /home/student/A2

# %%
os.chdir("/home/student/A2/drive-download-20240507T073745Z-001")

# %%
os.listdir()
# Out:
# ['climate_historic.csv',
#  'climate_streaming.csv',
#  'hotspot_AQUA_streaming.csv',
#  'hotspot_historic.csv',
#  'hotspot_TERRA_streaming.csv']

# %%
import pandas as pd
hotspot = pd.read_csv("./hotspot_historic.csv", sep=',')
climate = pd.read_csv("./climate_historic.csv", sep=',')

# %%
hotspot.head()
# Out:
#    latitude  longitude             datetime  confidence        date  \
# 0   -37.966    145.051  2023-12-27 04:16:51          78  27/12/2023
# 1   -35.541    143.311  2023-12-27 00:02:15          82  27/12/2023
# 2   -35.554    143.307  2023-12-27 00:02:15          67  27/12/2023
# 3   -35.543    143.316  2023-12-27 00:02:14          86  27/12/2023
# 4   -37.708    145.100  2023-12-25 04:29:08          80  25/12/2023
#
#    surface_temperature_celcius
# 0                           68
# 1                           63
# 2                           53
# 3                           67
# 4                           54

# %%
climate.head()
# Out:
#    station        date  air_temperature_celcius  relative_humidity  \
# 0   948700  31/12/2022                       19               56.8
# 1   948700  02/01/2023                       15               50.7
# 2   948700  03/01/2023                       16               53.6
# 3   948700  04/01/2023                       24               61.6
# 4   948700  05/01/2023                       24               62.3
#
#    windspeed_knots  max_wind_speed precipitation  GHI_w/m2
# 0              7.9            11.1         0.00I       154
# 1              9.2            13.0         0.02G       128
# 2              8.1            15.0         0.00G       133
# 3              7.7            14.0         0.00I       186
# 4              7.0            13.0         0.00I       185

# %%
climate.tail()
# Out:
#      station        date  air_temperature_celcius  relative_humidity  \
# 361   948702  28/12/2023                       21               61.1
# 362   948702  29/12/2023                       19               59.7
# 363   948702  30/12/2023                       16               51.5
# 364   948702  31/12/2023                       18               53.6
# 365   948702  01/01/2024                       19               52.9
#
#      windspeed_knots  max_wind_speed precipitation  GHI_w/m2
# 361              6.6            11.1         0.00I       163
# 362              7.4            14.0         0.63G       150
# 363              8.7            15.0         0.02G       135
# 364              7.9            15.9         0.00G       150
# 365              8.1            15.0         0.00I       159

# %%
print(climate['date'].dtype)
# Out:
# object

# %%
import csv
from pprint import pprint

# %%
def csv_to_dict(filename):
    with open(filename, mode='r', newline='', encoding='utf-8') as csvfile:
        #DictReader read the first row as column headers
        #return an iterator that produce disctionaries for each row
        #keys: column headers
        reader = csv.DictReader(csvfile)
        #convert iterator into list of dictionaries
        #keys: columne headers, values: cell values
        return list(reader)


# Read climate data
climate_data = csv_to_dict('climate_historic.csv')

# Read hotspot data
hotspot_data = csv_to_dict('hotspot_historic.csv')

# %%
import pymongo
from pymongo import MongoClient
#Residence wifi ip address: 172.16.62.212
ipadd = "10.192.33.112"

client = MongoClient(ipadd, 27017)
db = client.fit3182_db
collection = db.fit3182_assignment_db

# %%
#avoid error from exsiting collection with the same name
#collection.drop()

# %%
# Convert the date columns to datetime objects for proper comparison
                        #convert from d/m/Y format into 
# climate['date'] = pd.to_datetime(climate['date'], format='%d/%m/%Y')
# hotspot['date'] = pd.to_datetime(hotspot['date'], format='%d/%m/%Y')

#since the locaiton of the sensors would not change across the dates
#since the station would not change location across the dates
# Embed fire data into climate data
# loop through each entry of the climate 
for index, climate_row in climate.iterrows():
    
    #filter out the climate data entries that have the sensor data
    #since they are important, others are not
    #since stations have different data according to dates

    #for each climate, filter out the hotspot/sensors with matching/corresponding date
    #list of true/false to filter out the hotspots related to the dates
    useful_dates = hotspot['date'] == climate_row['date']
    matching_fires = hotspot[useful_dates]

    #convert to list of disctionaries
    fires_list = matching_fires.to_dict('records')
    
    #inner-join
#     if fires_list:
        #print(fires_list)
    #left-outer join
    climate_doc = {
        'stations': climate_row['station'],
                                    #string from time with format, 
                                    #since MongoDB can not store object
        #.strftime('%d/%m/%Y')
        'date': climate_row['date'],
        'air_temperature_celcius': climate_row['air_temperature_celcius'],
        'relative_humidity': climate_row['relative_humidity'],
        'windspeed_knots': climate_row['windspeed_knots'],
        'max_wind_speed': climate_row['max_wind_speed'],
        'precipitation': climate_row['precipitation'],
        'GHI_w/m2': climate_row['GHI_w/m2'],
        #embed sensor data here
        'hotspots': fires_list
    }

    collection.insert_one(climate_doc)

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
"""

# Q2.a.
res = collection.find(
    {
    'date': '12/12/2023'
    }
)

for d in res:
    print(d)
# Out:
# {'_id': ObjectId('66420d6d9e89db15968a9f2c'), 'stations': 948702, 'date': '12/12/2023', 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation': '0.00I', 'GHI_w/m2': 156, 'hotspots': [{'latitude': -37.903, 'longitude': 145.25, 'datetime': '2023-12-12 00:45:38', 'confidence': 53, 'date': '12/12/2023', 'surface_temperature_celcius': 44}]}
# {'_id': ObjectId('664315ec7ee68a2c20b02e79'), 'stations': 948702, 'date': '12/12/2023', 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation': '0.00I', 'GHI_w/m2': 156, 'hotspots': [{'latitude': -37.903, 'longitude': 145.25, 'datetime': '2023-12-12 00:45:38', 'confidence': 53, 'date': '12/12/2023', 'surface_temperature_celcius': 44}]}
# {'_id': ObjectId('664315f57ee68a2c20b02fe8'), 'stations': 948702, 'date': '12/12/2023', 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation': '0.00I', 'GHI_w/m2': 156, 'hotspots': [{'latitude': -37.903, 'longitude': 145.25, 'datetime': '2023-12-12 00:45:38', 'confidence': 53, 'date': '12/12/2023', 'surface_temperature_celcius': 44}]}
# {'_id': ObjectId('66431c927a9d7e37c83ed43d'), 'stations': 948702, 'date': '12/12/2023', 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation': '0.00I', 'GHI_w/m2': 156, 'hotspots': [{'latitude': -37.903, 'longitude': 145.25, 'datetime': '2023-12-12 00:45:38', 'confidence': 53, 'date': '12/12/2023', 'surface_temperature_celcius': 44}]}
# {'_id': ObjectId('6643203206cf726385f323a7'), 'stations': 948702, 'date': '12/12/2023', 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation': '0.00I', 'GHI_w/m2': 156, 'hotspots': [{'latitude': -37.903, 'longitude': 145.25, 'datetime': '2023-12-12 00:45:38', 'confidence': 53, 'date': '12/12/2023', 'surface_temperature_celcius': 44}]}
# {'_id': ObjectId('66449f0bad0ed5632f7d6338'), 'stations': 948702, 'date': '12/12/2023', 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation': '0.00I', 'GHI_w/m2': 156, 'hotspots': [{'latitude': -37.903, 'longitude': 145.25, 'datetime': '2023-12-12 00:45:38', 'confidence': 53, 'date': '12/12/2023', 'surface_temperature_celcius': 44}]}
# {'_id': ObjectId('6644a3832c62191bee0dd730'), 'stations': 948702, 'date': '12/12/2023', 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation': '0.00I', 'GHI_w/m2': 156, 'hotspots': [{'latitude': -37.903, 'longitude': 145.25, 'datetime': '2023-12-12 00:45:38', 'confidence': 53, 'date': '12/12/2023', 'surface_temperature_celcius': 44}]}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question b
"""

# as long as include filtering/matching on the documents of the hotspots array field in the main document
# use aggregate + pipeline

pipeline = [
    {   #first match, filter the station+date documents based on the hotspots that match
        '$match': {
            'hotspots.surface_temperature_celcius': {
                '$gte': 65,
                '$lte': 100
            }
        }
    },
    {   # since not all sensors in the document indexed by date and station
        # fulifll the condition, use unwind to release documents in array field(hotspots)
        # to flatten array
        '$unwind': '$hotspots'  # Unwind the hotspots array
    },
    {   #second match, filter the hotspot documents of the hotspots array
        '$match': {
            'hotspots.surface_temperature_celcius': {
                '$gte': 65,
                '$lte': 100
            }
        }
    },
    {
        '$project': { #   #value from output document after matching
                            #$ -> latitude field
            'latitude': '$hotspots.latitude',
            'longitude': '$hotspots.longitude',
            'surface_temperature_celcius': '$hotspots.surface_temperature_celcius',
            'confidence': '$hotspots.confidence'
        }
    }
]

res = collection.aggregate(pipeline)

# To display only the latitude
for d in res:
    pprint(d)
# Out:
# {'_id': ObjectId('66420d6d9e89db15968a9eed'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('66420d6d9e89db15968a9ef2'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('66420d6d9e89db15968a9ef2'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('66420d6d9e89db15968a9ef4'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('66420d6d9e89db15968a9ef8'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('66420d6d9e89db15968a9f0e'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('66420d6d9e89db15968a9f10'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('66420d6d9e89db15968a9f19'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66420d6d9e89db15968a9f1f'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('66420d6d9e89db15968a9f1f'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('66420d6d9e89db15968a9f1f'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('66420d6d9e89db15968a9f2e'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66420d6d9e89db15968a9f3b'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('66420d6d9e89db15968a9f3b'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('664315ec7ee68a2c20b02e3a'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('664315ec7ee68a2c20b02e3f'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('664315ec7ee68a2c20b02e3f'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('664315ec7ee68a2c20b02e41'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('664315ec7ee68a2c20b02e45'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('664315ec7ee68a2c20b02e5b'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('664315ec7ee68a2c20b02e5d'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('664315ec7ee68a2c20b02e66'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6c'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6c'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6c'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('664315ec7ee68a2c20b02e7b'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('664315ec7ee68a2c20b02e7d'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('664315ec7ee68a2c20b02e7d'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('664315ec7ee68a2c20b02e7d'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('664315ec7ee68a2c20b02e7d'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('664315ec7ee68a2c20b02e88'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('664315ec7ee68a2c20b02e88'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('664315f57ee68a2c20b02fa9'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('664315f57ee68a2c20b02fae'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('664315f57ee68a2c20b02fae'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('664315f57ee68a2c20b02fb0'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('664315f57ee68a2c20b02fb4'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('664315f57ee68a2c20b02fca'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('664315f57ee68a2c20b02fcc'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('664315f57ee68a2c20b02fd5'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('664315f57ee68a2c20b02fdb'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('664315f57ee68a2c20b02fdb'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('664315f57ee68a2c20b02fdb'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('664315f57ee68a2c20b02fdc'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('664315f57ee68a2c20b02fdc'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('664315f57ee68a2c20b02fdc'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('664315f57ee68a2c20b02fdc'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('664315f57ee68a2c20b02fdc'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('664315f57ee68a2c20b02fea'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('664315f67ee68a2c20b02fec'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('664315f67ee68a2c20b02fec'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('664315f67ee68a2c20b02fec'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('664315f67ee68a2c20b02fec'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('664315f67ee68a2c20b02ff7'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('664315f67ee68a2c20b02ff7'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('66431c927a9d7e37c83ed3fe'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('66431c927a9d7e37c83ed403'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('66431c927a9d7e37c83ed403'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('66431c927a9d7e37c83ed405'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('66431c927a9d7e37c83ed409'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('66431c927a9d7e37c83ed41f'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('66431c927a9d7e37c83ed421'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('66431c927a9d7e37c83ed42a'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66431c927a9d7e37c83ed430'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('66431c927a9d7e37c83ed430'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('66431c927a9d7e37c83ed430'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('66431c927a9d7e37c83ed431'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('66431c927a9d7e37c83ed431'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('66431c927a9d7e37c83ed431'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('66431c927a9d7e37c83ed431'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('66431c927a9d7e37c83ed431'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('66431c927a9d7e37c83ed43f'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('66431c927a9d7e37c83ed441'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66431c927a9d7e37c83ed441'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('66431c927a9d7e37c83ed441'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('66431c927a9d7e37c83ed441'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66431c937a9d7e37c83ed44c'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('66431c937a9d7e37c83ed44c'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6643203106cf726385f32368'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6643203106cf726385f3236d'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6643203106cf726385f3236d'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('6643203106cf726385f3236f'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6643203106cf726385f32373'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6643203206cf726385f32389'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6643203206cf726385f3238b'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6643203206cf726385f32394'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6643203206cf726385f3239a'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6643203206cf726385f3239a'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6643203206cf726385f3239a'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('6643203206cf726385f3239b'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6643203206cf726385f3239b'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6643203206cf726385f3239b'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('6643203206cf726385f3239b'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6643203206cf726385f3239b'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6643203206cf726385f323a9'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6643203206cf726385f323ab'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6643203206cf726385f323ab'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6643203206cf726385f323ab'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6643203206cf726385f323ab'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6643203206cf726385f323b6'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6643203206cf726385f323b6'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('66449f0aad0ed5632f7d62f9'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('66449f0aad0ed5632f7d62fe'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('66449f0aad0ed5632f7d62fe'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('66449f0aad0ed5632f7d6300'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('66449f0aad0ed5632f7d6304'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('66449f0aad0ed5632f7d631a'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('66449f0aad0ed5632f7d631c'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('66449f0bad0ed5632f7d6325'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66449f0bad0ed5632f7d632b'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('66449f0bad0ed5632f7d632b'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('66449f0bad0ed5632f7d632b'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('66449f0bad0ed5632f7d632c'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('66449f0bad0ed5632f7d632c'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('66449f0bad0ed5632f7d632c'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('66449f0bad0ed5632f7d632c'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('66449f0bad0ed5632f7d632c'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('66449f0bad0ed5632f7d633a'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('66449f0bad0ed5632f7d633c'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66449f0bad0ed5632f7d633c'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('66449f0bad0ed5632f7d633c'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('66449f0bad0ed5632f7d633c'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('66449f0bad0ed5632f7d6347'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('66449f0bad0ed5632f7d6347'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6644a3822c62191bee0dd6f1'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6644a3822c62191bee0dd6f6'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6644a3822c62191bee0dd6f6'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('6644a3822c62191bee0dd6f8'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6644a3822c62191bee0dd6fc'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6644a3822c62191bee0dd712'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6644a3822c62191bee0dd714'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6644a3822c62191bee0dd71d'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6644a3822c62191bee0dd723'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6644a3822c62191bee0dd723'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6644a3822c62191bee0dd723'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('6644a3822c62191bee0dd724'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6644a3822c62191bee0dd724'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6644a3822c62191bee0dd724'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('6644a3822c62191bee0dd724'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6644a3822c62191bee0dd724'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6644a3832c62191bee0dd732'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6644a3832c62191bee0dd734'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6644a3832c62191bee0dd734'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6644a3832c62191bee0dd734'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6644a3832c62191bee0dd734'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6644a3832c62191bee0dd73f'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6644a3832c62191bee0dd73f'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question c
"""
#filtering only on main document, no pipeline needed

res = collection.find(
    {
        'date':{
            '$in': ['15/12/2023', '16/12/2023']
        }
    },
    {   #only work for main 
        '_id': 0,
        'date': 1,
        'air_temperature_celcius': 1,
        'relative_humidity': 1,
                                        #must be used for array field
        'surface_temperature_celcius': '$hotspots.surface_temperature_celcius'
    }
)

for d in res:
    pprint(d)
# Out:
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question d
"""

pipeline = [
    {
        '$match': {
            'hotspots.confidence': {
                '$gte': 80,
                '$lte': 100
            }
        }
    },
    {
        '$unwind': '$hotspots'  # Corrected to a string
    },
    {
        '$match': {
            'hotspots.confidence': {
                '$gte': 80,
                '$lte': 100
            }
        }
    }
    # {   # no attributes from main document can be shown with fields of document in array field
    #     '$project': {
    #         'datetime': '$hotspots.datetime',
    #         'surface_temperature_celcius': '$hotspots.surface_temperature_celcius',
    #         'confidence': '$hotspots.confidence'  
    #     }
    # }
]

res = collection.aggregate(pipeline)

for d in res:
    pprint(d)


res = collection.aggregate(pipeline)

for d in res:
    pprint(d)
# Out:
# {'GHI_w/m2': 118,
#  '_id': ObjectId('66420d6d9e89db15968a9eed'),
#  'air_temperature_celcius': 13,
#  'date': '10/10/2023',
#  'hotspots': {'confidence': 96,
#               'date': '10/10/2023',
#               'datetime': '2023-10-10 04:04:19',
#               'latitude': -38.127,
#               'longitude': 143.82,
#               'surface_temperature_celcius': 77},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 42.5,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('66420d6d9e89db15968a9ef2'),
#  'air_temperature_celcius': 13,
#  'date': '15/10/2023',
#  'hotspots': {'confidence': 100,
#               'date': '15/10/2023',
#               'datetime': '2023-10-15 04:23:01',
#               'latitude': -37.294,
#               'longitude': 141.232,
#               'surface_temperature_celcius': 87},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.7,
#  'stations': 948702,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('66420d6d9e89db15968a9ef2'),
#  'air_temperature_celcius': 13,
#  'date': '15/10/2023',
#  'hotspots': {'confidence': 99,
#               'date': '15/10/2023',
#               'datetime': '2023-10-15 04:23:01',
#               'latitude': -37.293,
#               'longitude': 141.245,
#               'surface_temperature_celcius': 85},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.7,
#  'stations': 948702,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('66420d6d9e89db15968a9ef4'),
#  'air_temperature_celcius': 22,
#  'date': '17/10/2023',
#  'hotspots': {'confidence': 94,
#               'date': '17/10/2023',
#               'datetime': '2023-10-17 13:36:12',
#               'latitude': -37.247,
#               'longitude': 141.27,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.8,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('66420d6d9e89db15968a9ef4'),
#  'air_temperature_celcius': 22,
#  'date': '17/10/2023',
#  'hotspots': {'confidence': 91,
#               'date': '17/10/2023',
#               'datetime': '2023-10-17 04:10:45',
#               'latitude': -37.247,
#               'longitude': 141.278,
#               'surface_temperature_celcius': 68},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.8,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('66420d6d9e89db15968a9ef4'),
#  'air_temperature_celcius': 22,
#  'date': '17/10/2023',
#  'hotspots': {'confidence': 82,
#               'date': '17/10/2023',
#               'datetime': '2023-10-17 04:10:32',
#               'latitude': -37.805,
#               'longitude': 144.15,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.8,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 219,
#  '_id': ObjectId('66420d6d9e89db15968a9ef5'),
#  'air_temperature_celcius': 26,
#  'date': '18/10/2023',
#  'hotspots': {'confidence': 84,
#               'date': '18/10/2023',
#               'datetime': '2023-10-18 00:39:02',
#               'latitude': -35.89,
#               'longitude': 145.606,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.2,
#  'stations': 948702,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 219,
#  '_id': ObjectId('66420d6d9e89db15968a9ef5'),
#  'air_temperature_celcius': 26,
#  'date': '18/10/2023',
#  'hotspots': {'confidence': 82,
#               'date': '18/10/2023',
#               'datetime': '2023-10-18 00:39:02',
#               'latitude': -35.889,
#               'longitude': 145.614,
#               'surface_temperature_celcius': 56},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.2,
#  'stations': 948702,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('66420d6d9e89db15968a9ef7'),
#  'air_temperature_celcius': 13,
#  'date': '20/10/2023',
#  'hotspots': {'confidence': 80,
#               'date': '20/10/2023',
#               'datetime': '2023-10-20 04:41:19',
#               'latitude': -37.586,
#               'longitude': 141.271,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 42.0,
#  'stations': 948702,
#  'windspeed_knots': 11.4}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('66420d6d9e89db15968a9ef7'),
#  'air_temperature_celcius': 13,
#  'date': '20/10/2023',
#  'hotspots': {'confidence': 82,
#               'date': '20/10/2023',
#               'datetime': '2023-10-20 04:41:19',
#               'latitude': -37.588,
#               'longitude': 141.259,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 42.0,
#  'stations': 948702,
#  'windspeed_knots': 11.4}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('66420d6d9e89db15968a9ef8'),
#  'air_temperature_celcius': 12,
#  'date': '21/10/2023',
#  'hotspots': {'confidence': 88,
#               'date': '21/10/2023',
#               'datetime': '2023-10-21 01:09:55',
#               'latitude': -36.098,
#               'longitude': 143.735,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 47.3,
#  'stations': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('66420d6d9e89db15968a9ef8'),
#  'air_temperature_celcius': 12,
#  'date': '21/10/2023',
#  'hotspots': {'confidence': 92,
#               'date': '21/10/2023',
#               'datetime': '2023-10-21 01:09:54',
#               'latitude': -36.098,
#               'longitude': 143.74,
#               'surface_temperature_celcius': 67},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 47.3,
#  'stations': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('66420d6d9e89db15968a9efd'),
#  'air_temperature_celcius': 13,
#  'date': '26/10/2023',
#  'hotspots': {'confidence': 100,
#               'date': '26/10/2023',
#               'datetime': '2023-10-26 13:30:31',
#               'latitude': -35.321,
#               'longitude': 143.502,
#               'surface_temperature_celcius': 48},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.4,
#  'stations': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('66420d6d9e89db15968a9efd'),
#  'air_temperature_celcius': 13,
#  'date': '26/10/2023',
#  'hotspots': {'confidence': 100,
#               'date': '26/10/2023',
#               'datetime': '2023-10-26 13:30:31',
#               'latitude': -35.323,
#               'longitude': 143.509,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.4,
#  'stations': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 193,
#  '_id': ObjectId('66420d6d9e89db15968a9efe'),
#  'air_temperature_celcius': 22,
#  'date': '27/10/2023',
#  'hotspots': {'confidence': 86,
#               'date': '27/10/2023',
#               'datetime': '2023-10-27 04:47:31',
#               'latitude': -36.759,
#               'longitude': 144.158,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.9,
#  'stations': 948702,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('66420d6d9e89db15968a9eff'),
#  'air_temperature_celcius': 15,
#  'date': '28/10/2023',
#  'hotspots': {'confidence': 81,
#               'date': '28/10/2023',
#               'datetime': '2023-10-28 03:52:17',
#               'latitude': -37.34,
#               'longitude': 143.123,
#               'surface_temperature_celcius': 56},
#  'max_wind_speed': 20.0,
#  'precipitation': '0.01G',
#  'relative_humidity': 48.7,
#  'stations': 948702,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('66420d6d9e89db15968a9f0d'),
#  'air_temperature_celcius': 18,
#  'date': '11/11/2023',
#  'hotspots': {'confidence': 80,
#               'date': '11/11/2023',
#               'datetime': '2023-11-11 13:30:08',
#               'latitude': -36.941,
#               'longitude': 143.268,
#               'surface_temperature_celcius': 37},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'stations': 948702,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('66420d6d9e89db15968a9f0d'),
#  'air_temperature_celcius': 18,
#  'date': '11/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '11/11/2023',
#               'datetime': '2023-11-11 13:30:08',
#               'latitude': -36.939,
#               'longitude': 143.28,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'stations': 948702,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('66420d6d9e89db15968a9f0d'),
#  'air_temperature_celcius': 18,
#  'date': '11/11/2023',
#  'hotspots': {'confidence': 86,
#               'date': '11/11/2023',
#               'datetime': '2023-11-11 04:04:25',
#               'latitude': -37.863,
#               'longitude': 144.17,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'stations': 948702,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('66420d6d9e89db15968a9f0e'),
#  'air_temperature_celcius': 18,
#  'date': '12/11/2023',
#  'hotspots': {'confidence': 89,
#               'date': '12/11/2023',
#               'datetime': '2023-11-12 00:33:15',
#               'latitude': -36.94,
#               'longitude': 143.281,
#               'surface_temperature_celcius': 69},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.8,
#  'stations': 948702,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f0f'),
#  'air_temperature_celcius': 24,
#  'date': '13/11/2023',
#  'hotspots': {'confidence': 87,
#               'date': '13/11/2023',
#               'datetime': '2023-11-13 03:52:15',
#               'latitude': -37.621,
#               'longitude': 143.447,
#               'surface_temperature_celcius': 61},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.9,
#  'stations': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f0f'),
#  'air_temperature_celcius': 24,
#  'date': '13/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '13/11/2023',
#               'datetime': '2023-11-13 03:52:14',
#               'latitude': -37.614,
#               'longitude': 143.451,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.9,
#  'stations': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('66420d6d9e89db15968a9f10'),
#  'air_temperature_celcius': 28,
#  'date': '14/11/2023',
#  'hotspots': {'confidence': 87,
#               'date': '14/11/2023',
#               'datetime': '2023-11-14 04:35:04',
#               'latitude': -37.862,
#               'longitude': 144.175,
#               'surface_temperature_celcius': 65},
#  'max_wind_speed': 22.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 48.3,
#  'stations': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('66420d6d9e89db15968a9f17'),
#  'air_temperature_celcius': 24,
#  'date': '21/11/2023',
#  'hotspots': {'confidence': 85,
#               'date': '21/11/2023',
#               'datetime': '2023-11-21 00:27:21',
#               'latitude': -37.758,
#               'longitude': 144.693,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.8,
#  'stations': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('66420d6d9e89db15968a9f18'),
#  'air_temperature_celcius': 23,
#  'date': '22/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '22/11/2023',
#               'datetime': '2023-11-22 03:46:00',
#               'latitude': -37.978,
#               'longitude': 145.623,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.6,
#  'stations': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('66420d6d9e89db15968a9f18'),
#  'air_temperature_celcius': 23,
#  'date': '22/11/2023',
#  'hotspots': {'confidence': 88,
#               'date': '22/11/2023',
#               'datetime': '2023-11-22 03:46:00',
#               'latitude': -37.976,
#               'longitude': 145.649,
#               'surface_temperature_celcius': 64},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.6,
#  'stations': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('66420d6d9e89db15968a9f19'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '23/11/2023',
#               'datetime': '2023-11-23 04:28:59',
#               'latitude': -37.946,
#               'longitude': 144.342,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'stations': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('66420d6d9e89db15968a9f19'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2023',
#  'hotspots': {'confidence': 93,
#               'date': '23/11/2023',
#               'datetime': '2023-11-23 04:28:59',
#               'latitude': -37.945,
#               'longitude': 144.354,
#               'surface_temperature_celcius': 73},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'stations': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('66420d6d9e89db15968a9f1f'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 13:17:24',
#               'latitude': -37.608,
#               'longitude': 149.292,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('66420d6d9e89db15968a9f1f'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 03:52:10',
#               'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celcius': 87},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('66420d6d9e89db15968a9f1f'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 97,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 03:52:10',
#               'latitude': -37.61,
#               'longitude': 149.307,
#               'surface_temperature_celcius': 80},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('66420d6d9e89db15968a9f1f'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 99,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 03:52:10',
#               'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celcius': 84},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:36',
#               'latitude': -37.591,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:35',
#               'latitude': -37.585,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:35',
#               'latitude': -37.583,
#               'longitude': 149.316,
#               'surface_temperature_celcius': 49},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.596,
#               'longitude': 149.319,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.63,
#               'longitude': 149.232,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.644,
#               'longitude': 149.233,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:14',
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:35:00',
#               'latitude': -37.384,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 98,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.627,
#               'longitude': 149.261,
#               'surface_temperature_celcius': 57},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.623,
#               'longitude': 149.284,
#               'surface_temperature_celcius': 61},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 99,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 83,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.608,
#               'longitude': 149.282,
#               'surface_temperature_celcius': 58},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 87,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.62,
#               'longitude': 149.294,
#               'surface_temperature_celcius': 63},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 95,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.61,
#               'longitude': 149.296,
#               'surface_temperature_celcius': 56},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('66420d6d9e89db15968a9f20'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.602,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 240,
#  '_id': ObjectId('66420d6d9e89db15968a9f2d'),
#  'air_temperature_celcius': 28,
#  'date': '13/12/2023',
#  'hotspots': {'confidence': 83,
#               'date': '13/12/2023',
#               'datetime': '2023-12-13 04:04:19',
#               'latitude': -38.231,
#               'longitude': 147.172,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.9,
#  'stations': 948702,
#  'windspeed_knots': 11.0}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('66420d6d9e89db15968a9f2e'),
#  'air_temperature_celcius': 17,
#  'date': '14/12/2023',
#  'hotspots': {'confidence': 92,
#               'date': '14/12/2023',
#               'datetime': '2023-12-14 04:47:25',
#               'latitude': -37.95,
#               'longitude': 142.366,
#               'surface_temperature_celcius': 70},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.5,
#  'stations': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('66420d6d9e89db15968a9f2f'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'hotspots': {'confidence': 92,
#               'date': '15/12/2023',
#               'datetime': '2023-12-15 13:17:17',
#               'latitude': -37.627,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.0,
#  'stations': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 94,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 15:38:39',
#               'latitude': -37.636,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 93,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:35:13',
#               'latitude': -37.875,
#               'longitude': 142.51,
#               'surface_temperature_celcius': 73},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 84,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:34:58',
#               'latitude': -37.608,
#               'longitude': 149.328,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 95,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:34:58',
#               'latitude': -37.613,
#               'longitude': 149.305,
#               'surface_temperature_celcius': 75},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 90,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:34:57',
#               'latitude': -37.624,
#               'longitude': 149.314,
#               'surface_temperature_celcius': 66},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 93,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 00:21:12',
#               'latitude': -38.057,
#               'longitude': 144.211,
#               'surface_temperature_celcius': 73},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 82,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 00:21:11',
#               'latitude': -38.048,
#               'longitude': 144.213,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('66420d6d9e89db15968a9f30'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 82,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 00:20:53',
#               'latitude': -37.651,
#               'longitude': 149.345,
#               'surface_temperature_celcius': 64},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('66420d6d9e89db15968a9f39'),
#  'air_temperature_celcius': 17,
#  'date': '25/12/2023',
#  'hotspots': {'confidence': 80,
#               'date': '25/12/2023',
#               'datetime': '2023-12-25 04:29:08',
#               'latitude': -37.708,
#               'longitude': 145.1,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.4,
#  'stations': 948702,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('66420d6d9e89db15968a9f3b'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2023',
#  'hotspots': {'confidence': 82,
#               'date': '27/12/2023',
#               'datetime': '2023-12-27 00:02:15',
#               'latitude': -35.541,
#               'longitude': 143.311,
#               'surface_temperature_celcius': 63},
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('66420d6d9e89db15968a9f3b'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2023',
#  'hotspots': {'confidence': 86,
#               'date': '27/12/2023',
#               'datetime': '2023-12-27 00:02:14',
#               'latitude': -35.543,
#               'longitude': 143.316,
#               'surface_temperature_celcius': 67},
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 118,
#  '_id': ObjectId('664315ec7ee68a2c20b02e3a'),
#  'air_temperature_celcius': 13,
#  'date': '10/10/2023',
#  'hotspots': {'confidence': 96,
#               'date': '10/10/2023',
#               'datetime': '2023-10-10 04:04:19',
#               'latitude': -38.127,
#               'longitude': 143.82,
#               'surface_temperature_celcius': 77},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 42.5,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('664315ec7ee68a2c20b02e3f'),
#  'air_temperature_celcius': 13,
#  'date': '15/10/2023',
#  'hotspots': {'confidence': 100,
#               'date': '15/10/2023',
#               'datetime': '2023-10-15 04:23:01',
#               'latitude': -37.294,
#               'longitude': 141.232,
#               'surface_temperature_celcius': 87},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.7,
#  'stations': 948702,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('664315ec7ee68a2c20b02e3f'),
#  'air_temperature_celcius': 13,
#  'date': '15/10/2023',
#  'hotspots': {'confidence': 99,
#               'date': '15/10/2023',
#               'datetime': '2023-10-15 04:23:01',
#               'latitude': -37.293,
#               'longitude': 141.245,
#               'surface_temperature_celcius': 85},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.7,
#  'stations': 948702,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('664315ec7ee68a2c20b02e41'),
#  'air_temperature_celcius': 22,
#  'date': '17/10/2023',
#  'hotspots': {'confidence': 94,
#               'date': '17/10/2023',
#               'datetime': '2023-10-17 13:36:12',
#               'latitude': -37.247,
#               'longitude': 141.27,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.8,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('664315ec7ee68a2c20b02e41'),
#  'air_temperature_celcius': 22,
#  'date': '17/10/2023',
#  'hotspots': {'confidence': 91,
#               'date': '17/10/2023',
#               'datetime': '2023-10-17 04:10:45',
#               'latitude': -37.247,
#               'longitude': 141.278,
#               'surface_temperature_celcius': 68},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.8,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('664315ec7ee68a2c20b02e41'),
#  'air_temperature_celcius': 22,
#  'date': '17/10/2023',
#  'hotspots': {'confidence': 82,
#               'date': '17/10/2023',
#               'datetime': '2023-10-17 04:10:32',
#               'latitude': -37.805,
#               'longitude': 144.15,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.8,
#  'stations': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 219,
#  '_id': ObjectId('664315ec7ee68a2c20b02e42'),
#  'air_temperature_celcius': 26,
#  'date': '18/10/2023',
#  'hotspots': {'confidence': 84,
#               'date': '18/10/2023',
#               'datetime': '2023-10-18 00:39:02',
#               'latitude': -35.89,
#               'longitude': 145.606,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.2,
#  'stations': 948702,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 219,
#  '_id': ObjectId('664315ec7ee68a2c20b02e42'),
#  'air_temperature_celcius': 26,
#  'date': '18/10/2023',
#  'hotspots': {'confidence': 82,
#               'date': '18/10/2023',
#               'datetime': '2023-10-18 00:39:02',
#               'latitude': -35.889,
#               'longitude': 145.614,
#               'surface_temperature_celcius': 56},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.2,
#  'stations': 948702,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('664315ec7ee68a2c20b02e44'),
#  'air_temperature_celcius': 13,
#  'date': '20/10/2023',
#  'hotspots': {'confidence': 80,
#               'date': '20/10/2023',
#               'datetime': '2023-10-20 04:41:19',
#               'latitude': -37.586,
#               'longitude': 141.271,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 42.0,
#  'stations': 948702,
#  'windspeed_knots': 11.4}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('664315ec7ee68a2c20b02e44'),
#  'air_temperature_celcius': 13,
#  'date': '20/10/2023',
#  'hotspots': {'confidence': 82,
#               'date': '20/10/2023',
#               'datetime': '2023-10-20 04:41:19',
#               'latitude': -37.588,
#               'longitude': 141.259,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 42.0,
#  'stations': 948702,
#  'windspeed_knots': 11.4}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('664315ec7ee68a2c20b02e45'),
#  'air_temperature_celcius': 12,
#  'date': '21/10/2023',
#  'hotspots': {'confidence': 88,
#               'date': '21/10/2023',
#               'datetime': '2023-10-21 01:09:55',
#               'latitude': -36.098,
#               'longitude': 143.735,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 47.3,
#  'stations': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('664315ec7ee68a2c20b02e45'),
#  'air_temperature_celcius': 12,
#  'date': '21/10/2023',
#  'hotspots': {'confidence': 92,
#               'date': '21/10/2023',
#               'datetime': '2023-10-21 01:09:54',
#               'latitude': -36.098,
#               'longitude': 143.74,
#               'surface_temperature_celcius': 67},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 47.3,
#  'stations': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('664315ec7ee68a2c20b02e4a'),
#  'air_temperature_celcius': 13,
#  'date': '26/10/2023',
#  'hotspots': {'confidence': 100,
#               'date': '26/10/2023',
#               'datetime': '2023-10-26 13:30:31',
#               'latitude': -35.321,
#               'longitude': 143.502,
#               'surface_temperature_celcius': 48},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.4,
#  'stations': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('664315ec7ee68a2c20b02e4a'),
#  'air_temperature_celcius': 13,
#  'date': '26/10/2023',
#  'hotspots': {'confidence': 100,
#               'date': '26/10/2023',
#               'datetime': '2023-10-26 13:30:31',
#               'latitude': -35.323,
#               'longitude': 143.509,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.4,
#  'stations': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 193,
#  '_id': ObjectId('664315ec7ee68a2c20b02e4b'),
#  'air_temperature_celcius': 22,
#  'date': '27/10/2023',
#  'hotspots': {'confidence': 86,
#               'date': '27/10/2023',
#               'datetime': '2023-10-27 04:47:31',
#               'latitude': -36.759,
#               'longitude': 144.158,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.9,
#  'stations': 948702,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('664315ec7ee68a2c20b02e4c'),
#  'air_temperature_celcius': 15,
#  'date': '28/10/2023',
#  'hotspots': {'confidence': 81,
#               'date': '28/10/2023',
#               'datetime': '2023-10-28 03:52:17',
#               'latitude': -37.34,
#               'longitude': 143.123,
#               'surface_temperature_celcius': 56},
#  'max_wind_speed': 20.0,
#  'precipitation': '0.01G',
#  'relative_humidity': 48.7,
#  'stations': 948702,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5a'),
#  'air_temperature_celcius': 18,
#  'date': '11/11/2023',
#  'hotspots': {'confidence': 80,
#               'date': '11/11/2023',
#               'datetime': '2023-11-11 13:30:08',
#               'latitude': -36.941,
#               'longitude': 143.268,
#               'surface_temperature_celcius': 37},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'stations': 948702,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5a'),
#  'air_temperature_celcius': 18,
#  'date': '11/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '11/11/2023',
#               'datetime': '2023-11-11 13:30:08',
#               'latitude': -36.939,
#               'longitude': 143.28,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'stations': 948702,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5a'),
#  'air_temperature_celcius': 18,
#  'date': '11/11/2023',
#  'hotspots': {'confidence': 86,
#               'date': '11/11/2023',
#               'datetime': '2023-11-11 04:04:25',
#               'latitude': -37.863,
#               'longitude': 144.17,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'stations': 948702,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5b'),
#  'air_temperature_celcius': 18,
#  'date': '12/11/2023',
#  'hotspots': {'confidence': 89,
#               'date': '12/11/2023',
#               'datetime': '2023-11-12 00:33:15',
#               'latitude': -36.94,
#               'longitude': 143.281,
#               'surface_temperature_celcius': 69},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.8,
#  'stations': 948702,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5c'),
#  'air_temperature_celcius': 24,
#  'date': '13/11/2023',
#  'hotspots': {'confidence': 87,
#               'date': '13/11/2023',
#               'datetime': '2023-11-13 03:52:15',
#               'latitude': -37.621,
#               'longitude': 143.447,
#               'surface_temperature_celcius': 61},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.9,
#  'stations': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5c'),
#  'air_temperature_celcius': 24,
#  'date': '13/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '13/11/2023',
#               'datetime': '2023-11-13 03:52:14',
#               'latitude': -37.614,
#               'longitude': 143.451,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.9,
#  'stations': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5d'),
#  'air_temperature_celcius': 28,
#  'date': '14/11/2023',
#  'hotspots': {'confidence': 87,
#               'date': '14/11/2023',
#               'datetime': '2023-11-14 04:35:04',
#               'latitude': -37.862,
#               'longitude': 144.175,
#               'surface_temperature_celcius': 65},
#  'max_wind_speed': 22.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 48.3,
#  'stations': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('664315ec7ee68a2c20b02e64'),
#  'air_temperature_celcius': 24,
#  'date': '21/11/2023',
#  'hotspots': {'confidence': 85,
#               'date': '21/11/2023',
#               'datetime': '2023-11-21 00:27:21',
#               'latitude': -37.758,
#               'longitude': 144.693,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.8,
#  'stations': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('664315ec7ee68a2c20b02e65'),
#  'air_temperature_celcius': 23,
#  'date': '22/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '22/11/2023',
#               'datetime': '2023-11-22 03:46:00',
#               'latitude': -37.978,
#               'longitude': 145.623,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.6,
#  'stations': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('664315ec7ee68a2c20b02e65'),
#  'air_temperature_celcius': 23,
#  'date': '22/11/2023',
#  'hotspots': {'confidence': 88,
#               'date': '22/11/2023',
#               'datetime': '2023-11-22 03:46:00',
#               'latitude': -37.976,
#               'longitude': 145.649,
#               'surface_temperature_celcius': 64},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.6,
#  'stations': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('664315ec7ee68a2c20b02e66'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '23/11/2023',
#               'datetime': '2023-11-23 04:28:59',
#               'latitude': -37.946,
#               'longitude': 144.342,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'stations': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('664315ec7ee68a2c20b02e66'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2023',
#  'hotspots': {'confidence': 93,
#               'date': '23/11/2023',
#               'datetime': '2023-11-23 04:28:59',
#               'latitude': -37.945,
#               'longitude': 144.354,
#               'surface_temperature_celcius': 73},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'stations': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6c'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 13:17:24',
#               'latitude': -37.608,
#               'longitude': 149.292,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6c'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 03:52:10',
#               'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celcius': 87},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6c'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 97,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 03:52:10',
#               'latitude': -37.61,
#               'longitude': 149.307,
#               'surface_temperature_celcius': 80},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6c'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 99,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 03:52:10',
#               'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celcius': 84},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:36',
#               'latitude': -37.591,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:35',
#               'latitude': -37.585,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:35',
#               'latitude': -37.583,
#               'longitude': 149.316,
#               'surface_temperature_celcius': 49},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('664315ec7ee68a2c20b02e6d'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '30/11/2023',
# ...
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('6644a3822c62191bee0dd723'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2023',
#  'hotspots': {'confidence': 99,
#               'date': '29/11/2023',
#               'datetime': '2023-11-29 03:52:10',
#               'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celcius': 84},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.7,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:36',
#               'latitude': -37.591,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:35',
#               'latitude': -37.585,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 15:38:35',
#               'latitude': -37.583,
#               'longitude': 149.316,
#               'surface_temperature_celcius': 49},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.596,
#               'longitude': 149.319,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.63,
#               'longitude': 149.232,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.644,
#               'longitude': 149.233,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:15',
#               'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 100,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 12:22:14',
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:35:00',
#               'latitude': -37.384,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 59},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 98,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.627,
#               'longitude': 149.261,
#               'surface_temperature_celcius': 57},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 84,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.623,
#               'longitude': 149.284,
#               'surface_temperature_celcius': 61},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 99,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 04:34:57',
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 83,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.608,
#               'longitude': 149.282,
#               'surface_temperature_celcius': 58},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 87,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.62,
#               'longitude': 149.294,
#               'surface_temperature_celcius': 63},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 95,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.61,
#               'longitude': 149.296,
#               'surface_temperature_celcius': 56},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6644a3822c62191bee0dd724'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': {'confidence': 81,
#               'date': '30/11/2023',
#               'datetime': '2023-11-30 00:20:53',
#               'latitude': -37.602,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 240,
#  '_id': ObjectId('6644a3832c62191bee0dd731'),
#  'air_temperature_celcius': 28,
#  'date': '13/12/2023',
#  'hotspots': {'confidence': 83,
#               'date': '13/12/2023',
#               'datetime': '2023-12-13 04:04:19',
#               'latitude': -38.231,
#               'longitude': 147.172,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.9,
#  'stations': 948702,
#  'windspeed_knots': 11.0}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6644a3832c62191bee0dd732'),
#  'air_temperature_celcius': 17,
#  'date': '14/12/2023',
#  'hotspots': {'confidence': 92,
#               'date': '14/12/2023',
#               'datetime': '2023-12-14 04:47:25',
#               'latitude': -37.95,
#               'longitude': 142.366,
#               'surface_temperature_celcius': 70},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.5,
#  'stations': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('6644a3832c62191bee0dd733'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'hotspots': {'confidence': 92,
#               'date': '15/12/2023',
#               'datetime': '2023-12-15 13:17:17',
#               'latitude': -37.627,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.0,
#  'stations': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 94,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 15:38:39',
#               'latitude': -37.636,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 93,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:35:13',
#               'latitude': -37.875,
#               'longitude': 142.51,
#               'surface_temperature_celcius': 73},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 84,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:34:58',
#               'latitude': -37.608,
#               'longitude': 149.328,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 95,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:34:58',
#               'latitude': -37.613,
#               'longitude': 149.305,
#               'surface_temperature_celcius': 75},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 90,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 04:34:57',
#               'latitude': -37.624,
#               'longitude': 149.314,
#               'surface_temperature_celcius': 66},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 93,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 00:21:12',
#               'latitude': -38.057,
#               'longitude': 144.211,
#               'surface_temperature_celcius': 73},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 82,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 00:21:11',
#               'latitude': -38.048,
#               'longitude': 144.213,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6644a3832c62191bee0dd734'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': {'confidence': 82,
#               'date': '16/12/2023',
#               'datetime': '2023-12-16 00:20:53',
#               'latitude': -37.651,
#               'longitude': 149.345,
#               'surface_temperature_celcius': 64},
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'stations': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6644a3832c62191bee0dd73d'),
#  'air_temperature_celcius': 17,
#  'date': '25/12/2023',
#  'hotspots': {'confidence': 80,
#               'date': '25/12/2023',
#               'datetime': '2023-12-25 04:29:08',
#               'latitude': -37.708,
#               'longitude': 145.1,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.4,
#  'stations': 948702,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('6644a3832c62191bee0dd73f'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2023',
#  'hotspots': {'confidence': 82,
#               'date': '27/12/2023',
#               'datetime': '2023-12-27 00:02:15',
#               'latitude': -35.541,
#               'longitude': 143.311,
#               'surface_temperature_celcius': 63},
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'stations': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('6644a3832c62191bee0dd73f'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2023',
#  'hotspots': {'confidence': 86,
#               'date': '27/12/2023',
#               'datetime': '2023-12-27 00:02:14',
#               'latitude': -35.543,
#               'longitude': 143.316,
#               'surface_temperature_celcius': 67},
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'stations': 948702,
#  'windspeed_knots': 9.3}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question e
"""
                        #sort 
#res = collection.find().sort('surface_temperature_celcius', -1).limit(10)
res = collection.find().sort('surface_temperature_celcius', pymongo.DESCENDING).limit(10)

for i, d in enumerate(res):
    # only 10 records for res
    # if i == 9:
    pprint(d)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('66420d6b9e89db15968a9ddb'),
#  'air_temperature_celcius': 19,
#  'date': '09/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.3,
#  'stations': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('66420d6b9e89db15968a9ddc'),
#  'air_temperature_celcius': 20,
#  'date': '10/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.0,
#  'stations': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('66420d6b9e89db15968a9dd7'),
#  'air_temperature_celcius': 24,
#  'date': '05/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 62.3,
#  'stations': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('66420d6b9e89db15968a9dda'),
#  'air_temperature_celcius': 20,
#  'date': '08/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.7,
#  'stations': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('66420d6b9e89db15968a9dd8'),
#  'air_temperature_celcius': 26,
#  'date': '06/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.8,
#  'stations': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('66420d6b9e89db15968a9dd6'),
#  'air_temperature_celcius': 24,
#  'date': '04/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 61.6,
#  'stations': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('66420d6b9e89db15968a9dd4'),
#  'air_temperature_celcius': 15,
#  'date': '02/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 50.7,
#  'stations': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('66420d6b9e89db15968a9dd3'),
#  'air_temperature_celcius': 19,
#  'date': '31/12/2022',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'stations': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('66420d6b9e89db15968a9dd5'),
#  'air_temperature_celcius': 16,
#  'date': '03/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 53.6,
#  'stations': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('66420d6b9e89db15968a9dd9'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question f
"""

pipeline = [
    {
        '$group': {
            '_id': '$date',  # group by the 'date' field
            'count': {'$sum': 1}  # count the documents in each group
        }
    }
]

res = collection.aggregate(pipeline)
for i, d in enumerate(res):
    pprint(d)
# Out:
# {'_id': '23/10/2023', 'count': 7}
# {'_id': '24/12/2023', 'count': 7}
# {'_id': '01/04/2023', 'count': 7}
# {'_id': '03/06/2023', 'count': 7}
# {'_id': '17/08/2023', 'count': 7}
# {'_id': '24/08/2023', 'count': 7}
# {'_id': '20/09/2023', 'count': 7}
# {'_id': '31/07/2023', 'count': 7}
# {'_id': '29/09/2023', 'count': 7}
# {'_id': '28/04/2023', 'count': 7}
# {'_id': '03/10/2023', 'count': 7}
# {'_id': '11/11/2023', 'count': 7}
# {'_id': '28/05/2023', 'count': 7}
# {'_id': '17/10/2023', 'count': 7}
# {'_id': '09/01/2023', 'count': 7}
# {'_id': '06/04/2023', 'count': 7}
# {'_id': '04/05/2023', 'count': 7}
# {'_id': '08/08/2023', 'count': 7}
# {'_id': '26/02/2023', 'count': 7}
# {'_id': '17/05/2023', 'count': 7}
# {'_id': '14/02/2023', 'count': 7}
# {'_id': '30/03/2023', 'count': 7}
# {'_id': '18/09/2023', 'count': 7}
# {'_id': '19/05/2023', 'count': 7}
# {'_id': '21/09/2023', 'count': 7}
# {'_id': '10/08/2023', 'count': 7}
# {'_id': '16/10/2023', 'count': 7}
# {'_id': '14/07/2023', 'count': 7}
# {'_id': '05/09/2023', 'count': 7}
# {'_id': '05/12/2023', 'count': 7}
# {'_id': '27/06/2023', 'count': 7}
# {'_id': '11/02/2023', 'count': 7}
# {'_id': '13/02/2023', 'count': 7}
# {'_id': '04/10/2023', 'count': 7}
# {'_id': '07/10/2023', 'count': 7}
# {'_id': '04/03/2023', 'count': 7}
# {'_id': '08/06/2023', 'count': 7}
# {'_id': '17/04/2023', 'count': 7}
# {'_id': '25/10/2023', 'count': 7}
# {'_id': '12/04/2023', 'count': 7}
# {'_id': '07/04/2023', 'count': 7}
# {'_id': '29/10/2023', 'count': 7}
# {'_id': '09/11/2023', 'count': 7}
# {'_id': '03/01/2023', 'count': 7}
# {'_id': '27/02/2023', 'count': 7}
# {'_id': '27/08/2023', 'count': 7}
# {'_id': '30/12/2023', 'count': 7}
# {'_id': '11/01/2023', 'count': 7}
# {'_id': '21/01/2023', 'count': 7}
# {'_id': '15/07/2023', 'count': 7}
# {'_id': '07/01/2023', 'count': 7}
# {'_id': '29/07/2023', 'count': 7}
# {'_id': '02/09/2023', 'count': 7}
# {'_id': '14/11/2023', 'count': 7}
# {'_id': '02/12/2023', 'count': 7}
# {'_id': '12/12/2023', 'count': 7}
# {'_id': '02/05/2023', 'count': 7}
# {'_id': '20/12/2023', 'count': 7}
# {'_id': '28/02/2023', 'count': 7}
# {'_id': '15/02/2023', 'count': 7}
# {'_id': '25/07/2023', 'count': 7}
# {'_id': '03/04/2023', 'count': 7}
# {'_id': '20/07/2023', 'count': 7}
# {'_id': '14/12/2023', 'count': 7}
# {'_id': '10/07/2023', 'count': 7}
# {'_id': '14/05/2023', 'count': 7}
# {'_id': '03/11/2023', 'count': 7}
# {'_id': '15/04/2023', 'count': 7}
# {'_id': '30/04/2023', 'count': 7}
# {'_id': '21/06/2023', 'count': 7}
# {'_id': '13/06/2023', 'count': 7}
# {'_id': '02/04/2023', 'count': 7}
# {'_id': '16/06/2023', 'count': 7}
# {'_id': '10/05/2023', 'count': 7}
# {'_id': '20/05/2023', 'count': 7}
# {'_id': '19/04/2023', 'count': 7}
# {'_id': '11/10/2023', 'count': 7}
# {'_id': '17/11/2023', 'count': 7}
# {'_id': '25/12/2023', 'count': 7}
# {'_id': '23/09/2023', 'count': 7}
# {'_id': '17/01/2023', 'count': 7}
# {'_id': '13/04/2023', 'count': 7}
# {'_id': '31/03/2023', 'count': 7}
# {'_id': '16/12/2023', 'count': 7}
# {'_id': '26/01/2023', 'count': 7}
# {'_id': '07/05/2023', 'count': 7}
# {'_id': '25/08/2023', 'count': 7}
# {'_id': '31/08/2023', 'count': 7}
# {'_id': '13/10/2023', 'count': 7}
# {'_id': '01/05/2023', 'count': 7}
# {'_id': '01/06/2023', 'count': 7}
# {'_id': '22/02/2023', 'count': 7}
# {'_id': '29/01/2023', 'count': 7}
# {'_id': '24/10/2023', 'count': 7}
# {'_id': '03/03/2023', 'count': 7}
# {'_id': '17/07/2023', 'count': 7}
# {'_id': '28/01/2023', 'count': 7}
# {'_id': '04/02/2023', 'count': 7}
# {'_id': '15/06/2023', 'count': 7}
# {'_id': '10/04/2023', 'count': 7}
# {'_id': '17/06/2023', 'count': 7}
# {'_id': '03/09/2023', 'count': 7}
# {'_id': '05/04/2023', 'count': 7}
# {'_id': '09/09/2023', 'count': 7}
# {'_id': '23/01/2023', 'count': 7}
# {'_id': '04/06/2023', 'count': 7}
# {'_id': '11/09/2023', 'count': 7}
# {'_id': '19/07/2023', 'count': 7}
# {'_id': '06/08/2023', 'count': 7}
# {'_id': '19/06/2023', 'count': 7}
# {'_id': '29/08/2023', 'count': 7}
# {'_id': '26/03/2023', 'count': 7}
# {'_id': '26/05/2023', 'count': 7}
# {'_id': '16/09/2023', 'count': 7}
# {'_id': '10/03/2023', 'count': 7}
# {'_id': '06/10/2023', 'count': 7}
# {'_id': '16/02/2023', 'count': 7}
# {'_id': '29/06/2023', 'count': 7}
# {'_id': '16/04/2023', 'count': 7}
# {'_id': '05/11/2023', 'count': 7}
# {'_id': '15/11/2023', 'count': 7}
# {'_id': '11/12/2023', 'count': 7}
# {'_id': '29/04/2023', 'count': 7}
# {'_id': '08/05/2023', 'count': 7}
# {'_id': '26/12/2023', 'count': 7}
# {'_id': '15/10/2023', 'count': 7}
# {'_id': '22/07/2023', 'count': 7}
# {'_id': '20/01/2023', 'count': 7}
# {'_id': '05/08/2023', 'count': 7}
# {'_id': '01/11/2023', 'count': 7}
# {'_id': '07/03/2023', 'count': 7}
# {'_id': '08/03/2023', 'count': 7}
# {'_id': '20/11/2023', 'count': 7}
# {'_id': '05/06/2023', 'count': 7}
# {'_id': '26/04/2023', 'count': 7}
# {'_id': '17/03/2023', 'count': 7}
# {'_id': '11/06/2023', 'count': 7}
# {'_id': '03/02/2023', 'count': 7}
# {'_id': '15/05/2023', 'count': 7}
# {'_id': '22/08/2023', 'count': 7}
# {'_id': '18/01/2023', 'count': 7}
# {'_id': '27/01/2023', 'count': 7}
# {'_id': '10/02/2023', 'count': 7}
# {'_id': '12/03/2023', 'count': 7}
# {'_id': '13/09/2023', 'count': 7}
# {'_id': '27/09/2023', 'count': 7}
# {'_id': '01/10/2023', 'count': 7}
# {'_id': '23/07/2023', 'count': 7}
# {'_id': '24/04/2023', 'count': 7}
# {'_id': '06/09/2023', 'count': 7}
# {'_id': '21/08/2023', 'count': 7}
# {'_id': '28/11/2023', 'count': 7}
# {'_id': '30/10/2023', 'count': 7}
# {'_id': '06/06/2023', 'count': 7}
# {'_id': '10/10/2023', 'count': 7}
# {'_id': '10/11/2023', 'count': 7}
# {'_id': '09/03/2023', 'count': 7}
# {'_id': '19/08/2023', 'count': 7}
# {'_id': '01/02/2023', 'count': 7}
# {'_id': '14/09/2023', 'count': 7}
# {'_id': '28/10/2023', 'count': 7}
# {'_id': '13/03/2023', 'count': 7}
# {'_id': '15/03/2023', 'count': 7}
# {'_id': '27/04/2023', 'count': 7}
# {'_id': '19/01/2023', 'count': 7}
# {'_id': '04/09/2023', 'count': 7}
# {'_id': '28/12/2023', 'count': 7}
# {'_id': '16/05/2023', 'count': 7}
# {'_id': '31/12/2023', 'count': 7}
# {'_id': '02/01/2023', 'count': 7}
# {'_id': '25/05/2023', 'count': 7}
# {'_id': '24/01/2023', 'count': 7}
# {'_id': '06/01/2023', 'count': 7}
# {'_id': '02/06/2023', 'count': 7}
# {'_id': '06/07/2023', 'count': 7}
# {'_id': '24/05/2023', 'count': 7}
# {'_id': '21/11/2023', 'count': 7}
# {'_id': '25/03/2023', 'count': 7}
# {'_id': '04/07/2023', 'count': 7}
# {'_id': '21/02/2023', 'count': 7}
# {'_id': '07/07/2023', 'count': 7}
# {'_id': '21/03/2023', 'count': 7}
# {'_id': '18/07/2023', 'count': 7}
# {'_id': '18/06/2023', 'count': 7}
# {'_id': '08/11/2023', 'count': 7}
# {'_id': '03/12/2023', 'count': 7}
# {'_id': '30/11/2023', 'count': 7}
# {'_id': '12/06/2023', 'count': 7}
# {'_id': '07/08/2023', 'count': 7}
# {'_id': '11/04/2023', 'count': 7}
# {'_id': '22/09/2023', 'count': 7}
# {'_id': '19/02/2023', 'count': 7}
# {'_id': '19/03/2023', 'count': 7}
# {'_id': '06/05/2023', 'count': 7}
# {'_id': '14/03/2023', 'count': 7}
# {'_id': '26/08/2023', 'count': 7}
# {'_id': '22/03/2023', 'count': 7}
# {'_id': '22/01/2023', 'count': 7}
# {'_id': '22/11/2023', 'count': 7}
# {'_id': '03/05/2023', 'count': 7}
# {'_id': '15/08/2023', 'count': 7}
# {'_id': '08/12/2023', 'count': 7}
# {'_id': '20/08/2023', 'count': 7}
# {'_id': '04/01/2023', 'count': 7}
# {'_id': '07/12/2023', 'count': 7}
# {'_id': '08/09/2023', 'count': 7}
# {'_id': '20/04/2023', 'count': 7}
# {'_id': '10/01/2023', 'count': 7}
# {'_id': '21/07/2023', 'count': 7}
# {'_id': '29/05/2023', 'count': 7}
# {'_id': '13/05/2023', 'count': 7}
# {'_id': '17/09/2023', 'count': 7}
# {'_id': '30/06/2023', 'count': 7}
# {'_id': '24/09/2023', 'count': 7}
# {'_id': '28/08/2023', 'count': 7}
# {'_id': '09/10/2023', 'count': 7}
# {'_id': '08/04/2023', 'count': 7}
# {'_id': '19/10/2023', 'count': 7}
# {'_id': '11/03/2023', 'count': 7}
# {'_id': '12/08/2023', 'count': 7}
# {'_id': '07/09/2023', 'count': 7}
# {'_id': '22/04/2023', 'count': 7}
# {'_id': '04/08/2023', 'count': 7}
# {'_id': '14/01/2023', 'count': 7}
# {'_id': '02/07/2023', 'count': 7}
# {'_id': '30/05/2023', 'count': 7}
# {'_id': '31/05/2023', 'count': 7}
# {'_id': '07/02/2023', 'count': 7}
# {'_id': '28/07/2023', 'count': 7}
# {'_id': '24/07/2023', 'count': 7}
# {'_id': '28/06/2023', 'count': 7}
# {'_id': '14/08/2023', 'count': 7}
# {'_id': '05/03/2023', 'count': 7}
# {'_id': '06/03/2023', 'count': 7}
# {'_id': '31/10/2023', 'count': 7}
# {'_id': '15/12/2023', 'count': 7}
# {'_id': '21/12/2023', 'count': 7}
# {'_id': '25/02/2023', 'count': 7}
# {'_id': '18/04/2023', 'count': 7}
# {'_id': '12/09/2023', 'count': 7}
# {'_id': '29/11/2023', 'count': 7}
# {'_id': '05/01/2023', 'count': 7}
# {'_id': '21/04/2023', 'count': 7}
# {'_id': '09/07/2023', 'count': 7}
# {'_id': '18/12/2023', 'count': 7}
# {'_id': '26/10/2023', 'count': 7}
# {'_id': '09/06/2023', 'count': 7}
# {'_id': '24/03/2023', 'count': 7}
# {'_id': '30/09/2023', 'count': 7}
# {'_id': '08/07/2023', 'count': 7}
# {'_id': '30/07/2023', 'count': 7}
# {'_id': '27/10/2023', 'count': 7}
# {'_id': '10/12/2023', 'count': 7}
# {'_id': '08/01/2023', 'count': 7}
# {'_id': '29/12/2023', 'count': 7}
# {'_id': '10/06/2023', 'count': 7}
# {'_id': '28/03/2023', 'count': 7}
# {'_id': '22/05/2023', 'count': 7}
# {'_id': '31/01/2023', 'count': 7}
# {'_id': '12/07/2023', 'count': 7}
# {'_id': '27/07/2023', 'count': 7}
# {'_id': '07/11/2023', 'count': 7}
# {'_id': '14/10/2023', 'count': 7}
# {'_id': '20/10/2023', 'count': 7}
# {'_id': '23/06/2023', 'count': 7}
# {'_id': '03/08/2023', 'count': 7}
# {'_id': '13/01/2023', 'count': 7}
# {'_id': '23/08/2023', 'count': 7}
# {'_id': '25/09/2023', 'count': 7}
# {'_id': '20/06/2023', 'count': 7}
# {'_id': '25/11/2023', 'count': 7}
# {'_id': '09/12/2023', 'count': 7}
# {'_id': '23/12/2023', 'count': 7}
# {'_id': '02/02/2023', 'count': 7}
# {'_id': '12/02/2023', 'count': 7}
# {'_id': '17/02/2023', 'count': 7}
# {'_id': '09/05/2023', 'count': 7}
# {'_id': '12/10/2023', 'count': 7}
# {'_id': '29/03/2023', 'count': 7}
# {'_id': '09/04/2023', 'count': 7}
# {'_id': '01/09/2023', 'count': 7}
# {'_id': '04/04/2023', 'count': 7}
# {'_id': '23/05/2023', 'count': 7}
# {'_id': '22/06/2023', 'count': 7}
# {'_id': '12/11/2023', 'count': 7}
# {'_id': '23/04/2023', 'count': 7}
# {'_id': '13/11/2023', 'count': 7}
# {'_id': '12/05/2023', 'count': 7}
# {'_id': '23/11/2023', 'count': 7}
# {'_id': '31/12/2022', 'count': 7}
# {'_id': '04/12/2023', 'count': 7}
# {'_id': '08/02/2023', 'count': 7}
# {'_id': '06/11/2023', 'count': 7}
# {'_id': '23/02/2023', 'count': 7}
# {'_id': '19/09/2023', 'count': 7}
# {'_id': '05/05/2023', 'count': 7}
# {'_id': '09/08/2023', 'count': 7}
# {'_id': '25/04/2023', 'count': 7}
# {'_id': '07/06/2023', 'count': 7}
# {'_id': '05/10/2023', 'count': 7}
# {'_id': '18/05/2023', 'count': 7}
# {'_id': '13/07/2023', 'count': 7}
# {'_id': '12/01/2023', 'count': 7}
# {'_id': '18/08/2023', 'count': 7}
# {'_id': '21/05/2023', 'count': 7}
# {'_id': '19/12/2023', 'count': 7}
# {'_id': '24/11/2023', 'count': 7}
# {'_id': '16/01/2023', 'count': 7}
# {'_id': '02/10/2023', 'count': 7}
# {'_id': '14/04/2023', 'count': 7}
# {'_id': '11/07/2023', 'count': 7}
# {'_id': '26/07/2023', 'count': 7}
# {'_id': '24/06/2023', 'count': 7}
# {'_id': '05/02/2023', 'count': 7}
# {'_id': '05/07/2023', 'count': 7}
# {'_id': '15/01/2023', 'count': 7}
# {'_id': '25/06/2023', 'count': 7}
# {'_id': '15/09/2023', 'count': 7}
# {'_id': '16/11/2023', 'count': 7}
# {'_id': '08/10/2023', 'count': 7}
# {'_id': '18/11/2023', 'count': 7}
# {'_id': '22/12/2023', 'count': 7}
# {'_id': '16/07/2023', 'count': 7}
# {'_id': '25/01/2023', 'count': 7}
# {'_id': '09/02/2023', 'count': 7}
# {'_id': '02/11/2023', 'count': 7}
# {'_id': '26/06/2023', 'count': 7}
# {'_id': '21/10/2023', 'count': 7}
# {'_id': '01/03/2023', 'count': 7}
# {'_id': '06/12/2023', 'count': 7}
# {'_id': '20/02/2023', 'count': 7}
# {'_id': '06/02/2023', 'count': 7}
# {'_id': '22/10/2023', 'count': 7}
# {'_id': '19/11/2023', 'count': 7}
# {'_id': '26/11/2023', 'count': 7}
# {'_id': '13/12/2023', 'count': 7}
# {'_id': '27/03/2023', 'count': 7}
# {'_id': '27/12/2023', 'count': 7}
# {'_id': '28/09/2023', 'count': 7}
# {'_id': '26/09/2023', 'count': 7}
# {'_id': '04/11/2023', 'count': 7}
# {'_id': '20/03/2023', 'count': 7}
# {'_id': '01/12/2023', 'count': 7}
# {'_id': '24/02/2023', 'count': 7}
# {'_id': '27/05/2023', 'count': 7}
# {'_id': '11/08/2023', 'count': 7}
# {'_id': '18/03/2023', 'count': 7}
# {'_id': '01/07/2023', 'count': 7}
# {'_id': '13/08/2023', 'count': 7}
# {'_id': '30/08/2023', 'count': 7}
# {'_id': '01/01/2024', 'count': 7}
# {'_id': '27/11/2023', 'count': 7}
# {'_id': '23/03/2023', 'count': 7}
# {'_id': '18/10/2023', 'count': 7}
# {'_id': '02/03/2023', 'count': 7}
# {'_id': '03/07/2023', 'count': 7}
# {'_id': '16/03/2023', 'count': 7}
# {'_id': '18/02/2023', 'count': 7}
# {'_id': '02/08/2023', 'count': 7}
# {'_id': '01/08/2023', 'count': 7}
# {'_id': '10/09/2023', 'count': 7}
# {'_id': '11/05/2023', 'count': 7}
# {'_id': '30/01/2023', 'count': 7}
# {'_id': '14/06/2023', 'count': 7}
# {'_id': '17/12/2023', 'count': 7}
# {'_id': '16/08/2023', 'count': 7}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question g
"""

#Fires records = fields from array field -> pipeline
pipeline = [
    {
        '$unwind': '$hotspots'  # Unwind the hotspots array
    },
    {
        '$match': {
            'hotspots.confidence': {
                '$lt': 70  # Match documents where confidence is less than 70
            }
        }
    },
    {
        '$project': {
            #Just Fire records
            '_id': 0,
            'confidence': '$hotspots.confidence',  
            'date': '$hotspots.date',  
            'datetime': '$hotspots.datetime',  
            'latitude': '$hotspots.latitude',  
            'longitude': '$hotspots.longitude', 
            'surface_temperature_celcius': '$hotspots.surface_temperature_celcius'
        }
    }
]

res = collection.aggregate(pipeline)
for i, d in enumerate(res):
    pprint(d)
# Out:
# {'confidence': 62,
#  'date': '16/10/2023',
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'date': '17/10/2023',
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'date': '20/10/2023',
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'date': '21/10/2023',
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'date': '27/10/2023',
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '11/11/2023',
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'date': '28/11/2023',
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'date': '12/12/2023',
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'date': '24/12/2023',
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'date': '27/12/2023',
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'date': '16/10/2023',
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'date': '17/10/2023',
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'date': '20/10/2023',
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'date': '21/10/2023',
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'date': '27/10/2023',
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '11/11/2023',
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'date': '28/11/2023',
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'date': '12/12/2023',
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'date': '24/12/2023',
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'date': '27/12/2023',
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'date': '16/10/2023',
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'date': '17/10/2023',
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'date': '20/10/2023',
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'date': '21/10/2023',
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'date': '27/10/2023',
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '11/11/2023',
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'date': '28/11/2023',
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'date': '12/12/2023',
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'date': '24/12/2023',
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'date': '27/12/2023',
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'date': '16/10/2023',
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'date': '17/10/2023',
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'date': '20/10/2023',
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'date': '21/10/2023',
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'date': '27/10/2023',
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '11/11/2023',
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'date': '28/11/2023',
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'date': '12/12/2023',
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'date': '24/12/2023',
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'date': '27/12/2023',
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'date': '16/10/2023',
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'date': '17/10/2023',
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'date': '20/10/2023',
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'date': '21/10/2023',
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'date': '27/10/2023',
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '11/11/2023',
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'date': '28/11/2023',
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'date': '12/12/2023',
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'date': '24/12/2023',
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'date': '27/12/2023',
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'date': '16/10/2023',
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'date': '17/10/2023',
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'date': '20/10/2023',
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'date': '21/10/2023',
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'date': '27/10/2023',
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '11/11/2023',
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'date': '28/11/2023',
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'date': '12/12/2023',
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'date': '24/12/2023',
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'date': '27/12/2023',
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'date': '16/10/2023',
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'date': '17/10/2023',
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'date': '20/10/2023',
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'date': '21/10/2023',
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '26/10/2023',
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'date': '27/10/2023',
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '11/11/2023',
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'date': '12/11/2023',
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'date': '13/11/2023',
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'date': '14/11/2023',
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'date': '23/11/2023',
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'date': '28/11/2023',
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'date': '29/11/2023',
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'date': '30/11/2023',
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'date': '10/12/2023',
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'date': '12/12/2023',
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'date': '15/12/2023',
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'date': '16/12/2023',
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'date': '24/12/2023',
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'date': '27/12/2023',
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question h
"""

pipeline = [
    {
        '$unwind': '$hotspots' 
    },
    {
        '$group': {
            #_id must exist in $group can be replaced
            '_id': '$hotspots.date',  # group by the date field from hotspots
            'avg_surface_temperature': {
                '$avg': '$hotspots.surface_temperature_celcius' 
            }
        }
    },
    {   #modify the project of the output after all above processing
        '$project': {
            '_id': 0,  # Exclude the _id field
            'date': '$_id',  # Map the _id field (which is the date) to 'date' in the output
            'avg_surface_temperature': 1  # 
        }
    },
    {
        '$sort': {'date': 1}  # Optional: sort by date
    }
]

res = collection.aggregate(pipeline)
for d in res:
    print(d)
# Out:
# {'avg_surface_temperature': 53.333333333333336, 'date': '10/10/2023'}
# {'avg_surface_temperature': 46.0, 'date': '10/12/2023'}
# {'avg_surface_temperature': 46.25, 'date': '11/11/2023'}
# {'avg_surface_temperature': 53.0, 'date': '12/11/2023'}
# {'avg_surface_temperature': 44.0, 'date': '12/12/2023'}
# {'avg_surface_temperature': 47.0, 'date': '13/11/2023'}
# {'avg_surface_temperature': 60.0, 'date': '13/12/2023'}
# {'avg_surface_temperature': 52.0, 'date': '14/11/2023'}
# {'avg_surface_temperature': 70.0, 'date': '14/12/2023'}
# {'avg_surface_temperature': 72.66666666666667, 'date': '15/10/2023'}
# {'avg_surface_temperature': 39.0, 'date': '15/12/2023'}
# {'avg_surface_temperature': 36.0, 'date': '16/10/2023'}
# {'avg_surface_temperature': 57.8, 'date': '16/12/2023'}
# {'avg_surface_temperature': 51.6, 'date': '17/10/2023'}
# {'avg_surface_temperature': 52.166666666666664, 'date': '18/10/2023'}
# {'avg_surface_temperature': 50.0, 'date': '20/10/2023'}
# {'avg_surface_temperature': 51.25, 'date': '21/10/2023'}
# {'avg_surface_temperature': 59.0, 'date': '21/11/2023'}
# {'avg_surface_temperature': 46.0, 'date': '21/12/2023'}
# {'avg_surface_temperature': 61.5, 'date': '22/11/2023'}
# {'avg_surface_temperature': 38.0, 'date': '23/10/2023'}
# {'avg_surface_temperature': 58.8, 'date': '23/11/2023'}
# {'avg_surface_temperature': 32.0, 'date': '24/12/2023'}
# {'avg_surface_temperature': 54.0, 'date': '25/12/2023'}
# {'avg_surface_temperature': 44.6, 'date': '26/10/2023'}
# {'avg_surface_temperature': 50.4, 'date': '27/10/2023'}
# {'avg_surface_temperature': 62.75, 'date': '27/12/2023'}
# {'avg_surface_temperature': 56.0, 'date': '28/10/2023'}
# {'avg_surface_temperature': 42.0, 'date': '28/11/2023'}
# {'avg_surface_temperature': 60.625, 'date': '29/11/2023'}
# {'avg_surface_temperature': 52.41935483870968, 'date': '30/11/2023'}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question i
"""
# sort all by field 'GHI_w/m2' count for 10, -1 decending
res = collection.find().sort('GHI_w/m2', -1).limit(10)

for d in res:
    pprint(d)
# Out:
# {'GHI_w/m2': 265,
#  '_id': ObjectId('664315e97ee68a2c20b02d26'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('66449f08ad0ed5632f7d61e5'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('6644a37f2c62191bee0dd5dd'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('66431c8d7a9d7e37c83ed2ea'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('664315f37ee68a2c20b02e95'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('6643202e06cf726385f32254'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('66420d6b9e89db15968a9dd9'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'stations': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('664315ec7ee68a2c20b02e5d'),
#  'air_temperature_celcius': 28,
#  'date': '14/11/2023',
#  'hotspots': [{'confidence': 87,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 04:35:04',
#                'latitude': -37.862,
#                'longitude': 144.175,
#                'surface_temperature_celcius': 65},
#               {'confidence': 64,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 00:21:26',
#                'latitude': -38.527,
#                'longitude': 143.493,
#                'surface_temperature_celcius': 45},
#               {'confidence': 64,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 00:21:07',
#                'latitude': -37.332,
#                'longitude': 143.375,
#                'surface_temperature_celcius': 46}],
#  'max_wind_speed': 22.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 48.3,
#  'stations': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('6643203206cf726385f3238b'),
#  'air_temperature_celcius': 28,
#  'date': '14/11/2023',
#  'hotspots': [{'confidence': 87,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 04:35:04',
#                'latitude': -37.862,
#                'longitude': 144.175,
#                'surface_temperature_celcius': 65},
#               {'confidence': 64,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 00:21:26',
#                'latitude': -38.527,
#                'longitude': 143.493,
#                'surface_temperature_celcius': 45},
#               {'confidence': 64,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 00:21:07',
#                'latitude': -37.332,
#                'longitude': 143.375,
#                'surface_temperature_celcius': 46}],
#  'max_wind_speed': 22.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 48.3,
#  'stations': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('66431c927a9d7e37c83ed421'),
#  'air_temperature_celcius': 28,
#  'date': '14/11/2023',
#  'hotspots': [{'confidence': 87,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 04:35:04',
#                'latitude': -37.862,
#                'longitude': 144.175,
#                'surface_temperature_celcius': 65},
#               {'confidence': 64,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 00:21:26',
#                'latitude': -38.527,
#                'longitude': 143.493,
#                'surface_temperature_celcius': 45},
#               {'confidence': 64,
#                'date': '14/11/2023',
#                'datetime': '2023-11-14 00:21:07',
#                'latitude': -37.332,
#                'longitude': 143.375,
#                'surface_temperature_celcius': 46}],
#  'max_wind_speed': 22.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 48.3,
#  'stations': 948702,
#  'windspeed_knots': 11.9}

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question j
"""
#main document aggregate piepeline
pipeline = [
    {
        '$match':{
            'precipitation':{
                '$gte': 0.2,
                '$lte': 0.35
            }
        }
    },
    {
        '$project':{   
            '_id': 0,
            'date': 1,
            'precipitation': 1
        }
    }
]

res = collection.aggregate(pipeline)
for d in res:
    pprint(d)

# %%
"""
Part A
Task 2. Querying MongoDBusingPyMongo
Question 3
"""

# Assuming 'db' is your MongoDB database object and 'climate_data' is your collection.
db.climate_data.create_index([
    ('date', pymongo.ASCENDING),
    ('station', pymongo.ASCENDING)
])
# Out:
# 'date_1_station_1'

# %% [markdown]
# # since there is station for each day, with the compound index of date and station, we can efficiently access the data from climate, and the hotspots related to that date are limited, which can be further filtered with the locations of the hotspots by clutering.

# %%
# # Query the collection using the compound index

# All documents for station 948700 on January 1, 2023
results = collection.find({
    'date': '31/12/2023',
    'station': 948700
})

# Process the results
for doc in results:
    pprint(doc)

# %%
"""
Part b
Task 1. Processing Data Stream (45%)
Question a
"""
from datetime import datetime, timedelta

#res = collection.find().sort('surface_temperature_celcius', pymongo.DESCENDING).limit(10)
res = collection.find().sort('date', pymongo.DESCENDING).limit(1)

for d in res:
    res = d
#     print(d)

latest_date = res['date']
#string to datetime object
# latest_date = datetime.strptime(latest_date, '%Y-%m-%d %H:%M:%S')
#string to datetime object
latest_date = datetime.strptime(latest_date, '%d/%m/%Y')
start_date = latest_date + timedelta(days=1)
print(start_date)
# Out:
# 2024-01-01 00:00:00

# %%
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import json

hostip = "172.16.55.43" # change it to your IP

def connect_kafka_producer():
    producer = None
    
    try:
        producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],api_version=(0,10))
    
    except Exception as ex:
        print("Exception while connecting Kafka")
        print(str(ex))
    finally:
        return producer 
    
def publish_msg(producer, topic, data):
    try:
        #print(data)        #send the  value by dumps to JSON object
                            #then encode with utf-8 into bytes
        value_bytes = json.dumps(data).encode('utf-8')
        producer.send(topic, value=value_bytes)
        #print(data)
        """
        The flush() method in Kafka’s producer API is used to ensure that all 
        previously sent messages have been transmitted to the server and acknowledged 
        before proceeding. When you call flush(), it blocks the current thread and waits 
        for the producer to complete the sending of all records
        """
        producer.flush()  
    except Exception as ex:
        print('Exception from publish_msg func')
        print(str(ex))

# %%
"""
Event Producer 1
"""
climate_stream_csv = pd.read_csv("./climate_streaming.csv", sep=',')
climate_stream_csv.head()
# Out:
#    latitude  longitude  air_temperature_celcius  relative_humidity  \
# 0   -37.623    149.323                       19               56.8
# 1   -38.038    142.986                       15               50.7
# 2   -37.950    142.366                       16               53.6
# 3   -38.231    147.172                       24               61.6
# 4   -37.903    145.250                       24               62.3
#
#    windspeed_knots  max_wind_speed precipitation  GHI_w/m2
# 0              7.9            11.1         0.00I       154
# 1              9.2            13.0         0.02G       128
# 2              8.1            15.0         0.00G       133
# 3              7.7            14.0         0.00I       186
# 4              7.0            13.0         0.00I       185

# %%
"""
Main Function
"""

if __name__ == '__main__':
    topic = 'Scenaries01'
    print('Publishing records..')
    producer01 = connect_kafka_producer()


    # Assuming 'climate' is your DataFrame
    #print(len(climate.index))
    rand_row_indices = list(range(len(climate.index)))
    random.shuffle(rand_row_indices)  
    #print(len(indices))

    for index, climate_row in climate_stream_csv.iterrows():
        climate_row = climate_stream_csv.loc[rand_row_indices[index]]

        #inner-join
    #     if fires_list:
            #print(fires_list)

        #left-outer join
        #print(start_date.strftime('%Y-%m-%d'))
        climate_doc = {
                                        #string from time with format, 
                                        #since MongoDB can not store object
            #.strftime('%d/%m/%Y')
            #convert datetime object to string in format
            # laster dumps not work on datetime object but number of string
            'latitude': float(climate_row['latitude']),
            'longtitude': float(climate_row['longitude']),
            'air_temperature_celcius': int(climate_row['air_temperature_celcius']),
            'relative_humidity': float(climate_row['relative_humidity']),
            'windspeed_knots': float(climate_row['windspeed_knots']),
            'max_wind_speed': float(climate_row['max_wind_speed']),
            #'precipitation ' blank space count as char in csv column
            # get to do try except, return None if column not exist
            #'precipitation ': str(climate_row.get(['precipitation '])),
            #'precipitation': str(climate_row.get(['precipitation'])),
            'precipitation': str(climate_row['precipitation']),
            'GHI_w/m2': int(climate_row['GHI_w/m2']),
            'producer': "Producer_1",
            'date': start_date.strftime('%Y-%m-%d')

        }
        #update start date
        #print(climate_doc['date'])
        #producer publish msg in strictured streaming
        # convert the dictionary to JSON-formatted string and encode as UFT-8 by publish_msg
        # msg = json.dumps(climate_doc)
        print(climate_doc)
        publish_msg(producer01, topic, climate_doc)
        start_date += timedelta(days=1)
        # change to 1 for debugging
        sleep(1)
        #sleep(10) # every 10 seconds send
# Out:
# Publishing records..
# {'latitude': -37.013, 'longtitude': 141.5355, 'air_temperature_celcius': 10, 'relative_humidity': 44.1, 'windspeed_knots': 7.3, 'max_wind_speed': 12.0, 'precipitation': ' 0.39G', 'GHI_w/m2': 90, 'producer': 'Producer_1', 'date': '2024-01-01'}
# {'latitude': -36.94, 'longtitude': 143.281, 'air_temperature_celcius': 21, 'relative_humidity': 52.8, 'windspeed_knots': 4.1, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 176, 'producer': 'Producer_1', 'date': '2024-01-02'}
# {'latitude': -36.404, 'longtitude': 142.5467, 'air_temperature_celcius': 25, 'relative_humidity': 60.9, 'windspeed_knots': 6.3, 'max_wind_speed': 8.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 195, 'producer': 'Producer_1', 'date': '2024-01-03'}
# {'latitude': -37.436, 'longtitude': 148.088, 'air_temperature_celcius': 15, 'relative_humidity': 41.5, 'windspeed_knots': 17.0, 'max_wind_speed': 28.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 138, 'producer': 'Producer_1', 'date': '2024-01-04'}
# {'latitude': -36.941, 'longtitude': 143.268, 'air_temperature_celcius': 23, 'relative_humidity': 63.8, 'windspeed_knots': 7.1, 'max_wind_speed': 15.9, 'precipitation': ' 0.08G', 'GHI_w/m2': 174, 'producer': 'Producer_1', 'date': '2024-01-05'}
# {'latitude': -37.463, 'longtitude': 148.109, 'air_temperature_celcius': 11, 'relative_humidity': 45.1, 'windspeed_knots': 5.6, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 98, 'producer': 'Producer_1', 'date': '2024-01-06'}
# {'latitude': -37.471, 'longtitude': 148.091, 'air_temperature_celcius': 9, 'relative_humidity': 40.8, 'windspeed_knots': 6.7, 'max_wind_speed': 15.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 83, 'producer': 'Producer_1', 'date': '2024-01-07'}
# {'latitude': -37.627, 'longtitude': 149.261, 'air_temperature_celcius': 26, 'relative_humidity': 53.7, 'windspeed_knots': 8.7, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 216, 'producer': 'Producer_1', 'date': '2024-01-08'}
# {'latitude': -34.965, 'longtitude': 142.031, 'air_temperature_celcius': 20, 'relative_humidity': 62.6, 'windspeed_knots': 10.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 153, 'producer': 'Producer_1', 'date': '2024-01-09'}
# {'latitude': -37.59, 'longtitude': 149.31, 'air_temperature_celcius': 19, 'relative_humidity': 57.2, 'windspeed_knots': 8.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.98G', 'GHI_w/m2': 153, 'producer': 'Producer_1', 'date': '2024-01-10'}
# {'latitude': -37.296, 'longtitude': 144.386, 'air_temperature_celcius': 11, 'relative_humidity': 40.8, 'windspeed_knots': 12.2, 'max_wind_speed': 20.0, 'precipitation': ' 0.24G', 'GHI_w/m2': 102, 'producer': 'Producer_1', 'date': '2024-01-11'}
# {'latitude': -37.618, 'longtitude': 143.0013, 'air_temperature_celcius': 14, 'relative_humidity': 36.0, 'windspeed_knots': 15.9, 'max_wind_speed': 22.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 134, 'producer': 'Producer_1', 'date': '2024-01-12'}
# {'latitude': -37.446, 'longtitude': 148.102, 'air_temperature_celcius': 10, 'relative_humidity': 39.4, 'windspeed_knots': 9.6, 'max_wind_speed': 14.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 93, 'producer': 'Producer_1', 'date': '2024-01-13'}
# {'latitude': -37.1875, 'longtitude': 146.8024, 'air_temperature_celcius': 28, 'relative_humidity': 58.3, 'windspeed_knots': 9.3, 'max_wind_speed': 15.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 223, 'producer': 'Producer_1', 'date': '2024-01-14'}
# {'latitude': -36.3114, 'longtitude': 142.7605, 'air_temperature_celcius': 28, 'relative_humidity': 56.7, 'windspeed_knots': 9.3, 'max_wind_speed': 16.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 227, 'producer': 'Producer_1', 'date': '2024-01-15'}
# {'latitude': -37.6593, 'longtitude': 143.3445, 'air_temperature_celcius': 9, 'relative_humidity': 40.1, 'windspeed_knots': 12.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.08G', 'GHI_w/m2': 84, 'producer': 'Producer_1', 'date': '2024-01-16'}
# {'latitude': -37.6, 'longtitude': 149.297, 'air_temperature_celcius': 22, 'relative_humidity': 53.4, 'windspeed_knots': 10.9, 'max_wind_speed': 19.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 183, 'producer': 'Producer_1', 'date': '2024-01-17'}
# {'latitude': -37.856, 'longtitude': 143.416, 'air_temperature_celcius': 14, 'relative_humidity': 51.0, 'windspeed_knots': 9.1, 'max_wind_speed': 12.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 119, 'producer': 'Producer_1', 'date': '2024-01-18'}
# {'latitude': -36.2212, 'longtitude': 143.1666, 'air_temperature_celcius': 11, 'relative_humidity': 44.2, 'windspeed_knots': 5.8, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 99, 'producer': 'Producer_1', 'date': '2024-01-19'}
# {'latitude': -37.591, 'longtitude': 149.33, 'air_temperature_celcius': 16, 'relative_humidity': 46.7, 'windspeed_knots': 10.0, 'max_wind_speed': 16.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 141, 'producer': 'Producer_1', 'date': '2024-01-20'}
# {'latitude': -36.156, 'longtitude': 143.568, 'air_temperature_celcius': 13, 'relative_humidity': 51.4, 'windspeed_knots': 4.6, 'max_wind_speed': 8.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 110, 'producer': 'Producer_1', 'date': '2024-01-21'}
# {'latitude': -37.58, 'longtitude': 149.331, 'air_temperature_celcius': 23, 'relative_humidity': 59.0, 'windspeed_knots': 6.0, 'max_wind_speed': 12.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 182, 'producer': 'Producer_1', 'date': '2024-01-22'}
# {'latitude': -37.367, 'longtitude': 148.04, 'air_temperature_celcius': 12, 'relative_humidity': 47.6, 'windspeed_knots': 9.1, 'max_wind_speed': 13.0, 'precipitation': ' 0.12G', 'GHI_w/m2': 105, 'producer': 'Producer_1', 'date': '2024-01-23'}
# {'latitude': -37.605, 'longtitude': 149.308, 'air_temperature_celcius': 13, 'relative_humidity': 48.5, 'windspeed_knots': 10.7, 'max_wind_speed': 14.0, 'precipitation': ' 0.71G', 'GHI_w/m2': 113, 'producer': 'Producer_1', 'date': '2024-01-24'}
# {'latitude': -36.942, 'longtitude': 143.292, 'air_temperature_celcius': 18, 'relative_humidity': 51.1, 'windspeed_knots': 8.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 153, 'producer': 'Producer_1', 'date': '2024-01-25'}
# {'latitude': -37.61, 'longtitude': 149.307, 'air_temperature_celcius': 18, 'relative_humidity': 55.5, 'windspeed_knots': 8.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 147, 'producer': 'Producer_1', 'date': '2024-01-26'}
# {'latitude': -37.0046, 'longtitude': 141.8047, 'air_temperature_celcius': 10, 'relative_humidity': 41.4, 'windspeed_knots': 6.9, 'max_wind_speed': 8.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 92, 'producer': 'Producer_1', 'date': '2024-01-27'}
# {'latitude': -37.475, 'longtitude': 148.134, 'air_temperature_celcius': 8, 'relative_humidity': 43.1, 'windspeed_knots': 3.4, 'max_wind_speed': 7.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 73, 'producer': 'Producer_1', 'date': '2024-01-28'}
# {'latitude': -37.434, 'longtitude': 148.091, 'air_temperature_celcius': 9, 'relative_humidity': 40.0, 'windspeed_knots': 8.6, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 84, 'producer': 'Producer_1', 'date': '2024-01-29'}
# {'latitude': -36.3096, 'longtitude': 142.7722, 'air_temperature_celcius': 24, 'relative_humidity': 56.8, 'windspeed_knots': 5.7, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 194, 'producer': 'Producer_1', 'date': '2024-01-30'}
# {'latitude': -37.602, 'longtitude': 149.311, 'air_temperature_celcius': 14, 'relative_humidity': 48.5, 'windspeed_knots': 7.3, 'max_wind_speed': 14.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 122, 'producer': 'Producer_1', 'date': '2024-01-31'}
# {'latitude': -36.6851, 'longtitude': 141.6125, 'air_temperature_celcius': 17, 'relative_humidity': 59.0, 'windspeed_knots': 9.4, 'max_wind_speed': 15.0, 'precipitation': ' 0.75G', 'GHI_w/m2': 135, 'producer': 'Producer_1', 'date': '2024-02-01'}
# {'latitude': -35.364, 'longtitude': 141.063, 'air_temperature_celcius': 15, 'relative_humidity': 51.9, 'windspeed_knots': 6.6, 'max_wind_speed': 12.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 127, 'producer': 'Producer_1', 'date': '2024-02-02'}
# {'latitude': -37.34, 'longtitude': 143.123, 'air_temperature_celcius': 19, 'relative_humidity': 52.8, 'windspeed_knots': 12.5, 'max_wind_speed': 21.0, 'precipitation': ' 0.47G', 'GHI_w/m2': 159, 'producer': 'Producer_1', 'date': '2024-02-03'}
# {'latitude': -37.247, 'longtitude': 141.278, 'air_temperature_celcius': 14, 'relative_humidity': 47.4, 'windspeed_knots': 7.1, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 123, 'producer': 'Producer_1', 'date': '2024-02-04'}
# {'latitude': -36.5243, 'longtitude': 142.0839, 'air_temperature_celcius': 9, 'relative_humidity': 43.9, 'windspeed_knots': 5.7, 'max_wind_speed': 9.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 81, 'producer': 'Producer_1', 'date': '2024-02-05'}
# {'latitude': -37.0745, 'longtitude': 141.0692, 'air_temperature_celcius': 9, 'relative_humidity': 40.4, 'windspeed_knots': 6.9, 'max_wind_speed': 9.9, 'precipitation': ' 0.02G', 'GHI_w/m2': 83, 'producer': 'Producer_1', 'date': '2024-02-06'}
# {'latitude': -37.452, 'longtitude': 148.115, 'air_temperature_celcius': 8, 'relative_humidity': 43.8, 'windspeed_knots': 7.3, 'max_wind_speed': 14.0, 'precipitation': ' 0.08G', 'GHI_w/m2': 72, 'producer': 'Producer_1', 'date': '2024-02-07'}
# {'latitude': -35.957, 'longtitude': 141.088, 'air_temperature_celcius': 9, 'relative_humidity': 42.4, 'windspeed_knots': 7.2, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 82, 'producer': 'Producer_1', 'date': '2024-02-08'}
# {'latitude': -37.954, 'longtitude': 143.918, 'air_temperature_celcius': 20, 'relative_humidity': 59.7, 'windspeed_knots': 8.6, 'max_wind_speed': 15.9, 'precipitation': ' 0.01G', 'GHI_w/m2': 158, 'producer': 'Producer_1', 'date': '2024-02-09'}
# {'latitude': -37.091, 'longtitude': 145.362, 'air_temperature_celcius': 12, 'relative_humidity': 48.8, 'windspeed_knots': 4.2, 'max_wind_speed': 7.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 104, 'producer': 'Producer_1', 'date': '2024-02-10'}
# {'latitude': -36.0005, 'longtitude': 143.1847, 'air_temperature_celcius': 17, 'relative_humidity': 52.5, 'windspeed_knots': 7.7, 'max_wind_speed': 16.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 143, 'producer': 'Producer_1', 'date': '2024-02-11'}
# {'latitude': -36.098, 'longtitude': 143.735, 'air_temperature_celcius': 17, 'relative_humidity': 58.1, 'windspeed_knots': 11.7, 'max_wind_speed': 19.0, 'precipitation': ' 0.04G', 'GHI_w/m2': 136, 'producer': 'Producer_1', 'date': '2024-02-12'}
# {'latitude': -37.434, 'longtitude': 148.123, 'air_temperature_celcius': 14, 'relative_humidity': 43.7, 'windspeed_knots': 17.0, 'max_wind_speed': 27.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 126, 'producer': 'Producer_1', 'date': '2024-02-13'}
# {'latitude': -35.892, 'longtitude': 145.62, 'air_temperature_celcius': 10, 'relative_humidity': 42.6, 'windspeed_knots': 8.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.04G', 'GHI_w/m2': 91, 'producer': 'Producer_1', 'date': '2024-02-14'}
# {'latitude': -37.293, 'longtitude': 141.245, 'air_temperature_celcius': 10, 'relative_humidity': 45.7, 'windspeed_knots': 3.7, 'max_wind_speed': 8.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 89, 'producer': 'Producer_1', 'date': '2024-02-15'}
# {'latitude': -37.288, 'longtitude': 144.39, 'air_temperature_celcius': 12, 'relative_humidity': 49.9, 'windspeed_knots': 6.1, 'max_wind_speed': 13.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 103, 'producer': 'Producer_1', 'date': '2024-02-16'}
# {'latitude': -37.0585, 'longtitude': 143.8589, 'air_temperature_celcius': 19, 'relative_humidity': 59.7, 'windspeed_knots': 7.4, 'max_wind_speed': 14.0, 'precipitation': ' 0.63G', 'GHI_w/m2': 150, 'producer': 'Producer_1', 'date': '2024-02-17'}
# {'latitude': -37.236, 'longtitude': 141.176, 'air_temperature_celcius': 14, 'relative_humidity': 48.1, 'windspeed_knots': 13.7, 'max_wind_speed': 19.0, 'precipitation': ' 0.35G', 'GHI_w/m2': 122, 'producer': 'Producer_1', 'date': '2024-02-18'}
# {'latitude': -37.61, 'longtitude': 149.279, 'air_temperature_celcius': 20, 'relative_humidity': 57.4, 'windspeed_knots': 10.9, 'max_wind_speed': 22.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 161, 'producer': 'Producer_1', 'date': '2024-02-19'}
# {'latitude': -37.587, 'longtitude': 142.479, 'air_temperature_celcius': 12, 'relative_humidity': 45.1, 'windspeed_knots': 11.9, 'max_wind_speed': 18.1, 'precipitation': ' 0.16G', 'GHI_w/m2': 107, 'producer': 'Producer_1', 'date': '2024-02-20'}
# {'latitude': -37.379, 'longtitude': 148.126, 'air_temperature_celcius': 9, 'relative_humidity': 42.9, 'windspeed_knots': 8.9, 'max_wind_speed': 15.9, 'precipitation': ' 0.12G', 'GHI_w/m2': 82, 'producer': 'Producer_1', 'date': '2024-02-21'}
# {'latitude': -35.953, 'longtitude': 141.078, 'air_temperature_celcius': 12, 'relative_humidity': 47.2, 'windspeed_knots': 8.8, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 105, 'producer': 'Producer_1', 'date': '2024-02-22'}
# {'latitude': -36.779, 'longtitude': 146.108, 'air_temperature_celcius': 15, 'relative_humidity': 51.0, 'windspeed_knots': 9.6, 'max_wind_speed': 15.9, 'precipitation': ' 0.16G', 'GHI_w/m2': 128, 'producer': 'Producer_1', 'date': '2024-02-23'}
# {'latitude': -36.2032, 'longtitude': 145.3025, 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'windspeed_knots': 7.1, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 152, 'producer': 'Producer_1', 'date': '2024-02-24'}
# {'latitude': -37.485, 'longtitude': 148.095, 'air_temperature_celcius': 11, 'relative_humidity': 45.4, 'windspeed_knots': 5.2, 'max_wind_speed': 8.9, 'precipitation': ' 0.00A', 'GHI_w/m2': 98, 'producer': 'Producer_1', 'date': '2024-02-25'}
# {'latitude': -36.6516, 'longtitude': 141.4943, 'air_temperature_celcius': 11, 'relative_humidity': 45.3, 'windspeed_knots': 8.5, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 98, 'producer': 'Producer_1', 'date': '2024-02-26'}
# {'latitude': -37.4551, 'longtitude': 143.7902, 'air_temperature_celcius': 9, 'relative_humidity': 37.9, 'windspeed_knots': 9.1, 'max_wind_speed': 15.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 85, 'producer': 'Producer_1', 'date': '2024-02-27'}
# {'latitude': -36.0459, 'longtitude': 143.8907, 'air_temperature_celcius': 21, 'relative_humidity': 58.7, 'windspeed_knots': 7.8, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 167, 'producer': 'Producer_1', 'date': '2024-02-28'}
# {'latitude': -36.939, 'longtitude': 143.28, 'air_temperature_celcius': 20, 'relative_humidity': 67.4, 'windspeed_knots': 8.5, 'max_wind_speed': 14.0, 'precipitation': ' 0.63G', 'GHI_w/m2': 147, 'producer': 'Producer_1', 'date': '2024-02-29'}
# {'latitude': -36.282, 'longtitude': 146.157, 'air_temperature_celcius': 17, 'relative_humidity': 50.4, 'windspeed_knots': 11.9, 'max_wind_speed': 16.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 145, 'producer': 'Producer_1', 'date': '2024-03-01'}
# {'latitude': -37.8072, 'longtitude': 142.2406, 'air_temperature_celcius': 12, 'relative_humidity': 44.2, 'windspeed_knots': 6.2, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 108, 'producer': 'Producer_1', 'date': '2024-03-02'}
# {'latitude': -36.096, 'longtitude': 146.5016, 'air_temperature_celcius': 12, 'relative_humidity': 41.0, 'windspeed_knots': 12.9, 'max_wind_speed': 16.9, 'precipitation': ' 0.16G', 'GHI_w/m2': 111, 'producer': 'Producer_1', 'date': '2024-03-03'}
# {'latitude': -38.167, 'longtitude': 143.841, 'air_temperature_celcius': 21, 'relative_humidity': 58.1, 'windspeed_knots': 5.3, 'max_wind_speed': 11.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 168, 'producer': 'Producer_1', 'date': '2024-03-04'}
# {'latitude': -37.379, 'longtitude': 148.132, 'air_temperature_celcius': 12, 'relative_humidity': 44.9, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 107, 'producer': 'Producer_1', 'date': '2024-03-05'}
# {'latitude': -35.325, 'longtitude': 143.497, 'air_temperature_celcius': 13, 'relative_humidity': 48.5, 'windspeed_knots': 5.3, 'max_wind_speed': 11.1, 'precipitation': ' 0.08G', 'GHI_w/m2': 113, 'producer': 'Producer_1', 'date': '2024-03-06'}
# {'latitude': -37.438, 'longtitude': 148.09, 'air_temperature_celcius': 10, 'relative_humidity': 44.7, 'windspeed_knots': 8.0, 'max_wind_speed': 15.9, 'precipitation': ' 0.08G', 'GHI_w/m2': 90, 'producer': 'Producer_1', 'date': '2024-03-07'}
# {'latitude': -36.098, 'longtitude': 143.74, 'air_temperature_celcius': 17, 'relative_humidity': 59.3, 'windspeed_knots': 4.2, 'max_wind_speed': 7.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 134, 'producer': 'Producer_1', 'date': '2024-03-08'}
# {'latitude': -34.289, 'longtitude': 141.712, 'air_temperature_celcius': 32, 'relative_humidity': 54.1, 'windspeed_knots': 12.8, 'max_wind_speed': 19.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 265, 'producer': 'Producer_1', 'date': '2024-03-09'}
# {'latitude': -37.886, 'longtitude': 147.207, 'air_temperature_celcius': 19, 'relative_humidity': 54.3, 'windspeed_knots': 5.9, 'max_wind_speed': 12.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 157, 'producer': 'Producer_1', 'date': '2024-03-10'}
# {'latitude': -37.465, 'longtitude': 148.153, 'air_temperature_celcius': 11, 'relative_humidity': 43.5, 'windspeed_knots': 13.1, 'max_wind_speed': 21.0, 'precipitation': ' 0.24G', 'GHI_w/m2': 99, 'producer': 'Producer_1', 'date': '2024-03-11'}
# {'latitude': -36.277, 'longtitude': 146.165, 'air_temperature_celcius': 20, 'relative_humidity': 57.0, 'windspeed_knots': 8.7, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 161, 'producer': 'Producer_1', 'date': '2024-03-12'}
# {'latitude': -38.495, 'longtitude': 146.944, 'air_temperature_celcius': 8, 'relative_humidity': 44.6, 'windspeed_knots': 3.9, 'max_wind_speed': 8.0, 'precipitation': ' 0.39G', 'GHI_w/m2': 72, 'producer': 'Producer_1', 'date': '2024-03-13'}
# {'latitude': -37.497, 'longtitude': 147.266, 'air_temperature_celcius': 10, 'relative_humidity': 41.0, 'windspeed_knots': 14.1, 'max_wind_speed': 20.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 92, 'producer': 'Producer_1', 'date': '2024-03-14'}
# {'latitude': -36.273, 'longtitude': 146.155, 'air_temperature_celcius': 22, 'relative_humidity': 56.3, 'windspeed_knots': 8.0, 'max_wind_speed': 13.0, 'precipitation': ' 0.08G', 'GHI_w/m2': 179, 'producer': 'Producer_1', 'date': '2024-03-15'}
# {'latitude': -38.127, 'longtitude': 143.82, 'air_temperature_celcius': 9, 'relative_humidity': 44.0, 'windspeed_knots': 2.8, 'max_wind_speed': 8.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 81, 'producer': 'Producer_1', 'date': '2024-03-16'}
# {'latitude': -36.2111, 'longtitude': 141.505, 'air_temperature_celcius': 24, 'relative_humidity': 55.5, 'windspeed_knots': 7.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 196, 'producer': 'Producer_1', 'date': '2024-03-17'}
# {'latitude': -37.608, 'longtitude': 149.282, 'air_temperature_celcius': 22, 'relative_humidity': 62.7, 'windspeed_knots': 7.6, 'max_wind_speed': 18.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 169, 'producer': 'Producer_1', 'date': '2024-03-18'}
# {'latitude': -37.945, 'longtitude': 144.354, 'air_temperature_celcius': 24, 'relative_humidity': 55.6, 'windspeed_knots': 5.9, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 196, 'producer': 'Producer_1', 'date': '2024-03-19'}
# {'latitude': -36.4422, 'longtitude': 141.427, 'air_temperature_celcius': 15, 'relative_humidity': 48.1, 'windspeed_knots': 7.9, 'max_wind_speed': 12.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 131, 'producer': 'Producer_1', 'date': '2024-03-20'}
# {'latitude': -37.598, 'longtitude': 149.29, 'air_temperature_celcius': 18, 'relative_humidity': 53.5, 'windspeed_knots': 8.8, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 150, 'producer': 'Producer_1', 'date': '2024-03-21'}
# {'latitude': -36.759, 'longtitude': 145.179, 'air_temperature_celcius': 18, 'relative_humidity': 55.6, 'windspeed_knots': 12.8, 'max_wind_speed': 19.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 147, 'producer': 'Producer_1', 'date': '2024-03-22'}
# {'latitude': -36.3674, 'longtitude': 143.7295, 'air_temperature_celcius': 15, 'relative_humidity': 48.7, 'windspeed_knots': 8.5, 'max_wind_speed': 20.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 130, 'producer': 'Producer_1', 'date': '2024-03-23'}
# {'latitude': -37.479, 'longtitude': 143.358, 'air_temperature_celcius': 23, 'relative_humidity': 60.6, 'windspeed_knots': 10.1, 'max_wind_speed': 26.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 180, 'producer': 'Producer_1', 'date': '2024-03-24'}
# {'latitude': -38.226, 'longtitude': 147.167, 'air_temperature_celcius': 10, 'relative_humidity': 43.7, 'windspeed_knots': 7.2, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 90, 'producer': 'Producer_1', 'date': '2024-03-25'}
# {'latitude': -37.368, 'longtitude': 148.05, 'air_temperature_celcius': 10, 'relative_humidity': 41.4, 'windspeed_knots': 9.4, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 92, 'producer': 'Producer_1', 'date': '2024-03-26'}
# {'latitude': -37.332, 'longtitude': 148.091, 'air_temperature_celcius': 8, 'relative_humidity': 39.3, 'windspeed_knots': 7.7, 'max_wind_speed': 14.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 75, 'producer': 'Producer_1', 'date': '2024-03-27'}
# {'latitude': -37.9243, 'longtitude': 144.1064, 'air_temperature_celcius': 17, 'relative_humidity': 53.0, 'windspeed_knots': 14.6, 'max_wind_speed': 22.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 142, 'producer': 'Producer_1', 'date': '2024-03-28'}
# {'latitude': -37.242, 'longtitude': 141.153, 'air_temperature_celcius': 12, 'relative_humidity': 42.8, 'windspeed_knots': 12.1, 'max_wind_speed': 19.0, 'precipitation': ' 0.04G', 'GHI_w/m2': 109, 'producer': 'Producer_1', 'date': '2024-03-29'}
# {'latitude': -36.952, 'longtitude': 144.972, 'air_temperature_celcius': 21, 'relative_humidity': 57.3, 'windspeed_knots': 5.4, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 169, 'producer': 'Producer_1', 'date': '2024-03-30'}
# {'latitude': -36.3782, 'longtitude': 143.7313, 'air_temperature_celcius': 17, 'relative_humidity': 44.9, 'windspeed_knots': 16.1, 'max_wind_speed': 27.0, 'precipitation': ' 0.24G', 'GHI_w/m2': 152, 'producer': 'Producer_1', 'date': '2024-03-31'}
# {'latitude': -37.637, 'longtitude': 146.288, 'air_temperature_celcius': 31, 'relative_humidity': 61.9, 'windspeed_knots': 14.1, 'max_wind_speed': 23.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 239, 'producer': 'Producer_1', 'date': '2024-04-01'}
# {'latitude': -36.3823, 'longtitude': 141.3146, 'air_temperature_celcius': 10, 'relative_humidity': 43.7, 'windspeed_knots': 9.5, 'max_wind_speed': 13.0, 'precipitation': ' 0.08G', 'GHI_w/m2': 90, 'producer': 'Producer_1', 'date': '2024-04-02'}
# {'latitude': -36.6859, 'longtitude': 146.8907, 'air_temperature_celcius': 16, 'relative_humidity': 51.5, 'windspeed_knots': 8.7, 'max_wind_speed': 15.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 135, 'producer': 'Producer_1', 'date': '2024-04-03'}
# {'latitude': -37.621, 'longtitude': 143.447, 'air_temperature_celcius': 23, 'relative_humidity': 53.4, 'windspeed_knots': 6.1, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 192, 'producer': 'Producer_1', 'date': '2024-04-04'}
# {'latitude': -37.437, 'longtitude': 148.104, 'air_temperature_celcius': 12, 'relative_humidity': 40.7, 'windspeed_knots': 16.7, 'max_wind_speed': 21.0, 'precipitation': ' 0.12G', 'GHI_w/m2': 111, 'producer': 'Producer_1', 'date': '2024-04-05'}
# {'latitude': -37.4661, 'longtitude': 143.2419, 'air_temperature_celcius': 14, 'relative_humidity': 48.2, 'windspeed_knots': 9.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 122, 'producer': 'Producer_1', 'date': '2024-04-06'}
# {'latitude': -36.3328, 'longtitude': 146.0355, 'air_temperature_celcius': 7, 'relative_humidity': 37.2, 'windspeed_knots': 6.2, 'max_wind_speed': 16.9, 'precipitation': ' 0.08G', 'GHI_w/m2': 66, 'producer': 'Producer_1', 'date': '2024-04-07'}
# {'latitude': -36.984, 'longtitude': 148.25, 'air_temperature_celcius': 10, 'relative_humidity': 39.9, 'windspeed_knots': 12.6, 'max_wind_speed': 16.9, 'precipitation': ' 0.08G', 'GHI_w/m2': 93, 'producer': 'Producer_1', 'date': '2024-04-08'}
# {'latitude': -37.245, 'longtitude': 143.426, 'air_temperature_celcius': 10, 'relative_humidity': 47.0, 'windspeed_knots': 5.2, 'max_wind_speed': 8.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 88, 'producer': 'Producer_1', 'date': '2024-04-09'}
# {'latitude': -37.457, 'longtitude': 148.143, 'air_temperature_celcius': 9, 'relative_humidity': 39.0, 'windspeed_knots': 5.6, 'max_wind_speed': 8.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 84, 'producer': 'Producer_1', 'date': '2024-04-10'}
# {'latitude': -37.249, 'longtitude': 143.413, 'air_temperature_celcius': 14, 'relative_humidity': 47.9, 'windspeed_knots': 5.3, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 122, 'producer': 'Producer_1', 'date': '2024-04-11'}
# {'latitude': -37.642, 'longtitude': 149.263, 'air_temperature_celcius': 20, 'relative_humidity': 55.8, 'windspeed_knots': 10.5, 'max_wind_speed': 15.9, 'precipitation': ' 0.01G', 'GHI_w/m2': 163, 'producer': 'Producer_1', 'date': '2024-04-12'}
# {'latitude': -36.275, 'longtitude': 146.154, 'air_temperature_celcius': 18, 'relative_humidity': 53.3, 'windspeed_knots': 7.9, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 150, 'producer': 'Producer_1', 'date': '2024-04-13'}
# {'latitude': -36.8264, 'longtitude': 142.6138, 'air_temperature_celcius': 15, 'relative_humidity': 48.2, 'windspeed_knots': 14.7, 'max_wind_speed': 25.1, 'precipitation': ' 0.43G', 'GHI_w/m2': 131, 'producer': 'Producer_1', 'date': '2024-04-14'}
# {'latitude': -37.475, 'longtitude': 143.365, 'air_temperature_celcius': 17, 'relative_humidity': 49.9, 'windspeed_knots': 12.2, 'max_wind_speed': 21.0, 'precipitation': ' 0.24G', 'GHI_w/m2': 146, 'producer': 'Producer_1', 'date': '2024-04-15'}
# {'latitude': -37.453, 'longtitude': 148.118, 'air_temperature_celcius': 6, 'relative_humidity': 39.0, 'windspeed_knots': 1.8, 'max_wind_speed': 5.1, 'precipitation': ' 0.01G', 'GHI_w/m2': 56, 'producer': 'Producer_1', 'date': '2024-04-16'}
# {'latitude': -36.0313, 'longtitude': 143.6296, 'air_temperature_celcius': 14, 'relative_humidity': 47.4, 'windspeed_knots': 10.6, 'max_wind_speed': 19.0, 'precipitation': ' 0.03G', 'GHI_w/m2': 123, 'producer': 'Producer_1', 'date': '2024-04-17'}
# {'latitude': -37.389, 'longtitude': 149.311, 'air_temperature_celcius': 18, 'relative_humidity': 53.0, 'windspeed_knots': 6.6, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 150, 'producer': 'Producer_1', 'date': '2024-04-18'}
# {'latitude': -36.009, 'longtitude': 143.185, 'air_temperature_celcius': 28, 'relative_humidity': 48.3, 'windspeed_knots': 11.9, 'max_wind_speed': 22.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 243, 'producer': 'Producer_1', 'date': '2024-04-19'}
# {'latitude': -36.8948, 'longtitude': 142.3282, 'air_temperature_celcius': 9, 'relative_humidity': 41.2, 'windspeed_knots': 6.7, 'max_wind_speed': 13.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 83, 'producer': 'Producer_1', 'date': '2024-04-20'}
# {'latitude': -37.399, 'longtitude': 148.081, 'air_temperature_celcius': 14, 'relative_humidity': 49.9, 'windspeed_knots': 13.7, 'max_wind_speed': 22.0, 'precipitation': ' 0.03G', 'GHI_w/m2': 120, 'producer': 'Producer_1', 'date': '2024-04-21'}
# {'latitude': -36.779, 'longtitude': 146.108, 'air_temperature_celcius': 13, 'relative_humidity': 42.0, 'windspeed_knots': 11.4, 'max_wind_speed': 16.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 119, 'producer': 'Producer_1', 'date': '2024-04-22'}
# {'latitude': -36.4125, 'longtitude': 143.1189, 'air_temperature_celcius': 12, 'relative_humidity': 47.9, 'windspeed_knots': 6.7, 'max_wind_speed': 11.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 105, 'producer': 'Producer_1', 'date': '2024-04-23'}
# {'latitude': -37.469, 'longtitude': 148.125, 'air_temperature_celcius': 14, 'relative_humidity': 48.4, 'windspeed_knots': 7.5, 'max_wind_speed': 13.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 122, 'producer': 'Producer_1', 'date': '2024-04-24'}
# {'latitude': -36.251, 'longtitude': 142.5651, 'air_temperature_celcius': 17, 'relative_humidity': 53.6, 'windspeed_knots': 7.6, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 141, 'producer': 'Producer_1', 'date': '2024-04-25'}
# {'latitude': -35.937, 'longtitude': 145.607, 'air_temperature_celcius': 10, 'relative_humidity': 43.3, 'windspeed_knots': 2.6, 'max_wind_speed': 7.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 91, 'producer': 'Producer_1', 'date': '2024-04-26'}
# {'latitude': -36.701, 'longtitude': 142.538, 'air_temperature_celcius': 18, 'relative_humidity': 61.5, 'windspeed_knots': 5.5, 'max_wind_speed': 11.1, 'precipitation': ' 0.28G', 'GHI_w/m2': 140, 'producer': 'Producer_1', 'date': '2024-04-27'}
# {'latitude': -37.384, 'longtitude': 148.056, 'air_temperature_celcius': 9, 'relative_humidity': 43.2, 'windspeed_knots': 4.9, 'max_wind_speed': 8.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 82, 'producer': 'Producer_1', 'date': '2024-04-28'}
# {'latitude': -37.477, 'longtitude': 143.352, 'air_temperature_celcius': 18, 'relative_humidity': 50.6, 'windspeed_knots': 6.0, 'max_wind_speed': 13.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 154, 'producer': 'Producer_1', 'date': '2024-04-29'}
# {'latitude': -37.863, 'longtitude': 144.17, 'air_temperature_celcius': 18, 'relative_humidity': 57.5, 'windspeed_knots': 16.1, 'max_wind_speed': 21.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 145, 'producer': 'Producer_1', 'date': '2024-04-30'}
# {'latitude': -37.46, 'longtitude': 148.102, 'air_temperature_celcius': 10, 'relative_humidity': 46.3, 'windspeed_knots': 4.6, 'max_wind_speed': 8.0, 'precipitation': ' 0.08G', 'GHI_w/m2': 88, 'producer': 'Producer_1', 'date': '2024-05-01'}
# {'latitude': -37.644, 'longtitude': 149.233, 'air_temperature_celcius': 22, 'relative_humidity': 58.0, 'windspeed_knots': 6.9, 'max_wind_speed': 12.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 176, 'producer': 'Producer_1', 'date': '2024-05-02'}
# {'latitude': -35.321, 'longtitude': 143.502, 'air_temperature_celcius': 12, 'relative_humidity': 44.0, 'windspeed_knots': 4.7, 'max_wind_speed': 7.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 108, 'producer': 'Producer_1', 'date': '2024-05-03'}
# {'latitude': -37.6008, 'longtitude': 143.0558, 'air_temperature_celcius': 15, 'relative_humidity': 44.8, 'windspeed_knots': 8.3, 'max_wind_speed': 19.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 134, 'producer': 'Producer_1', 'date': '2024-05-04'}
# {'latitude': -36.498, 'longtitude': 144.877, 'air_temperature_celcius': 12, 'relative_humidity': 51.6, 'windspeed_knots': 3.4, 'max_wind_speed': 11.1, 'precipitation': ' 0.05G', 'GHI_w/m2': 101, 'producer': 'Producer_1', 'date': '2024-05-05'}
# {'latitude': -37.634, 'longtitude': 149.237, 'air_temperature_celcius': 16, 'relative_humidity': 48.4, 'windspeed_knots': 8.1, 'max_wind_speed': 15.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 139, 'producer': 'Producer_1', 'date': '2024-05-06'}
# {'latitude': -36.765, 'longtitude': 144.176, 'air_temperature_celcius': 16, 'relative_humidity': 54.9, 'windspeed_knots': 5.9, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 132, 'producer': 'Producer_1', 'date': '2024-05-07'}
# {'latitude': -37.425, 'longtitude': 148.107, 'air_temperature_celcius': 15, 'relative_humidity': 41.2, 'windspeed_knots': 13.8, 'max_wind_speed': 16.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 138, 'producer': 'Producer_1', 'date': '2024-05-08'}
# {'latitude': -36.294, 'longtitude': 146.149, 'air_temperature_celcius': 20, 'relative_humidity': 57.7, 'windspeed_knots': 9.9, 'max_wind_speed': 18.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 160, 'producer': 'Producer_1', 'date': '2024-05-09'}
# {'latitude': -37.719, 'longtitude': 142.154, 'air_temperature_celcius': 13, 'relative_humidity': 47.0, 'windspeed_knots': 7.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 114, 'producer': 'Producer_1', 'date': '2024-05-10'}
# {'latitude': -36.759, 'longtitude': 144.158, 'air_temperature_celcius': 14, 'relative_humidity': 52.5, 'windspeed_knots': 7.0, 'max_wind_speed': 13.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 118, 'producer': 'Producer_1', 'date': '2024-05-11'}
# {'latitude': -38.231, 'longtitude': 147.172, 'air_temperature_celcius': 24, 'relative_humidity': 61.6, 'windspeed_knots': 7.7, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 186, 'producer': 'Producer_1', 'date': '2024-05-12'}
# {'latitude': -37.401, 'longtitude': 148.067, 'air_temperature_celcius': 13, 'relative_humidity': 42.5, 'windspeed_knots': 14.0, 'max_wind_speed': 19.0, 'precipitation': ' 0.04G', 'GHI_w/m2': 118, 'producer': 'Producer_1', 'date': '2024-05-13'}
# {'latitude': -37.1815, 'longtitude': 146.7777, 'air_temperature_celcius': 17, 'relative_humidity': 50.4, 'windspeed_knots': 10.8, 'max_wind_speed': 16.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 145, 'producer': 'Producer_1', 'date': '2024-05-14'}
# {'latitude': -38.527, 'longtitude': 143.493, 'air_temperature_celcius': 19, 'relative_humidity': 51.5, 'windspeed_knots': 10.2, 'max_wind_speed': 20.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 161, 'producer': 'Producer_1', 'date': '2024-05-15'}
# {'latitude': -36.6732, 'longtitude': 142.5162, 'air_temperature_celcius': 19, 'relative_humidity': 53.9, 'windspeed_knots': 8.3, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 158, 'producer': 'Producer_1', 'date': '2024-05-16'}
# {'latitude': -37.477, 'longtitude': 148.097, 'air_temperature_celcius': 8, 'relative_humidity': 42.6, 'windspeed_knots': 2.0, 'max_wind_speed': 6.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 73, 'producer': 'Producer_1', 'date': '2024-05-17'}
# {'latitude': -36.1346, 'longtitude': 145.2196, 'air_temperature_celcius': 8, 'relative_humidity': 37.2, 'windspeed_knots': 5.5, 'max_wind_speed': 11.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 76, 'producer': 'Producer_1', 'date': '2024-05-18'}
# {'latitude': -37.365, 'longtitude': 148.052, 'air_temperature_celcius': 11, 'relative_humidity': 43.8, 'windspeed_knots': 6.5, 'max_wind_speed': 12.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 99, 'producer': 'Producer_1', 'date': '2024-05-19'}
# {'latitude': -37.461, 'longtitude': 148.105, 'air_temperature_celcius': 10, 'relative_humidity': 45.6, 'windspeed_knots': 4.5, 'max_wind_speed': 7.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 89, 'producer': 'Producer_1', 'date': '2024-05-20'}
# {'latitude': -37.327, 'longtitude': 148.083, 'air_temperature_celcius': 10, 'relative_humidity': 44.8, 'windspeed_knots': 8.8, 'max_wind_speed': 14.0, 'precipitation': ' 0.39G', 'GHI_w/m2': 89, 'producer': 'Producer_1', 'date': '2024-05-21'}
# {'latitude': -38.116, 'longtitude': 143.818, 'air_temperature_celcius': 10, 'relative_humidity': 46.8, 'windspeed_knots': 5.3, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 88, 'producer': 'Producer_1', 'date': '2024-05-22'}
# {'latitude': -34.282, 'longtitude': 142.121, 'air_temperature_celcius': 15, 'relative_humidity': 49.1, 'windspeed_knots': 9.6, 'max_wind_speed': 16.9, 'precipitation': ' 0.01G', 'GHI_w/m2': 130, 'producer': 'Producer_1', 'date': '2024-05-23'}
# {'latitude': -37.406, 'longtitude': 148.123, 'air_temperature_celcius': 12, 'relative_humidity': 44.7, 'windspeed_knots': 11.4, 'max_wind_speed': 18.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 107, 'producer': 'Producer_1', 'date': '2024-05-24'}
# {'latitude': -37.294, 'longtitude': 141.232, 'air_temperature_celcius': 12, 'relative_humidity': 49.0, 'windspeed_knots': 4.6, 'max_wind_speed': 8.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 104, 'producer': 'Producer_1', 'date': '2024-05-25'}
# {'latitude': -37.375, 'longtitude': 148.054, 'air_temperature_celcius': 12, 'relative_humidity': 47.0, 'windspeed_knots': 4.8, 'max_wind_speed': 8.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 105, 'producer': 'Producer_1', 'date': '2024-05-26'}
# {'latitude': -37.386, 'longtitude': 148.043, 'air_temperature_celcius': 8, 'relative_humidity': 43.3, 'windspeed_knots': 3.9, 'max_wind_speed': 8.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 72, 'producer': 'Producer_1', 'date': '2024-05-27'}
# {'latitude': -37.247, 'longtitude': 141.27, 'air_temperature_celcius': 10, 'relative_humidity': 43.1, 'windspeed_knots': 4.7, 'max_wind_speed': 8.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 91, 'producer': 'Producer_1', 'date': '2024-05-28'}
# {'latitude': -37.46, 'longtitude': 148.113, 'air_temperature_celcius': 11, 'relative_humidity': 44.2, 'windspeed_knots': 8.7, 'max_wind_speed': 15.9, 'precipitation': ' 0.04G', 'GHI_w/m2': 99, 'producer': 'Producer_1', 'date': '2024-05-29'}
# {'latitude': -35.963, 'longtitude': 141.078, 'air_temperature_celcius': 5, 'relative_humidity': 33.1, 'windspeed_knots': 5.8, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 49, 'producer': 'Producer_1', 'date': '2024-05-30'}
# {'latitude': -37.397, 'longtitude': 148.121, 'air_temperature_celcius': 13, 'relative_humidity': 44.0, 'windspeed_knots': 13.6, 'max_wind_speed': 21.0, 'precipitation': ' 0.04G', 'GHI_w/m2': 117, 'producer': 'Producer_1', 'date': '2024-05-31'}
# {'latitude': -37.538, 'longtitude': 148.895, 'air_temperature_celcius': 6, 'relative_humidity': 37.1, 'windspeed_knots': 5.8, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 57, 'producer': 'Producer_1', 'date': '2024-06-01'}
# {'latitude': -36.0714, 'longtitude': 145.7665, 'air_temperature_celcius': 18, 'relative_humidity': 54.6, 'windspeed_knots': 12.0, 'max_wind_speed': 25.1, 'precipitation': ' 0.12G', 'GHI_w/m2': 148, 'producer': 'Producer_1', 'date': '2024-06-02'}
# {'latitude': -37.856, 'longtitude': 143.416, 'air_temperature_celcius': 15, 'relative_humidity': 53.7, 'windspeed_knots': 6.8, 'max_wind_speed': 11.1, 'precipitation': ' 0.51G', 'GHI_w/m2': 125, 'producer': 'Producer_1', 'date': '2024-06-03'}
# {'latitude': -37.0669, 'longtitude': 141.0556, 'air_temperature_celcius': 12, 'relative_humidity': 47.5, 'windspeed_knots': 15.0, 'max_wind_speed': 18.1, 'precipitation': ' 0.20G', 'GHI_w/m2': 105, 'producer': 'Producer_1', 'date': '2024-06-04'}
# {'latitude': -36.942, 'longtitude': 143.282, 'air_temperature_celcius': 25, 'relative_humidity': 58.3, 'windspeed_knots': 7.1, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 199, 'producer': 'Producer_1', 'date': '2024-06-05'}
# {'latitude': -37.585, 'longtitude': 149.336, 'air_temperature_celcius': 17, 'relative_humidity': 52.5, 'windspeed_knots': 6.7, 'max_wind_speed': 12.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 143, 'producer': 'Producer_1', 'date': '2024-06-06'}
# {'latitude': -36.6511, 'longtitude': 143.915, 'air_temperature_celcius': 13, 'relative_humidity': 46.2, 'windspeed_knots': 5.6, 'max_wind_speed': 12.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 115, 'producer': 'Producer_1', 'date': '2024-06-07'}
# {'latitude': -37.5865, 'longtitude': 143.0246, 'air_temperature_celcius': 17, 'relative_humidity': 53.5, 'windspeed_knots': 7.3, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 141, 'producer': 'Producer_1', 'date': '2024-06-08'}
# {'latitude': -37.6767, 'longtitude': 142.9892, 'air_temperature_celcius': 18, 'relative_humidity': 53.8, 'windspeed_knots': 6.7, 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 149, 'producer': 'Producer_1', 'date': '2024-06-09'}
# {'latitude': -35.323, 'longtitude': 143.509, 'air_temperature_celcius': 15, 'relative_humidity': 49.3, 'windspeed_knots': 3.6, 'max_wind_speed': 7.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 129, 'producer': 'Producer_1', 'date': '2024-06-10'}
# {'latitude': -37.562, 'longtitude': 148.05, 'air_temperature_celcius': 7, 'relative_humidity': 40.5, 'windspeed_knots': 3.1, 'max_wind_speed': 8.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 65, 'producer': 'Producer_1', 'date': '2024-06-11'}
# {'latitude': -36.538, 'longtitude': 141.129, 'air_temperature_celcius': 12, 'relative_humidity': 43.4, 'windspeed_knots': 9.3, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 109, 'producer': 'Producer_1', 'date': '2024-06-12'}
# {'latitude': -37.062, 'longtitude': 141.373, 'air_temperature_celcius': 22, 'relative_humidity': 46.8, 'windspeed_knots': 8.0, 'max_wind_speed': 16.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 194, 'producer': 'Producer_1', 'date': '2024-06-13'}
# {'latitude': -36.284, 'longtitude': 146.145, 'air_temperature_celcius': 19, 'relative_humidity': 54.1, 'windspeed_knots': 11.2, 'max_wind_speed': 18.1, 'precipitation': ' 0.31G', 'GHI_w/m2': 157, 'producer': 'Producer_1', 'date': '2024-06-14'}
# {'latitude': -36.5507, 'longtitude': 142.5788, 'air_temperature_celcius': 17, 'relative_humidity': 51.2, 'windspeed_knots': 9.9, 'max_wind_speed': 18.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 144, 'producer': 'Producer_1', 'date': '2024-06-15'}
# {'latitude': -38.16, 'longtitude': 143.803, 'air_temperature_celcius': 20, 'relative_humidity': 62.2, 'windspeed_knots': 7.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 154, 'producer': 'Producer_1', 'date': '2024-06-16'}
# {'latitude': -37.858, 'longtitude': 143.428, 'air_temperature_celcius': 14, 'relative_humidity': 49.5, 'windspeed_knots': 6.0, 'max_wind_speed': 12.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 121, 'producer': 'Producer_1', 'date': '2024-06-17'}
# {'latitude': -38.5, 'longtitude': 146.938, 'air_temperature_celcius': 7, 'relative_humidity': 40.7, 'windspeed_knots': 3.7, 'max_wind_speed': 7.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 65, 'producer': 'Producer_1', 'date': '2024-06-18'}
# {'latitude': -37.586, 'longtitude': 141.271, 'air_temperature_celcius': 19, 'relative_humidity': 60.5, 'windspeed_knots': 7.0, 'max_wind_speed': 11.1, 'precipitation': ' 0.83G', 'GHI_w/m2': 149, 'producer': 'Producer_1', 'date': '2024-06-19'}
# {'latitude': -36.764, 'longtitude': 144.165, 'air_temperature_celcius': 14, 'relative_humidity': 52.4, 'windspeed_knots': 6.7, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 118, 'producer': 'Producer_1', 'date': '2024-06-20'}
# {'latitude': -37.0684, 'longtitude': 141.0437, 'air_temperature_celcius': 13, 'relative_humidity': 51.1, 'windspeed_knots': 6.0, 'max_wind_speed': 13.0, 'precipitation': ' 0.12G', 'GHI_w/m2': 110, 'producer': 'Producer_1', 'date': '2024-06-21'}
# {'latitude': -34.5374, 'longtitude': 141.7141, 'air_temperature_celcius': 8, 'relative_humidity': 40.8, 'windspeed_knots': 5.5, 'max_wind_speed': 9.9, 'precipitation': ' 0.01G', 'GHI_w/m2': 74, 'producer': 'Producer_1', 'date': '2024-06-22'}
# {'latitude': -36.575, 'longtitude': 146.6668, 'air_temperature_celcius': 18, 'relative_humidity': 53.6, 'windspeed_knots': 7.9, 'max_wind_speed': 15.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 150, 'producer': 'Producer_1', 'date': '2024-06-23'}
# {'latitude': -37.4437, 'longtitude': 143.4924, 'air_temperature_celcius': 13, 'relative_humidity': 50.7, 'windspeed_knots': 6.1, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 111, 'producer': 'Producer_1', 'date': '2024-06-24'}
# {'latitude': -36.2229, 'longtitude': 143.4245, 'air_temperature_celcius': 23, 'relative_humidity': 58.8, 'windspeed_knots': 9.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 183, 'producer': 'Producer_1', 'date': '2024-06-25'}
# {'latitude': -38.038, 'longtitude': 142.986, 'air_temperature_celcius': 15, 'relative_humidity': 50.7, 'windspeed_knots': 9.2, 'max_wind_speed': 13.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 128, 'producer': 'Producer_1', 'date': '2024-06-26'}
# {'latitude': -37.466, 'longtitude': 148.1, 'air_temperature_celcius': 12, 'relative_humidity': 49.4, 'windspeed_knots': 4.4, 'max_wind_speed': 8.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 103, 'producer': 'Producer_1', 'date': '2024-06-27'}
# {'latitude': -36.7685, 'longtitude': 142.7134, 'air_temperature_celcius': 14, 'relative_humidity': 48.2, 'windspeed_knots': 12.5, 'max_wind_speed': 19.0, 'precipitation': ' 0.03G', 'GHI_w/m2': 122, 'producer': 'Producer_1', 'date': '2024-06-28'}
# {'latitude': -35.779, 'longtitude': 143.1057, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'windspeed_knots': 9.0, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 150, 'producer': 'Producer_1', 'date': '2024-06-29'}
# {'latitude': -36.748, 'longtitude': 144.168, 'air_temperature_celcius': 11, 'relative_humidity': 48.2, 'windspeed_knots': 10.8, 'max_wind_speed': 22.9, 'precipitation': ' 0.59G', 'GHI_w/m2': 96, 'producer': 'Producer_1', 'date': '2024-06-30'}
# {'latitude': -36.0201, 'longtitude': 143.7775, 'air_temperature_celcius': 18, 'relative_humidity': 55.6, 'windspeed_knots': 8.2, 'max_wind_speed': 12.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 147, 'producer': 'Producer_1', 'date': '2024-07-01'}
# {'latitude': -36.398, 'longtitude': 145.286, 'air_temperature_celcius': 11, 'relative_humidity': 45.1, 'windspeed_knots': 11.5, 'max_wind_speed': 18.1, 'precipitation': ' 0.20G', 'GHI_w/m2': 98, 'producer': 'Producer_1', 'date': '2024-07-02'}
# {'latitude': -38.912, 'longtitude': 146.272, 'air_temperature_celcius': 18, 'relative_humidity': 53.3, 'windspeed_knots': 10.8, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 150, 'producer': 'Producer_1', 'date': '2024-07-03'}
# {'latitude': -36.291, 'longtitude': 146.159, 'air_temperature_celcius': 24, 'relative_humidity': 55.4, 'windspeed_knots': 5.9, 'max_wind_speed': 9.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 196, 'producer': 'Producer_1', 'date': '2024-07-04'}
# {'latitude': -37.0899, 'longtitude': 141.0238, 'air_temperature_celcius': 9, 'relative_humidity': 42.2, 'windspeed_knots': 6.4, 'max_wind_speed': 9.9, 'precipitation': ' 0.01G', 'GHI_w/m2': 82, 'producer': 'Producer_1', 'date': '2024-07-05'}
# {'latitude': -36.5871, 'longtitude': 144.961, 'air_temperature_celcius': 13, 'relative_humidity': 43.6, 'windspeed_knots': 9.0, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 117, 'producer': 'Producer_1', 'date': '2024-07-06'}
# {'latitude': -37.57, 'longtitude': 148.034, 'air_temperature_celcius': 11, 'relative_humidity': 40.4, 'windspeed_knots': 19.3, 'max_wind_speed': 26.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 102, 'producer': 'Producer_1', 'date': '2024-07-07'}
# {'latitude': -36.341, 'longtitude': 143.636, 'air_temperature_celcius': 16, 'relative_humidity': 47.5, 'windspeed_knots': 5.4, 'max_wind_speed': 12.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 140, 'producer': 'Producer_1', 'date': '2024-07-08'}
# {'latitude': -37.376, 'longtitude': 148.042, 'air_temperature_celcius': 11, 'relative_humidity': 43.2, 'windspeed_knots': 5.5, 'max_wind_speed': 8.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 100, 'producer': 'Producer_1', 'date': '2024-07-09'}
# {'latitude': -37.7836, 'longtitude': 141.4711, 'air_temperature_celcius': 12, 'relative_humidity': 44.5, 'windspeed_knots': 11.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 108, 'producer': 'Producer_1', 'date': '2024-07-10'}
# {'latitude': -37.0884, 'longtitude': 141.0357, 'air_temperature_celcius': 12, 'relative_humidity': 40.4, 'windspeed_knots': 5.9, 'max_wind_speed': 8.9, 'precipitation': ' 0.00G', 'GHI_w/m2': 111, 'producer': 'Producer_1', 'date': '2024-07-11'}
# {'latitude': -37.472, 'longtitude': 148.119, 'air_temperature_celcius': 15, 'relative_humidity': 49.9, 'windspeed_knots': 7.9, 'max_wind_speed': 13.0, 'precipitation': ' 0.01G', 'GHI_w/m2': 129, 'producer': 'Producer_1', 'date': '2024-07-12'}
# {'latitude': -36.3799, 'longtitude': 143.7149, 'air_temperature_celcius': 12, 'relative_humidity': 43.8, 'windspeed_knots': 6.7, 'max_wind_speed': 14.0, 'precipitation': ' 0.16G', 'GHI_w/m2': 108, 'producer': 'Producer_1', 'date': '2024-07-13'}
# {'latitude': -37.297, 'longtitude': 144.384, 'air_temperature_celcius': 22, 'relative_humidity': 52.8, 'windspeed_knots': 9.1, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 184, 'producer': 'Producer_1', 'date': '2024-07-14'}

# %%
"""
Event Producer 2
"""
hotspot_AQUA = pd.read_csv("./hotspot_AQUA_streaming.csv", sep=',')

hotspot_AQUA.head()


"""
Main Function
"""
if __name__ == '__main__':
    topic = 'Scenaries02'
    print('Publishing records..')
    producer02 = connect_kafka_producer()
    
    
    rand_row_indices = list(range(len(hotspot_AQUA.index)))
    random.shuffle(rand_row_indices) 
    # random choose time from 0 to 10
    max_time = 10
    #rand_time = list(range(1,max_time))
#     random.shuffle(rand_time) 
     

    for index, hotspot_AQUA_row in hotspot_AQUA.iterrows():
        hotspot_AQUA_row = hotspot_AQUA.loc[rand_row_indices[index]]

        hotspot_AQUA_doc = {
            'latitude': hotspot_AQUA_row['latitude'],
            'longtitude': hotspot_AQUA_row['longitude'],
            'confidence': hotspot_AQUA_row['confidence'],
            'surface_temperature_celcius': hotspot_AQUA_row['surface_temperature_celcius'],
            'producer': "Producer_2",
            'random_time': rand_row_indices[index]%max_time + 1 # at least 1 sec
        }
        #update start date
        #print(climate_doc['date'])
        #producer publish msg in strictured streaming
        # convert the dictionary to JSON-formatted string and encode as UFT-8 by publish_msg
        # msg = json.dumps(climate_doc)
        #print(climate_doc)
        #print(hotspot_AQUA_doc['random_time'])
        publish_msg(producer02, topic, hotspot_AQUA_doc)
        # every random seconds
        sleep(hotspot_AQUA_doc['random_time'])
# Out:
# Publishing records..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 36
#      21 hotspot_AQUA_doc = {
#      22     'latitude': hotspot_AQUA_row['latitude'],
#      23     'longtitude': hotspot_AQUA_row['longitude'],
#    (...)
#      27     'random_time': rand_row_indices[index]%max_time + 1 # at least 1 sec
#      28 }
#      29 #update start date
#      30 #print(climate_doc['date'])
#      31 #producer publish msg in strictured streaming
#    (...)
#      34 #print(climate_doc)
#      35 #print(hotspot_AQUA_doc['random_time'])
# ---> 36 publish_msg(producer02, topic, hotspot_AQUA_doc)
#      37 # every random seconds
#      38 sleep(hotspot_AQUA_doc['random_time'])
#
# Cell In[27], line 34, in publish_msg(producer, topic, data)
#      27     #print(data)
#      28     """
#      29     The flush() method in Kafka’s producer API is used to ensure that all
#      30     previously sent messages have been transmitted to the server and acknowledged
#      31     before proceeding. When you call flush(), it blocks the current thread and waits
#      32     for the producer to complete the sending of all records
#      33     """
# ---> 34     producer.flush()
#      35 except Exception as ex:
#      36     print('Exception from publish_msg func')
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/producer/kafka.py:652, in KafkaProducer.flush(self, timeout)
#     650 self._accumulator.begin_flush()
#     651 self._sender.wakeup()
# --> 652 self._accumulator.await_flush_completion(timeout=timeout)
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/producer/record_accumulator.py:528, in RecordAccumulator.await_flush_completion(self, timeout)
#     525 for batch in self._incomplete.all():
#     526     log.debug('Waiting on produce to %s',
#     527               batch.produce_future.topic_partition)
# --> 528     if not batch.produce_future.wait(timeout=timeout):
#     529         raise Errors.KafkaTimeoutError('Timeout waiting for future')
#     530     if not batch.produce_future.is_done:
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/producer/future.py:28, in FutureProduceResult.wait(self, timeout)
#      26 def wait(self, timeout=None):
#      27     # wait() on python2.6 returns None instead of the flag value
# ---> 28     return self._latch.wait(timeout) or self._latch.is_set()
#
# File /opt/conda/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File /opt/conda/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
"""
Event Producer 3
"""
hotspot_TERRA= pd.read_csv("./hotspot_TERRA_streaming.csv", sep=',')

hotspot_TERRA.head()

"""
Main Function
"""
if __name__ == '__main__':
    topic = 'Scenaries03'
    print('Publishing records..')
    producer03 = connect_kafka_producer()
    
    
    rand_row_indices = list(range(len(hotspot_AQUA.index)))
    random.shuffle(rand_row_indices) 
    # random choose time from 0 to 10
    max_time = 10
    #rand_time = list(range(1,max_time))
#     random.shuffle(rand_time) 
     

    for index, hotspot_TERRA_row in hotspot_TERRA.iterrows():
        hotspot_TERRA_row = hotspot_TERRA.loc[rand_row_indices[index]]

        hotspot_TERRA_doc = {
            'latitude': hotspot_TERRA_row['latitude'],
            'longtitude': hotspot_TERRA_row['longitude'],
            'confidence': hotspot_TERRA_row['confidence'],
            'surface_temperature_celcius': hotspot_TERRA_row['surface_temperature_celcius'],
            'producer': "Producer_3",
            'random_time': rand_row_indices[index]%max_time + 1 # at least 1 sec
        }
        #update start date
        #print(climate_doc['date'])
        #producer publish msg in strictured streaming
        # convert the dictionary to JSON-formatted string and encode as UFT-8 by publish_msg
        # msg = json.dumps(climate_doc)
        #print(climate_doc)
        print(hotspot_TERRA_doc['random_time'])
        publish_msg(producer01, topic, hotspot_AQUA_doc)
        # every random seconds
        sleep(hotspot_TERRA_doc['random_time'])
# Out:
# Publishing records..
# 10
# Node 1 connection failed -- refreshing metadata
